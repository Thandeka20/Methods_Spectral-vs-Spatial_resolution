# %% [markdown]
# ## Import packages

# %%
# Import packages
import argparse
import os
#import geoviews
import warnings
import rasterio as rio
import rasterio
import pandas as pd
import fiona
import matplotlib.pyplot as plt
import numpy.ma as ma
import numpy as np
import xarray as xr
import rioxarray as rxr
from shapely.geometry import mapping, box
import geopandas as gpd
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from rasterio.features import rasterize
from rasterio.transform import from_origin
from rasterio.mask import mask

warnings.simplefilter('ignore')

# %% [markdown]
# ### Code loops through the folder and prints out metadata

# %%
# Define the path to the specific TIFF file
mosaic_file_path = r'C:\Users\User\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\mosaic_2\EMIT_mosaic.tif'

print(f"\nProcessing file: {mosaic_file_path}")

# Open the image
with rasterio.open(mosaic_file_path) as img:
    # Print the original image metadata
    metadata = img.meta
    print("Metadata:", metadata)
    
    # Get NoData value
    nodata = img.nodatavals[0] if img.nodatavals else None
    if nodata is not None:
        print(f"NoData value: {nodata}")
    
    # Loop through each band and print its statistics
    for band in range(1, img.count + 1):
        band_data = img.read(band)
        
        # Mask NoData values
        if nodata is not None:
            band_data = np.ma.masked_equal(band_data, nodata)
        
        # Calculate statistics ignoring NaN values
        valid_data = band_data[np.isfinite(band_data)]
        
        if valid_data.size > 0:
            print(f"\nBand {band} Statistics:")
            print(f"Min: {valid_data.min()}")
            print(f"Max: {valid_data.max()}")
            print(f"Mean: {valid_data.mean()}")
            print(f"Standard Deviation: {valid_data.std()}")
            print(f"First 5 valid pixel values in Band {band}: {valid_data.flatten()[:5]}")
        else:
            print(f"\nBand {band} contains only NaN values.")
# Out:
# Processing file: C:\Users\User\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\mosaic_2\EMIT_mosaic.tif
# Metadata: {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 741, 'height': 686, 'count': 277, 'crs': CRS.from_epsg(4326), 'transform': Affine(0.0005422325202563664, 0.0, 28.79877741333535,
#        0.0, -0.0005422325202563676, -30.673875192500052)}
#
# Band 1 Statistics:
# Min: 0.0038172972854226828
# Max: 0.25613316893577576
# Mean: 0.028315644711256027
# Standard Deviation: 0.007758589927107096
# First 5 valid pixel values in Band 1: [0.03343217 0.02979366 0.02979366 0.02811558 0.03058411]
#
# Band 2 Statistics:
# Min: 0.003957449924200773
# Max: 0.29933997988700867
# Mean: 0.0310385599732399
# Standard Deviation: 0.009054050780832767
# First 5 valid pixel values in Band 2: [0.0362503  0.03142168 0.03142168 0.02955993 0.0325173 ]
#
# Band 3 Statistics:
# Min: 0.004167942795902491
# Max: 0.3212912380695343
# Mean: 0.033452749252319336
# Standard Deviation: 0.01003800518810749
# First 5 valid pixel values in Band 3: [0.03995162 0.03311162 0.03311162 0.03111886 0.03450575]
#
# Band 4 Statistics:
# Min: 0.004415273200720549
# Max: 0.3313937485218048
# Mean: 0.0352327823638916
# Standard Deviation: 0.010471168905496597
# First 5 valid pixel values in Band 4: [0.04027449 0.03479494 0.03479494 0.0327429  0.0365066 ]
#
# Band 5 Statistics:
# Min: 0.004639552440494299
# Max: 0.34025391936302185
# Mean: 0.03707016259431839
# Standard Deviation: 0.0110673438757658
# First 5 valid pixel values in Band 5: [0.0428324  0.03628733 0.03628733 0.03420462 0.0383168 ]
#
# Band 6 Statistics:
# Min: 0.004872863180935383
# Max: 0.3479689955711365
# Mean: 0.03886745125055313
# Standard Deviation: 0.011607946828007698
# First 5 valid pixel values in Band 6: [0.04429211 0.03775148 0.03775148 0.0356911  0.0401396 ]
#
# Band 7 Statistics:
# Min: 0.005097879096865654
# Max: 0.3546527922153473
# Mean: 0.040455784648656845
# Standard Deviation: 0.011997772380709648
# First 5 valid pixel values in Band 7: [0.04622983 0.03917363 0.03917363 0.03705526 0.04186765]
#
# Band 8 Statistics:
# Min: 0.005288119427859783
# Max: 0.35932523012161255
# Mean: 0.041820548474788666
# Standard Deviation: 0.012308560311794281
# First 5 valid pixel values in Band 8: [0.04750047 0.04051917 0.04051917 0.03823099 0.04341228]
#
# Band 9 Statistics:
# Min: 0.00545517448335886
# Max: 0.3648598790168762
# Mean: 0.04275050386786461
# Standard Deviation: 0.012374551966786385
# First 5 valid pixel values in Band 9: [0.04790009 0.04170362 0.04170362 0.03923369 0.04472985]
#
# Band 10 Statistics:
# Min: 0.005594431888312101
# Max: 0.36853086948394775
# Mean: 0.043804898858070374
# Standard Deviation: 0.012614660896360874
# First 5 valid pixel values in Band 10: [0.04824018 0.04280883 0.04280883 0.04018589 0.04595522]
#
# Band 11 Statistics:
# Min: 0.01031030248850584
# Max: 0.37392503023147583
# Mean: 0.04495902732014656
# Standard Deviation: 0.013025878928601742
# First 5 valid pixel values in Band 11: [0.04989382 0.04228206 0.04228206 0.04222565 0.04794841]
#
# Band 12 Statistics:
# Min: 0.009650344960391521
# Max: 0.3779172897338867
# Mean: 0.045703183859586716
# Standard Deviation: 0.013565507717430592
# First 5 valid pixel values in Band 12: [0.0505468  0.04319971 0.04319971 0.04282681 0.04835707]
#
# Band 13 Statistics:
# Min: 0.010263968259096146
# Max: 0.3848815858364105
# Mean: 0.04802674055099487
# Standard Deviation: 0.01418677531182766
# First 5 valid pixel values in Band 13: [0.05302201 0.04493804 0.04493804 0.0451013  0.05167682]
#
# Band 14 Statistics:
# Min: 0.01077740266919136
# Max: 0.3897203207015991
# Mean: 0.0508633553981781
# Standard Deviation: 0.014750806614756584
# First 5 valid pixel values in Band 14: [0.05508765 0.04693912 0.04693912 0.04741147 0.05461223]
#
# Band 15 Statistics:
# Min: 0.011251820251345634
# Max: 0.3950219750404358
# Mean: 0.05458053946495056
# Standard Deviation: 0.015156271867454052
# First 5 valid pixel values in Band 15: [0.0584044  0.0487274  0.0487274  0.0504207  0.05894049]
#
# Band 16 Statistics:
# Min: 0.012453293427824974
# Max: 0.39686819911003113
# Mean: 0.05914192646741867
# Standard Deviation: 0.015342367812991142
# First 5 valid pixel values in Band 16: [0.06125345 0.05204599 0.05204599 0.05480595 0.06343335]
#
# Band 17 Statistics:
# Min: 0.013491173274815083
# Max: 0.40206995606422424
# Mean: 0.06421703100204468
# Standard Deviation: 0.015605230815708637
# First 5 valid pixel values in Band 17: [0.06436999 0.05593873 0.05593873 0.05971566 0.06964219]
#
# Band 18 Statistics:
# Min: 0.014524334110319614
# Max: 0.40638959407806396
# Mean: 0.06861775368452072
# Standard Deviation: 0.016058839857578278
# First 5 valid pixel values in Band 18: [0.06785782 0.05932813 0.05932813 0.06355913 0.07442322]
#
# Band 19 Statistics:
# Min: 0.014848098158836365
# Max: 0.4095393717288971
# Mean: 0.07165595144033432
# Standard Deviation: 0.016623638570308685
# First 5 valid pixel values in Band 19: [0.07053124 0.06069893 0.06069893 0.06609504 0.0778959 ]
#
# Band 20 Statistics:
# Min: 0.015315237455070019
# Max: 0.41294994950294495
# Mean: 0.07445216178894043
# Standard Deviation: 0.01731785386800766
# First 5 valid pixel values in Band 20: [0.07239206 0.06295852 0.06295852 0.06830376 0.0808885 ]
#
# Band 21 Statistics:
# Min: 0.015091456472873688
# Max: 0.41791296005249023
# Mean: 0.0762399360537529
# Standard Deviation: 0.0181956235319376
# First 5 valid pixel values in Band 21: [0.07415055 0.06372812 0.06372812 0.06955365 0.08280741]
#
# Band 22 Statistics:
# Min: 0.013935238122940063
# Max: 0.41699880361557007
# Mean: 0.07619810849428177
# Standard Deviation: 0.019226251170039177
# First 5 valid pixel values in Band 22: [0.07530156 0.06327341 0.06327341 0.06901822 0.08303708]
#
# Band 23 Statistics:
# Min: 0.01287797000259161
# Max: 0.4174131453037262
# Mean: 0.07528828829526901
# Standard Deviation: 0.020284421741962433
# First 5 valid pixel values in Band 23: [0.07482786 0.06187775 0.06187775 0.06722317 0.08197644]
#
# Band 24 Statistics:
# Min: 0.012414589524269104
# Max: 0.41916170716285706
# Mean: 0.07528632134199142
# Standard Deviation: 0.02130228467285633
# First 5 valid pixel values in Band 24: [0.07548442 0.06183261 0.06183261 0.06646106 0.08166391]
#
# Band 25 Statistics:
# Min: 0.012016822583973408
# Max: 0.4198179841041565
# Mean: 0.07550578564405441
# Standard Deviation: 0.022179007530212402
# First 5 valid pixel values in Band 25: [0.07665064 0.06172809 0.06172809 0.06596538 0.08249912]
#
# Band 26 Statistics:
# Min: 0.012024118565022945
# Max: 0.42063331604003906
# Mean: 0.07650543749332428
# Standard Deviation: 0.02298044227063656
# First 5 valid pixel values in Band 26: [0.0779685  0.06201253 0.06201253 0.06640577 0.08314674]
#
# Band 27 Statistics:
# Min: 0.011442696675658226
# Max: 0.41983720660209656
# Mean: 0.07737520337104797
# Standard Deviation: 0.02365313284099102
# First 5 valid pixel values in Band 27: [0.07919081 0.06217804 0.06217804 0.066526   0.08435314]
#
# Band 28 Statistics:
# Min: 0.011237920261919498
# Max: 0.4210774302482605
# Mean: 0.0775051862001419
# Standard Deviation: 0.02434089407324791
# First 5 valid pixel values in Band 28: [0.08012013 0.06171944 0.06171944 0.065404   0.08422648]
#
# Band 29 Statistics:
# Min: 0.010714317671954632
# Max: 0.4232613146305084
# Mean: 0.0771888867020607
# Standard Deviation: 0.02500648982822895
# First 5 valid pixel values in Band 29: [0.08059519 0.06213702 0.06213702 0.06496864 0.08304048]
#
# Band 30 Statistics:
# Min: 0.010291851125657558
# Max: 0.42206668853759766
# Mean: 0.07749220728874207
# Standard Deviation: 0.0255525354295969
# First 5 valid pixel values in Band 30: [0.08159716 0.06196729 0.06196729 0.06435286 0.08335775]
#
# Band 31 Statistics:
# Min: 0.010526690632104874
# Max: 0.4215167164802551
# Mean: 0.07847725600004196
# Standard Deviation: 0.02610839158296585
# First 5 valid pixel values in Band 31: [0.08308227 0.06271491 0.06271491 0.0651496  0.08428405]
#
# Band 32 Statistics:
# Min: 0.009493865072727203
# Max: 0.42056021094322205
# Mean: 0.07850056886672974
# Standard Deviation: 0.02678358554840088
# First 5 valid pixel values in Band 32: [0.08367304 0.06230709 0.06230709 0.06469047 0.08438951]
#
# Band 33 Statistics:
# Min: 0.009291441179811954
# Max: 0.421014666557312
# Mean: 0.07762471586465836
# Standard Deviation: 0.02735576033592224
# First 5 valid pixel values in Band 33: [0.08457021 0.06265948 0.06265948 0.06345505 0.0838142 ]
#
# Band 34 Statistics:
# Min: 0.008843690156936646
# Max: 0.42059457302093506
# Mean: 0.07729943096637726
# Standard Deviation: 0.027895744889974594
# First 5 valid pixel values in Band 34: [0.08533979 0.06230179 0.06230179 0.062674   0.08300298]
#
# Band 35 Statistics:
# Min: 0.009283604100346565
# Max: 0.4206998348236084
# Mean: 0.07623162865638733
# Standard Deviation: 0.028288589790463448
# First 5 valid pixel values in Band 35: [0.08552944 0.06184701 0.06184701 0.06203268 0.08030897]
#
# Band 36 Statistics:
# Min: 0.008184577338397503
# Max: 0.42199552059173584
# Mean: 0.07663784921169281
# Standard Deviation: 0.02899003028869629
# First 5 valid pixel values in Band 36: [0.08791303 0.06194811 0.06194811 0.06200523 0.08308063]
#
# Band 37 Statistics:
# Min: 0.007774935569614172
# Max: 0.424801230430603
# Mean: 0.07719855010509491
# Standard Deviation: 0.02937248907983303
# First 5 valid pixel values in Band 37: [0.08861667 0.06226409 0.06226409 0.06115742 0.08434917]
#
# Band 38 Statistics:
# Min: 0.007588913198560476
# Max: 0.4224897623062134
# Mean: 0.08027763664722443
# Standard Deviation: 0.029668297618627548
# First 5 valid pixel values in Band 38: [0.09056859 0.06330552 0.06330552 0.0633051  0.08915782]
#
# Band 39 Statistics:
# Min: 0.010111009702086449
# Max: 0.4270419478416443
# Mean: 0.09022779017686844
# Standard Deviation: 0.029538117349147797
# First 5 valid pixel values in Band 39: [0.09597215 0.06883424 0.06883424 0.07083608 0.09812555]
#
# Band 40 Statistics:
# Min: 0.014867004938423634
# Max: 0.43390247225761414
# Mean: 0.10728602856397629
# Standard Deviation: 0.02866046316921711
# First 5 valid pixel values in Band 40: [0.10519737 0.07975698 0.07975698 0.0857348  0.11644313]
#
# Band 41 Statistics:
# Min: 0.020237181335687637
# Max: 0.4350627660751343
# Mean: 0.12600240111351013
# Standard Deviation: 0.026981620118021965
# First 5 valid pixel values in Band 41: [0.11514595 0.09405614 0.09405614 0.10513742 0.13564222]
#
# Band 42 Statistics:
# Min: 0.026421543210744858
# Max: 0.43739765882492065
# Mean: 0.14490023255348206
# Standard Deviation: 0.02543526701629162
# First 5 valid pixel values in Band 42: [0.12483509 0.1099619  0.1099619  0.12656565 0.15631583]
#
# Band 43 Statistics:
# Min: 0.02839190699160099
# Max: 0.43788421154022217
# Mean: 0.1648198813199997
# Standard Deviation: 0.0240219384431839
# First 5 valid pixel values in Band 43: [0.13490072 0.12911692 0.12911692 0.15097892 0.17661236]
#
# Band 44 Statistics:
# Min: 0.023942546918988228
# Max: 0.43929749727249146
# Mean: 0.18262310326099396
# Standard Deviation: 0.024135416373610497
# First 5 valid pixel values in Band 44: [0.14347024 0.14830808 0.14830808 0.1755779  0.19446759]
#
# Band 45 Statistics:
# Min: 0.021723289042711258
# Max: 0.4404814839363098
# Mean: 0.19677600264549255
# Standard Deviation: 0.025808772072196007
# First 5 valid pixel values in Band 45: [0.15060106 0.16454773 0.16454773 0.19759735 0.21061914]
#
# Band 46 Statistics:
# Min: 0.020631710067391396
# Max: 0.441417932510376
# Mean: 0.20790641009807587
# Standard Deviation: 0.0274310652166605
# First 5 valid pixel values in Band 46: [0.15597638 0.17899153 0.17899153 0.21671106 0.22198416]
#
# Band 47 Statistics:
# Min: 0.021143119782209396
# Max: 0.44135716557502747
# Mean: 0.2130766212940216
# Standard Deviation: 0.02870207093656063
# First 5 valid pixel values in Band 47: [0.15863675 0.18504441 0.18504441 0.22433272 0.2277946 ]
#
# Band 48 Statistics:
# Min: 0.02121233381330967
# Max: 0.4438271224498749
# Mean: 0.21713069081306458
# Standard Deviation: 0.029594682157039642
# First 5 valid pixel values in Band 48: [0.16115505 0.18954992 0.18954992 0.22979799 0.23255913]
#
# Band 49 Statistics:
# Min: 0.02112196385860443
# Max: 0.4414255619049072
# Mean: 0.2201550453901291
# Standard Deviation: 0.02999008074402809
# First 5 valid pixel values in Band 49: [0.16351448 0.19232433 0.19232433 0.23292957 0.2354489 ]
#
# Band 50 Statistics:
# Min: 0.020952342078089714
# Max: 0.44393178820610046
# Mean: 0.22324791550636292
# Standard Deviation: 0.03041127137839794
# First 5 valid pixel values in Band 50: [0.16603671 0.19514312 0.19514312 0.23624195 0.23887286]
#
# Band 51 Statistics:
# Min: 0.020746435970067978
# Max: 0.4443824589252472
# Mean: 0.22583414614200592
# Standard Deviation: 0.030759679153561592
# First 5 valid pixel values in Band 51: [0.16825794 0.19755405 0.19755405 0.23899922 0.24184969]
#
# Band 52 Statistics:
# Min: 0.02070479653775692
# Max: 0.4484354555606842
# Mean: 0.2283121943473816
# Standard Deviation: 0.031120115891098976
# First 5 valid pixel values in Band 52: [0.1703877 0.1998066 0.1998066 0.2416991 0.2448027]
#
# Band 53 Statistics:
# Min: 0.020755812525749207
# Max: 0.4521540105342865
# Mean: 0.23069673776626587
# Standard Deviation: 0.03148442879319191
# First 5 valid pixel values in Band 53: [0.17231692 0.20202738 0.20202738 0.2442771  0.24775617]
#
# Band 54 Statistics:
# Min: 0.02080310694873333
# Max: 0.4556816816329956
# Mean: 0.23296146094799042
# Standard Deviation: 0.0318528488278389
# First 5 valid pixel values in Band 54: [0.17421935 0.20410456 0.20410456 0.24673246 0.25057355]
#
# Band 55 Statistics:
# Min: 0.020952653139829636
# Max: 0.45839980244636536
# Mean: 0.23489148914813995
# Standard Deviation: 0.03212643787264824
# First 5 valid pixel values in Band 55: [0.17594157 0.20579524 0.20579524 0.24876027 0.2529046 ]
#
# Band 56 Statistics:
# Min: 0.020904330536723137
# Max: 0.46121394634246826
# Mean: 0.23689930140972137
# Standard Deviation: 0.03245372325181961
# First 5 valid pixel values in Band 56: [0.17767955 0.20755398 0.20755398 0.25079733 0.25538707]
#
# Band 57 Statistics:
# Min: 0.020552735775709152
# Max: 0.4634876847267151
# Mean: 0.23885157704353333
# Standard Deviation: 0.032773446291685104
# First 5 valid pixel values in Band 57: [0.17932332 0.20929208 0.20929208 0.25273338 0.25777817]
#
# Band 58 Statistics:
# Min: 0.019970107823610306
# Max: 0.46571651101112366
# Mean: 0.24076226353645325
# Standard Deviation: 0.033096931874752045
# First 5 valid pixel values in Band 58: [0.18094243 0.21098867 0.21098867 0.25459233 0.26011425]
#
# Band 59 Statistics:
# Min: 0.019556164741516113
# Max: 0.46847233176231384
# Mean: 0.2426779866218567
# Standard Deviation: 0.03345926105976105
# First 5 valid pixel values in Band 59: [0.18251494 0.21274975 0.21274975 0.25658035 0.26253092]
#
# Band 60 Statistics:
# Min: 0.0190415158867836
# Max: 0.47116926312446594
# Mean: 0.24453097581863403
# Standard Deviation: 0.03379442170262337
# First 5 valid pixel values in Band 60: [0.18403082 0.21445513 0.21445513 0.25851688 0.26480812]
#
# Band 61 Statistics:
# Min: 0.018473586067557335
# Max: 0.473450630903244
# Mean: 0.24632546305656433
# Standard Deviation: 0.034118641167879105
# First 5 valid pixel values in Band 61: [0.18561974 0.21608035 0.21608035 0.2603219  0.2670224 ]
#
# Band 62 Statistics:
# Min: 0.017770865932106972
# Max: 0.47596946358680725
# Mean: 0.24806919693946838
# Standard Deviation: 0.034448105841875076
# First 5 valid pixel values in Band 62: [0.18707848 0.21766281 0.21766281 0.26216137 0.2692161 ]
#
# Band 63 Statistics:
# Min: 0.017037183046340942
# Max: 0.47787079215049744
# Mean: 0.2497696727514267
# Standard Deviation: 0.03475163131952286
# First 5 valid pixel values in Band 63: [0.18854922 0.21923244 0.21923244 0.26389667 0.27135813]
#
# Band 64 Statistics:
# Min: 0.016393201425671577
# Max: 0.4796098470687866
# Mean: 0.25147193670272827
# Standard Deviation: 0.035054925829172134
# First 5 valid pixel values in Band 64: [0.19008335 0.22080168 0.22080168 0.2656245  0.27350482]
#
# Band 65 Statistics:
# Min: 0.015763331204652786
# Max: 0.4811875820159912
# Mean: 0.25310447812080383
# Standard Deviation: 0.03533802926540375
# First 5 valid pixel values in Band 65: [0.19151694 0.22233282 0.22233282 0.267306   0.2756466 ]
#
# Band 66 Statistics:
# Min: 0.015209775418043137
# Max: 0.48183920979499817
# Mean: 0.2545529901981354
# Standard Deviation: 0.03560318425297737
# First 5 valid pixel values in Band 66: [0.19283177 0.22384897 0.22384897 0.26897988 0.27774826]
#
# Band 67 Statistics:
# Min: 0.014816793613135815
# Max: 0.4826074540615082
# Mean: 0.2561644911766052
# Standard Deviation: 0.0358673520386219
# First 5 valid pixel values in Band 67: [0.19439071 0.2253593  0.2253593  0.27057663 0.27992877]
#
# Band 68 Statistics:
# Min: 0.014407594688236713
# Max: 0.4835706949234009
# Mean: 0.25771769881248474
# Standard Deviation: 0.03614885360002518
# First 5 valid pixel values in Band 68: [0.19581263 0.22683981 0.22683981 0.2721917  0.28205952]
#
# Band 69 Statistics:
# Min: 0.014011133462190628
# Max: 0.48375993967056274
# Mean: 0.2591554820537567
# Standard Deviation: 0.036336567252874374
# First 5 valid pixel values in Band 69: [0.1973309  0.22809753 0.22809753 0.27334225 0.28385487]
#
# Band 70 Statistics:
# Min: 0.013443553820252419
# Max: 0.4831188917160034
# Mean: 0.26041775941848755
# Standard Deviation: 0.036481823772192
# First 5 valid pixel values in Band 70: [0.19877112 0.22917707 0.22917707 0.27426147 0.285403  ]
#
# Band 71 Statistics:
# Min: 0.012468035332858562
# Max: 0.4775448441505432
# Mean: 0.26103201508522034
# Standard Deviation: 0.03640611469745636
# First 5 valid pixel values in Band 71: [0.20015167 0.22982565 0.22982565 0.27442384 0.2862114 ]
#
# Band 72 Statistics:
# Min: 0.011338423006236553
# Max: 0.4707307815551758
# Mean: 0.2615041434764862
# Standard Deviation: 0.03616369143128395
# First 5 valid pixel values in Band 72: [0.2017384  0.22973235 0.22973235 0.27335405 0.2863452 ]
#
# Band 73 Statistics:
# Min: 0.009969882667064667
# Max: 0.46386781334877014
# Mean: 0.2620145380496979
# Standard Deviation: 0.03586253523826599
# First 5 valid pixel values in Band 73: [0.20342693 0.229364   0.229364   0.27213767 0.28641778]
#
# Band 74 Statistics:
# Min: 0.008165977895259857
# Max: 0.4533635079860687
# Mean: 0.2618350088596344
# Standard Deviation: 0.035340480506420135
# First 5 valid pixel values in Band 74: [0.20507847 0.22787073 0.22787073 0.2692419  0.28532818]
#
# Band 75 Statistics:
# Min: 0.006960708182305098
# Max: 0.44565317034721375
# Mean: 0.26180005073547363
# Standard Deviation: 0.034936580806970596
# First 5 valid pixel values in Band 75: [0.20683    0.22638384 0.22638384 0.26640716 0.28440455]
#
# Band 76 Statistics:
# Min: 0.006539962720125914
# Max: 0.4462907612323761
# Mean: 0.26272818446159363
# Standard Deviation: 0.034890953451395035
# First 5 valid pixel values in Band 76: [0.2086744  0.22622812 0.22622812 0.2656435  0.28499305]
#
# Band 77 Statistics:
# Min: 0.00652666762471199
# Max: 0.44590499997138977
# Mean: 0.2641403377056122
# Standard Deviation: 0.035036612302064896
# First 5 valid pixel values in Band 77: [0.21044073 0.22714387 0.22714387 0.2663221  0.2863813 ]
#
# Band 78 Statistics:
# Min: 0.006610887590795755
# Max: 0.4452001452445984
# Mean: 0.2654503881931305
# Standard Deviation: 0.0353366993367672
# First 5 valid pixel values in Band 78: [0.21191753 0.22871906 0.22871906 0.2678457  0.2881343 ]
#
# Band 79 Statistics:
# Min: 0.006810595281422138
# Max: 0.4503081142902374
# Mean: 0.2678060233592987
# Standard Deviation: 0.035810671746730804
# First 5 valid pixel values in Band 79: [0.21373145 0.23065604 0.23065604 0.27092513 0.2911942 ]
#
# Band 80 Statistics:
# Min: 0.007223400287330151
# Max: 0.45756521821022034
# Mean: 0.2707252502441406
# Standard Deviation: 0.03640025854110718
# First 5 valid pixel values in Band 80: [0.21558128 0.23347506 0.23347506 0.27499586 0.295024  ]
#
# Band 81 Statistics:
# Min: 0.007526901550590992
# Max: 0.46500059962272644
# Mean: 0.2737277150154114
# Standard Deviation: 0.03701145574450493
# First 5 valid pixel values in Band 81: [0.21744078 0.23680861 0.23680861 0.27907962 0.29891476]
#
# Band 82 Statistics:
# Min: 0.007887612096965313
# Max: 0.4727196991443634
# Mean: 0.2766215205192566
# Standard Deviation: 0.03757813945412636
# First 5 valid pixel values in Band 82: [0.21953121 0.23994051 0.23994051 0.28292856 0.30244315]
#
# Band 83 Statistics:
# Min: 0.008344918489456177
# Max: 0.4808850884437561
# Mean: 0.2795808017253876
# Standard Deviation: 0.03816577419638634
# First 5 valid pixel values in Band 83: [0.22154078 0.24313805 0.24313805 0.2869381  0.30614725]
#
# Band 84 Statistics:
# Min: 0.008749252185225487
# Max: 0.4886276423931122
# Mean: 0.2824938893318176
# Standard Deviation: 0.038755059242248535
# First 5 valid pixel values in Band 84: [0.22351205 0.24631032 0.24631032 0.29089966 0.3098783 ]
#
# Band 85 Statistics:
# Min: 0.008956500329077244
# Max: 0.4958183169364929
# Mean: 0.28527164459228516
# Standard Deviation: 0.03932094946503639
# First 5 valid pixel values in Band 85: [0.22546203 0.24938865 0.24938865 0.29467893 0.3133314 ]
#
# Band 86 Statistics:
# Min: 0.009318157099187374
# Max: 0.502356231212616
# Mean: 0.2879561185836792
# Standard Deviation: 0.039868857711553574
# First 5 valid pixel values in Band 86: [0.22749159 0.25239244 0.25239244 0.29826692 0.31692055]
#
# Band 87 Statistics:
# Min: 0.009649577550590038
# Max: 0.5078216791152954
# Mean: 0.29043275117874146
# Standard Deviation: 0.04034743830561638
# First 5 valid pixel values in Band 87: [0.22934557 0.25507143 0.25507143 0.3015232  0.32004398]
#
# Band 88 Statistics:
# Min: 0.009890048764646053
# Max: 0.5121459364891052
# Mean: 0.2927393317222595
# Standard Deviation: 0.040761373937129974
# First 5 valid pixel values in Band 88: [0.23123388 0.25749403 0.25749403 0.3043877  0.3230833 ]
#
# Band 89 Statistics:
# Min: 0.01003969181329012
# Max: 0.5151697397232056
# Mean: 0.29483503103256226
# Standard Deviation: 0.041095178574323654
# First 5 valid pixel values in Band 89: [0.23298483 0.25957364 0.25957364 0.30682608 0.32560042]
#
# Band 90 Statistics:
# Min: 0.010171575471758842
# Max: 0.517097532749176
# Mean: 0.2968748211860657
# Standard Deviation: 0.04138494282960892
# First 5 valid pixel values in Band 90: [0.23499337 0.26149064 0.26149064 0.30893743 0.32808346]
#
# Band 91 Statistics:
# Min: 0.010156274773180485
# Max: 0.517656683921814
# Mean: 0.29867005348205566
# Standard Deviation: 0.04158762842416763
# First 5 valid pixel values in Band 91: [0.23697667 0.2631021  0.2631021  0.31057572 0.33017918]
#
# Band 92 Statistics:
# Min: 0.009949647821485996
# Max: 0.5167952179908752
# Mean: 0.30031368136405945
# Standard Deviation: 0.041764095425605774
# First 5 valid pixel values in Band 92: [0.23883557 0.26454285 0.26454285 0.31204626 0.3322312 ]
#
# Band 93 Statistics:
# Min: 0.00970698893070221
# Max: 0.5144388675689697
# Mean: 0.30160295963287354
# Standard Deviation: 0.04187546297907829
# First 5 valid pixel values in Band 93: [0.24065006 0.26568255 0.26568255 0.31321692 0.33399376]
#
# Band 94 Statistics:
# Min: 0.009486556053161621
# Max: 0.5113281011581421
# Mean: 0.30258890986442566
# Standard Deviation: 0.041940316557884216
# First 5 valid pixel values in Band 94: [0.24223593 0.26644924 0.26644924 0.31397817 0.33543706]
#
# Band 95 Statistics:
# Min: 0.00913612823933363
# Max: 0.5076719522476196
# Mean: 0.30329281091690063
# Standard Deviation: 0.04203643649816513
# First 5 valid pixel values in Band 95: [0.24357903 0.26710337 0.26710337 0.31491122 0.3369467 ]
#
# Band 96 Statistics:
# Min: 0.00879671610891819
# Max: 0.502181351184845
# Mean: 0.3032137453556061
# Standard Deviation: 0.04194806516170502
# First 5 valid pixel values in Band 96: [0.24485946 0.2667263  0.2667263  0.31461257 0.33742112]
#
# Band 97 Statistics:
# Min: 0.008258255198597908
# Max: 0.5060739517211914
# Mean: 0.30185577273368835
# Standard Deviation: 0.041463613510131836
# First 5 valid pixel values in Band 97: [0.24611185 0.26422885 0.26422885 0.31057554 0.33526707]
#
# Band 98 Statistics:
# Min: 0.007330206222832203
# Max: 0.5099074244499207
# Mean: 0.2989613115787506
# Standard Deviation: 0.04060567542910576
# First 5 valid pixel values in Band 98: [0.24724033 0.2591569  0.2591569  0.30245435 0.33015567]
#
# Band 99 Statistics:
# Min: 0.006042073480784893
# Max: 0.5140871405601501
# Mean: 0.2953025996685028
# Standard Deviation: 0.039981164038181305
# First 5 valid pixel values in Band 99: [0.24807465 0.25355148 0.25355148 0.2936709  0.32463875]
#
# Band 100 Statistics:
# Min: 0.005057165864855051
# Max: 0.5173358917236328
# Mean: 0.29055219888687134
# Standard Deviation: 0.03962233290076256
# First 5 valid pixel values in Band 100: [0.2486062  0.24706547 0.24706547 0.28312942 0.31776094]
#
# Band 101 Statistics:
# Min: 0.004560048226267099
# Max: 0.520287036895752
# Mean: 0.28758299350738525
# Standard Deviation: 0.03960514813661575
# First 5 valid pixel values in Band 101: [0.24906889 0.24322739 0.24322739 0.2762407  0.31347817]
#
# Band 102 Statistics:
# Min: 0.004481840878725052
# Max: 0.5237529873847961
# Mean: 0.2866576313972473
# Standard Deviation: 0.039677977561950684
# First 5 valid pixel values in Band 102: [0.24969688 0.24201496 0.24201496 0.2737731  0.31235072]
#
# Band 103 Statistics:
# Min: 0.004678424447774887
# Max: 0.5277103781700134
# Mean: 0.2865535616874695
# Standard Deviation: 0.039806563407182693
# First 5 valid pixel values in Band 103: [0.25062737 0.24175073 0.24175073 0.2730155  0.31243047]
#
# Band 104 Statistics:
# Min: 0.0050119697116315365
# Max: 0.5309150218963623
# Mean: 0.2866295874118805
# Standard Deviation: 0.03996073827147484
# First 5 valid pixel values in Band 104: [0.25154698 0.24161984 0.24161984 0.27266937 0.31273675]
#
# Band 105 Statistics:
# Min: 0.005356162786483765
# Max: 0.5340796709060669
# Mean: 0.2866375148296356
# Standard Deviation: 0.04011743515729904
# First 5 valid pixel values in Band 105: [0.25244936 0.24151917 0.24151917 0.27220786 0.31294295]
#
# Band 106 Statistics:
# Min: 0.005556718446314335
# Max: 0.5371202230453491
# Mean: 0.2870391607284546
# Standard Deviation: 0.04028751701116562
# First 5 valid pixel values in Band 106: [0.25339374 0.24188475 0.24188475 0.27236632 0.31364807]
#
# Band 107 Statistics:
# Min: 0.005900575313717127
# Max: 0.5402505993843079
# Mean: 0.2880639433860779
# Standard Deviation: 0.040491983294487
# First 5 valid pixel values in Band 107: [0.2544903  0.24297473 0.24297473 0.27346376 0.31520188]
#
# Band 108 Statistics:
# Min: 0.006266572047024965
# Max: 0.5435118079185486
# Mean: 0.28959783911705017
# Standard Deviation: 0.04067212715744972
# First 5 valid pixel values in Band 108: [0.25565493 0.24483247 0.24483247 0.27538654 0.31745458]
#
# Band 109 Statistics:
# Min: 0.006642876658588648
# Max: 0.5458123087882996
# Mean: 0.291755735874176
# Standard Deviation: 0.040859419852495193
# First 5 valid pixel values in Band 109: [0.25713104 0.24749313 0.24749313 0.2782362  0.32051694]
#
# Band 110 Statistics:
# Min: 0.007143015507608652
# Max: 0.5495094656944275
# Mean: 0.2944646179676056
# Standard Deviation: 0.041098568588495255
# First 5 valid pixel values in Band 110: [0.25887766 0.25069278 0.25069278 0.28181496 0.32412344]
#
# Band 111 Statistics:
# Min: 0.007518414407968521
# Max: 0.5520294308662415
# Mean: 0.29726240038871765
# Standard Deviation: 0.04135952144861221
# First 5 valid pixel values in Band 111: [0.2606599  0.2540524  0.2540524  0.28545013 0.32777515]
#
# Band 112 Statistics:
# Min: 0.0078008221462368965
# Max: 0.5570065975189209
# Mean: 0.3000885844230652
# Standard Deviation: 0.04170858860015869
# First 5 valid pixel values in Band 112: [0.26263443 0.25714955 0.25714955 0.28905377 0.3314423 ]
#
# Band 113 Statistics:
# Min: 0.008050461299717426
# Max: 0.5602325797080994
# Mean: 0.3025784194469452
# Standard Deviation: 0.042036786675453186
# First 5 valid pixel values in Band 113: [0.26437312 0.25992894 0.25992894 0.29213876 0.33465272]
#
# Band 114 Statistics:
# Min: 0.008229412138462067
# Max: 0.561381995677948
# Mean: 0.30484575033187866
# Standard Deviation: 0.04236375913023949
# First 5 valid pixel values in Band 114: [0.2660044  0.26252759 0.26252759 0.2951896  0.33792213]
#
# Band 115 Statistics:
# Min: 0.008212322369217873
# Max: 0.5641766786575317
# Mean: 0.30678924918174744
# Standard Deviation: 0.04267319664359093
# First 5 valid pixel values in Band 115: [0.26756603 0.26468164 0.26468164 0.29770702 0.3406611 ]
#
# Band 116 Statistics:
# Min: 0.008244531229138374
# Max: 0.5668991804122925
# Mean: 0.30839991569519043
# Standard Deviation: 0.04296055808663368
# First 5 valid pixel values in Band 116: [0.26912397 0.2664041  0.2664041  0.29945347 0.3427836 ]
#
# Band 117 Statistics:
# Min: 0.008183708414435387
# Max: 0.5696525573730469
# Mean: 0.30976027250289917
# Standard Deviation: 0.04324301332235336
# First 5 valid pixel values in Band 117: [0.27061594 0.26782978 0.26782978 0.30062774 0.3445601 ]
#
# Band 118 Statistics:
# Min: 0.008070259355008602
# Max: 0.5723057389259338
# Mean: 0.3108539581298828
# Standard Deviation: 0.043531496077775955
# First 5 valid pixel values in Band 118: [0.27214786 0.26885912 0.26885912 0.30123693 0.34591627]
#
# Band 119 Statistics:
# Min: 0.007995976135134697
# Max: 0.5749301314353943
# Mean: 0.3114728629589081
# Standard Deviation: 0.04382266476750374
# First 5 valid pixel values in Band 119: [0.27367526 0.2692736  0.2692736  0.30094036 0.34653184]
#
# Band 120 Statistics:
# Min: 0.007824800908565521
# Max: 0.5774334669113159
# Mean: 0.31140926480293274
# Standard Deviation: 0.044111467897892
# First 5 valid pixel values in Band 120: [0.27504948 0.2689266  0.2689266  0.29953706 0.34621844]
#
# Band 121 Statistics:
# Min: 0.0076541295275092125
# Max: 0.5799956917762756
# Mean: 0.31046736240386963
# Standard Deviation: 0.044415973126888275
# First 5 valid pixel values in Band 121: [0.27619866 0.26764765 0.26764765 0.29668584 0.34469336]
#
# Band 122 Statistics:
# Min: 0.00735374353826046
# Max: 0.5823850035667419
# Mean: 0.3085545301437378
# Standard Deviation: 0.04477131366729736
# First 5 valid pixel values in Band 122: [0.2770486  0.26540196 0.26540196 0.29233572 0.34185594]
#
# Band 123 Statistics:
# Min: 0.007028938736766577
# Max: 0.5846263766288757
# Mean: 0.30564749240875244
# Standard Deviation: 0.04524143785238266
# First 5 valid pixel values in Band 123: [0.2775383  0.26222095 0.26222095 0.28639042 0.33768854]
#
# Band 124 contains only NaN values.
#
# Band 125 contains only NaN values.
#
# Band 126 contains only NaN values.
#
# Band 127 contains only NaN values.
#
# Band 128 contains only NaN values.
#
# Band 129 contains only NaN values.
#
# Band 130 contains only NaN values.
#
# Band 131 contains only NaN values.
#
# Band 132 contains only NaN values.
#
# Band 133 contains only NaN values.
#
# Band 134 contains only NaN values.
#
# Band 135 contains only NaN values.
#
# Band 136 contains only NaN values.
#
# Band 137 contains only NaN values.
#
# Band 138 contains only NaN values.
#
# Band 139 Statistics:
# Min: -0.041508711874485016
# Max: 0.5657085180282593
# Mean: 0.15283632278442383
# Standard Deviation: 0.05077635496854782
# First 5 valid pixel values in Band 139: [0.20045733 0.13752845 0.13752845 0.106567   0.14850628]
#
# Band 140 Statistics:
# Min: 0.0012424546293914318
# Max: 0.5855212807655334
# Mean: 0.1550663560628891
# Standard Deviation: 0.05314886197447777
# First 5 valid pixel values in Band 140: [0.20792606 0.1342027  0.1342027  0.10485432 0.14484781]
#
# Band 141 Statistics:
# Min: 0.0010920584900304675
# Max: 0.6173887848854065
# Mean: 0.15915381908416748
# Standard Deviation: 0.055911701172590256
# First 5 valid pixel values in Band 141: [0.21547577 0.14237499 0.14237499 0.10621429 0.14868067]
#
# Band 142 Statistics:
# Min: 0.0016102222725749016
# Max: 0.6534445285797119
# Mean: 0.1647871434688568
# Standard Deviation: 0.057832613587379456
# First 5 valid pixel values in Band 142: [0.2216699  0.1405767  0.1405767  0.11004552 0.16847984]
#
# Band 143 Statistics:
# Min: 0.0028935358859598637
# Max: 0.6070060133934021
# Mean: 0.16220302879810333
# Standard Deviation: 0.055872976779937744
# First 5 valid pixel values in Band 143: [0.21911895 0.13725606 0.13725606 0.11108779 0.16895959]
#
# Band 144 Statistics:
# Min: 0.002458515577018261
# Max: 0.6161406636238098
# Mean: 0.1627153903245926
# Standard Deviation: 0.054938893765211105
# First 5 valid pixel values in Band 144: [0.21810474 0.14094302 0.14094302 0.10957588 0.15780972]
#
# Band 145 Statistics:
# Min: 0.003145157592371106
# Max: 0.6092788577079773
# Mean: 0.1638537496328354
# Standard Deviation: 0.05419595539569855
# First 5 valid pixel values in Band 145: [0.21684985 0.14475021 0.14475021 0.11176359 0.15917861]
#
# Band 146 Statistics:
# Min: 0.001972359837964177
# Max: 0.6197596788406372
# Mean: 0.16992169618606567
# Standard Deviation: 0.05511576309800148
# First 5 valid pixel values in Band 146: [0.22394384 0.14894739 0.14894739 0.11569732 0.1628109 ]
#
# Band 147 Statistics:
# Min: 0.0019866195507347584
# Max: 0.6222676038742065
# Mean: 0.17484168708324432
# Standard Deviation: 0.055021271109580994
# First 5 valid pixel values in Band 147: [0.22823751 0.15168945 0.15168945 0.11938906 0.17355344]
#
# Band 148 Statistics:
# Min: 0.0021430738270282745
# Max: 0.6185263395309448
# Mean: 0.17910242080688477
# Standard Deviation: 0.054689593613147736
# First 5 valid pixel values in Band 148: [0.23131128 0.15511297 0.15511297 0.1234221  0.17900948]
#
# Band 149 Statistics:
# Min: 0.0018877119291573763
# Max: 0.6245471835136414
# Mean: 0.1836727112531662
# Standard Deviation: 0.054680898785591125
# First 5 valid pixel values in Band 149: [0.23566394 0.15764916 0.15764916 0.12816265 0.18621998]
#
# Band 150 Statistics:
# Min: 0.0024863258004188538
# Max: 0.6234954595565796
# Mean: 0.18857789039611816
# Standard Deviation: 0.05459240451455116
# First 5 valid pixel values in Band 150: [0.23881043 0.16225533 0.16225533 0.13279581 0.19031286]
#
# Band 151 Statistics:
# Min: 0.0023487024009227753
# Max: 0.6263538002967834
# Mean: 0.1925981342792511
# Standard Deviation: 0.05436018481850624
# First 5 valid pixel values in Band 151: [0.24217947 0.16554649 0.16554649 0.13643494 0.19530404]
#
# Band 152 Statistics:
# Min: 0.002697847317904234
# Max: 0.6283695101737976
# Mean: 0.19657112658023834
# Standard Deviation: 0.05414724349975586
# First 5 valid pixel values in Band 152: [0.24464403 0.16845144 0.16845144 0.14062083 0.20051824]
#
# Band 153 Statistics:
# Min: 0.00228321086615324
# Max: 0.6291724443435669
# Mean: 0.20044541358947754
# Standard Deviation: 0.05399429798126221
# First 5 valid pixel values in Band 153: [0.24761799 0.17076121 0.17076121 0.14482762 0.20505859]
#
# Band 154 Statistics:
# Min: 0.0025634041521698236
# Max: 0.6310835480690002
# Mean: 0.20451204478740692
# Standard Deviation: 0.05397907644510269
# First 5 valid pixel values in Band 154: [0.25115064 0.17397675 0.17397675 0.1490404  0.2107477 ]
#
# Band 155 Statistics:
# Min: 0.002482619136571884
# Max: 0.631770133972168
# Mean: 0.2078334093093872
# Standard Deviation: 0.05373428016901016
# First 5 valid pixel values in Band 155: [0.25282663 0.17728385 0.17728385 0.15265056 0.2142871 ]
#
# Band 156 Statistics:
# Min: 0.0023102795239537954
# Max: 0.6333833932876587
# Mean: 0.21075037121772766
# Standard Deviation: 0.05360487475991249
# First 5 valid pixel values in Band 156: [0.25441948 0.17909959 0.17909959 0.15624923 0.21846928]
#
# Band 157 Statistics:
# Min: 0.0028717562090605497
# Max: 0.6300656199455261
# Mean: 0.21257539093494415
# Standard Deviation: 0.0531676821410656
# First 5 valid pixel values in Band 157: [0.25479272 0.18067011 0.18067011 0.15766728 0.21999039]
#
# Band 158 Statistics:
# Min: 0.0026963597629219294
# Max: 0.6306601762771606
# Mean: 0.21578900516033173
# Standard Deviation: 0.05312485247850418
# First 5 valid pixel values in Band 158: [0.25753605 0.18468297 0.18468297 0.16079202 0.2225116 ]
#
# Band 159 Statistics:
# Min: 0.0026695674750953913
# Max: 0.6375417709350586
# Mean: 0.22008119523525238
# Standard Deviation: 0.05342768505215645
# First 5 valid pixel values in Band 159: [0.26063052 0.18792154 0.18792154 0.1648257  0.22799972]
#
# Band 160 Statistics:
# Min: 0.002606855006888509
# Max: 0.6398206353187561
# Mean: 0.22354741394519806
# Standard Deviation: 0.05356479063630104
# First 5 valid pixel values in Band 160: [0.2636917  0.1896244  0.1896244  0.16854292 0.23251946]
#
# Band 161 Statistics:
# Min: 0.002597925951704383
# Max: 0.635615885257721
# Mean: 0.2252494990825653
# Standard Deviation: 0.05337218940258026
# First 5 valid pixel values in Band 161: [0.26433387 0.19144526 0.19144526 0.17108074 0.2348244 ]
#
# Band 162 Statistics:
# Min: 0.002772377571091056
# Max: 0.638554573059082
# Mean: 0.2289036065340042
# Standard Deviation: 0.053641077131032944
# First 5 valid pixel values in Band 162: [0.26737374 0.19421986 0.19421986 0.1737475  0.2382362 ]
#
# Band 163 Statistics:
# Min: 0.002632977906614542
# Max: 0.638281524181366
# Mean: 0.23280632495880127
# Standard Deviation: 0.05404764413833618
# First 5 valid pixel values in Band 163: [0.26978984 0.1978767  0.1978767  0.17739615 0.2433424 ]
#
# Band 164 Statistics:
# Min: 0.002656486351042986
# Max: 0.6446702480316162
# Mean: 0.2361554205417633
# Standard Deviation: 0.05441351234912872
# First 5 valid pixel values in Band 164: [0.27227554 0.20136508 0.20136508 0.18089132 0.2469013 ]
#
# Band 165 Statistics:
# Min: 0.00247656786814332
# Max: 0.6461320519447327
# Mean: 0.23853985965251923
# Standard Deviation: 0.05459338799118996
# First 5 valid pixel values in Band 165: [0.2748487  0.20247057 0.20247057 0.18379532 0.25123605]
#
# Band 166 Statistics:
# Min: 0.0027944203466176987
# Max: 0.6458564400672913
# Mean: 0.2403184473514557
# Standard Deviation: 0.05466736853122711
# First 5 valid pixel values in Band 166: [0.27636272 0.20409212 0.20409212 0.18563841 0.2538637 ]
#
# Band 167 Statistics:
# Min: 0.0028119096532464027
# Max: 0.6469631791114807
# Mean: 0.24138151109218597
# Standard Deviation: 0.054781243205070496
# First 5 valid pixel values in Band 167: [0.27663067 0.2048611  0.2048611  0.18660602 0.25438994]
#
# Band 168 Statistics:
# Min: 0.00250880210660398
# Max: 0.644504964351654
# Mean: 0.24207803606987
# Standard Deviation: 0.054980210959911346
# First 5 valid pixel values in Band 168: [0.27731892 0.20574664 0.20574664 0.1870395  0.2549538 ]
#
# Band 169 Statistics:
# Min: 0.002076625358313322
# Max: 0.6462177038192749
# Mean: 0.2417905032634735
# Standard Deviation: 0.05506901443004608
# First 5 valid pixel values in Band 169: [0.2772633  0.2041793  0.2041793  0.18730102 0.25594243]
#
# Band 170 Statistics:
# Min: 0.002832199912518263
# Max: 0.6435369253158569
# Mean: 0.24139228463172913
# Standard Deviation: 0.055031873285770416
# First 5 valid pixel values in Band 170: [0.27830547 0.20505975 0.20505975 0.18544957 0.2534495 ]
#
# Band 171 Statistics:
# Min: 0.0024634634610265493
# Max: 0.6447458267211914
# Mean: 0.24089907109737396
# Standard Deviation: 0.055007874965667725
# First 5 valid pixel values in Band 171: [0.2770684  0.20429553 0.20429553 0.1851478  0.2551808 ]
#
# Band 172 Statistics:
# Min: 0.002876797690987587
# Max: 0.6458914875984192
# Mean: 0.23964445292949677
# Standard Deviation: 0.05495060607790947
# First 5 valid pixel values in Band 172: [0.27722645 0.20324294 0.20324294 0.18353051 0.25214136]
#
# Band 173 Statistics:
# Min: 0.0025744109880179167
# Max: 0.6454623937606812
# Mean: 0.2375645637512207
# Standard Deviation: 0.054921504110097885
# First 5 valid pixel values in Band 173: [0.2767961  0.20162977 0.20162977 0.18121357 0.24975003]
#
# Band 174 Statistics:
# Min: 0.0024319307412952185
# Max: 0.6474145650863647
# Mean: 0.23556724190711975
# Standard Deviation: 0.054916247725486755
# First 5 valid pixel values in Band 174: [0.2753317  0.1994962  0.1994962  0.18005958 0.24685821]
#
# Band 175 Statistics:
# Min: 0.0025301799178123474
# Max: 0.6492069959640503
# Mean: 0.2334326058626175
# Standard Deviation: 0.0550806000828743
# First 5 valid pixel values in Band 175: [0.27494657 0.19717075 0.19717075 0.17747264 0.24568363]
#
# Band 176 Statistics:
# Min: 0.0025967773981392384
# Max: 0.6495923399925232
# Mean: 0.23071357607841492
# Standard Deviation: 0.055069271475076675
# First 5 valid pixel values in Band 176: [0.27385706 0.19623072 0.19623072 0.17401429 0.2403774 ]
#
# Band 177 Statistics:
# Min: 0.0025355457328259945
# Max: 0.6509070992469788
# Mean: 0.22843928635120392
# Standard Deviation: 0.055102452635765076
# First 5 valid pixel values in Band 177: [0.2728559  0.19333366 0.19333366 0.17148438 0.23954277]
#
# Band 178 Statistics:
# Min: 0.00205672113224864
# Max: 0.6540016531944275
# Mean: 0.2261900156736374
# Standard Deviation: 0.05527014657855034
# First 5 valid pixel values in Band 178: [0.272254   0.19171053 0.19171053 0.16754434 0.23533523]
#
# Band 179 Statistics:
# Min: 0.002386470092460513
# Max: 0.6513660550117493
# Mean: 0.22594264149665833
# Standard Deviation: 0.05556931346654892
# First 5 valid pixel values in Band 179: [0.2724647  0.19231229 0.19231229 0.16815664 0.23476748]
#
# Band 180 Statistics:
# Min: 0.0026278411969542503
# Max: 0.6553177237510681
# Mean: 0.2251785546541214
# Standard Deviation: 0.055907368659973145
# First 5 valid pixel values in Band 180: [0.27331012 0.1925061  0.1925061  0.16719009 0.23596053]
#
# Band 181 Statistics:
# Min: 0.0019947406835854053
# Max: 0.6638595461845398
# Mean: 0.2235102504491806
# Standard Deviation: 0.05629598721861839
# First 5 valid pixel values in Band 181: [0.27250743 0.19117771 0.19117771 0.16484453 0.23196788]
#
# Band 182 Statistics:
# Min: 0.0020249944645911455
# Max: 0.6652932167053223
# Mean: 0.2221495807170868
# Standard Deviation: 0.05671984329819679
# First 5 valid pixel values in Band 182: [0.27246663 0.1897059  0.1897059  0.16382073 0.2311283 ]
#
# Band 183 Statistics:
# Min: 0.002319193445146084
# Max: 0.6654083728790283
# Mean: 0.22009219229221344
# Standard Deviation: 0.05694395303726196
# First 5 valid pixel values in Band 183: [0.2723931  0.18910356 0.18910356 0.16281247 0.22829004]
#
# Band 184 contains only NaN values.
#
# Band 185 contains only NaN values.
#
# Band 186 contains only NaN values.
#
# Band 187 contains only NaN values.
#
# Band 188 contains only NaN values.
#
# Band 189 contains only NaN values.
#
# Band 190 contains only NaN values.
#
# Band 191 contains only NaN values.
#
# Band 192 contains only NaN values.
#
# Band 193 contains only NaN values.
#
# Band 194 contains only NaN values.
#
# Band 195 contains only NaN values.
#
# Band 196 contains only NaN values.
#
# Band 197 contains only NaN values.
#
# Band 198 contains only NaN values.
#
# Band 199 contains only NaN values.
#
# Band 200 contains only NaN values.
#
# Band 201 contains only NaN values.
#
# Band 202 contains only NaN values.
#
# Band 203 contains only NaN values.
#
# Band 204 contains only NaN values.
#
# Band 205 contains only NaN values.
#
# Band 206 contains only NaN values.
#
# Band 207 contains only NaN values.
#
# Band 208 contains only NaN values.
#
# Band 209 contains only NaN values.
#
# Band 210 Statistics:
# Min: 0.0011414248729124665
# Max: 0.7146592140197754
# Mean: 0.12959833443164825
# Standard Deviation: 0.059149570763111115
# First 5 valid pixel values in Band 210: [0.21625188 0.12088399 0.12088399 0.07472235 0.11685622]
#
# Band 211 Statistics:
# Min: 0.0012633646838366985
# Max: 0.7176127433776855
# Mean: 0.1326417177915573
# Standard Deviation: 0.05976739898324013
# First 5 valid pixel values in Band 211: [0.21932442 0.12356522 0.12356522 0.07690123 0.12023789]
#
# Band 212 Statistics:
# Min: 0.0012981356121599674
# Max: 0.7212250232696533
# Mean: 0.13559101521968842
# Standard Deviation: 0.06025591865181923
# First 5 valid pixel values in Band 212: [0.22222823 0.12625624 0.12625624 0.07911237 0.12366524]
#
# Band 213 Statistics:
# Min: 0.0013891473645344377
# Max: 0.7222081422805786
# Mean: 0.138106107711792
# Standard Deviation: 0.06055576726794243
# First 5 valid pixel values in Band 213: [0.2245978  0.12834588 0.12834588 0.08114483 0.12676436]
#
# Band 214 Statistics:
# Min: 0.001497086021117866
# Max: 0.7217839360237122
# Mean: 0.14008276164531708
# Standard Deviation: 0.0606439970433712
# First 5 valid pixel values in Band 214: [0.22623934 0.12989943 0.12989943 0.08287888 0.12939012]
#
# Band 215 Statistics:
# Min: 0.0015336895594373345
# Max: 0.7201926708221436
# Mean: 0.14253608882427216
# Standard Deviation: 0.060419242829084396
# First 5 valid pixel values in Band 215: [0.22755721 0.13293496 0.13293496 0.08506734 0.13264428]
#
# Band 216 Statistics:
# Min: 0.0015735720517113805
# Max: 0.7205618619918823
# Mean: 0.14390893280506134
# Standard Deviation: 0.06005129963159561
# First 5 valid pixel values in Band 216: [0.22804503 0.13435154 0.13435154 0.08654258 0.13465507]
#
# Band 217 Statistics:
# Min: 0.0016775820404291153
# Max: 0.720100998878479
# Mean: 0.1442507952451706
# Standard Deviation: 0.059420883655548096
# First 5 valid pixel values in Band 217: [0.22744416 0.13480008 0.13480008 0.08733845 0.13556069]
#
# Band 218 Statistics:
# Min: 0.0017313746502622962
# Max: 0.7199283242225647
# Mean: 0.1438482403755188
# Standard Deviation: 0.05871357023715973
# First 5 valid pixel values in Band 218: [0.22633028 0.13406362 0.13406362 0.08763413 0.13561276]
#
# Band 219 Statistics:
# Min: 0.0018224159721285105
# Max: 0.7179633378982544
# Mean: 0.14327846467494965
# Standard Deviation: 0.05805981159210205
# First 5 valid pixel values in Band 219: [0.22513735 0.1329101  0.1329101  0.08770201 0.1353681 ]
#
# Band 220 Statistics:
# Min: 0.001833293354138732
# Max: 0.7196622490882874
# Mean: 0.1420922875404358
# Standard Deviation: 0.05725129693746567
# First 5 valid pixel values in Band 220: [0.22323199 0.13137846 0.13137846 0.08737842 0.13462962]
#
# Band 221 Statistics:
# Min: 0.001864784862846136
# Max: 0.7237796187400818
# Mean: 0.1411280483007431
# Standard Deviation: 0.05650975555181503
# First 5 valid pixel values in Band 221: [0.22150841 0.12999922 0.12999922 0.08721159 0.13404539]
#
# Band 222 Statistics:
# Min: 0.0018711186712607741
# Max: 0.7222344279289246
# Mean: 0.14000597596168518
# Standard Deviation: 0.05561695247888565
# First 5 valid pixel values in Band 222: [0.2195142  0.12890813 0.12890813 0.08697227 0.13317625]
#
# Band 223 Statistics:
# Min: 0.0019137043273076415
# Max: 0.7233451008796692
# Mean: 0.13920272886753082
# Standard Deviation: 0.0549938827753067
# First 5 valid pixel values in Band 223: [0.21826728 0.12781419 0.12781419 0.08672671 0.13261384]
#
# Band 224 Statistics:
# Min: 0.0016371245728805661
# Max: 0.7210192084312439
# Mean: 0.14011625945568085
# Standard Deviation: 0.054724156856536865
# First 5 valid pixel values in Band 224: [0.21791288 0.13185836 0.13185836 0.08776665 0.12878463]
#
# Band 225 Statistics:
# Min: 0.001682315138168633
# Max: 0.723161518573761
# Mean: 0.13985289633274078
# Standard Deviation: 0.05423661321401596
# First 5 valid pixel values in Band 225: [0.21726282 0.13138294 0.13138294 0.08799438 0.12778279]
#
# Band 226 Statistics:
# Min: 0.0015345803694799542
# Max: 0.7141993045806885
# Mean: 0.13960100710391998
# Standard Deviation: 0.05359010398387909
# First 5 valid pixel values in Band 226: [0.21736868 0.13055988 0.13055988 0.08893283 0.1312774 ]
#
# Band 227 Statistics:
# Min: 0.0016755961114540696
# Max: 0.7088068723678589
# Mean: 0.13927529752254486
# Standard Deviation: 0.052994582802057266
# First 5 valid pixel values in Band 227: [0.21684888 0.12971519 0.12971519 0.08854836 0.13054016]
#
# Band 228 Statistics:
# Min: 0.0019452859414741397
# Max: 0.7063215374946594
# Mean: 0.139505073428154
# Standard Deviation: 0.05266430974006653
# First 5 valid pixel values in Band 228: [0.21667695 0.12958571 0.12958571 0.08869016 0.131387  ]
#
# Band 229 Statistics:
# Min: 0.001782576204277575
# Max: 0.7021979093551636
# Mean: 0.13910308480262756
# Standard Deviation: 0.05195276811718941
# First 5 valid pixel values in Band 229: [0.21472895 0.1290326  0.1290326  0.08916557 0.13064969]
#
# Band 230 Statistics:
# Min: 0.0015300551895052195
# Max: 0.7034096717834473
# Mean: 0.140143483877182
# Standard Deviation: 0.05189796909689903
# First 5 valid pixel values in Band 230: [0.21592292 0.12975986 0.12975986 0.0902515  0.13259275]
#
# Band 231 Statistics:
# Min: 0.0016960272332653403
# Max: 0.7054851651191711
# Mean: 0.1425793617963791
# Standard Deviation: 0.0523509755730629
# First 5 valid pixel values in Band 231: [0.21979383 0.13273405 0.13273405 0.09212427 0.13411027]
#
# Band 232 Statistics:
# Min: 0.0019360213773325086
# Max: 0.7112997770309448
# Mean: 0.14438088238239288
# Standard Deviation: 0.052590642124414444
# First 5 valid pixel values in Band 232: [0.22156453 0.1330747  0.1330747  0.09354397 0.13485223]
#
# Band 233 Statistics:
# Min: 0.0022398524452000856
# Max: 0.7061699032783508
# Mean: 0.14526690542697906
# Standard Deviation: 0.0523933470249176
# First 5 valid pixel values in Band 233: [0.22332662 0.1343012  0.1343012  0.094717   0.13777027]
#
# Band 234 Statistics:
# Min: 0.0016174174379557371
# Max: 0.7100626230239868
# Mean: 0.14616970717906952
# Standard Deviation: 0.05222174897789955
# First 5 valid pixel values in Band 234: [0.22249916 0.13453992 0.13453992 0.09511425 0.13975137]
#
# Band 235 Statistics:
# Min: 0.0020270859822630882
# Max: 0.7066670060157776
# Mean: 0.1465986967086792
# Standard Deviation: 0.05175672098994255
# First 5 valid pixel values in Band 235: [0.22291781 0.13564439 0.13564439 0.09526081 0.13974188]
#
# Band 236 Statistics:
# Min: 0.0019040904007852077
# Max: 0.7023584246635437
# Mean: 0.14619673788547516
# Standard Deviation: 0.050958771258592606
# First 5 valid pixel values in Band 236: [0.22204602 0.13370487 0.13370487 0.09605744 0.13997896]
#
# Band 237 Statistics:
# Min: 0.0016117631457746029
# Max: 0.6951172947883606
# Mean: 0.14634573459625244
# Standard Deviation: 0.050308145582675934
# First 5 valid pixel values in Band 237: [0.22044247 0.13712193 0.13712193 0.09598845 0.13878766]
#
# Band 238 Statistics:
# Min: 0.0016442523337900639
# Max: 0.7011073231697083
# Mean: 0.146912083029747
# Standard Deviation: 0.05000455677509308
# First 5 valid pixel values in Band 238: [0.2214847  0.13601059 0.13601059 0.09572683 0.14052334]
#
# Band 239 Statistics:
# Min: 0.0020143063738942146
# Max: 0.7031815648078918
# Mean: 0.14722687005996704
# Standard Deviation: 0.04948122799396515
# First 5 valid pixel values in Band 239: [0.22144641 0.13560808 0.13560808 0.09768499 0.14191496]
#
# Band 240 Statistics:
# Min: 0.002189431805163622
# Max: 0.6970146298408508
# Mean: 0.14736196398735046
# Standard Deviation: 0.0487673394382
# First 5 valid pixel values in Band 240: [0.22125813 0.1384715  0.1384715  0.09725293 0.1403301 ]
#
# Band 241 Statistics:
# Min: 0.0020904699340462685
# Max: 0.7003443837165833
# Mean: 0.14727139472961426
# Standard Deviation: 0.047964926809072495
# First 5 valid pixel values in Band 241: [0.22119859 0.13736278 0.13736278 0.09763443 0.14255883]
#
# Band 242 Statistics:
# Min: 0.0024443366564810276
# Max: 0.6913887858390808
# Mean: 0.14628128707408905
# Standard Deviation: 0.046980224549770355
# First 5 valid pixel values in Band 242: [0.21845278 0.13804269 0.13804269 0.0981731  0.13962041]
#
# Band 243 Statistics:
# Min: 0.0017810903955250978
# Max: 0.694566547870636
# Mean: 0.1474473476409912
# Standard Deviation: 0.04730819910764694
# First 5 valid pixel values in Band 243: [0.21957333 0.13745938 0.13745938 0.0987465  0.13969454]
#
# Band 244 Statistics:
# Min: 0.0016370081575587392
# Max: 0.6942318677902222
# Mean: 0.14916884899139404
# Standard Deviation: 0.048330578953027725
# First 5 valid pixel values in Band 244: [0.22247966 0.1391339  0.1391339  0.09934356 0.14105268]
#
# Band 245 Statistics:
# Min: 0.001926170545630157
# Max: 0.6936884522438049
# Mean: 0.14893025159835815
# Standard Deviation: 0.04861734062433243
# First 5 valid pixel values in Band 245: [0.22318105 0.1382265  0.1382265  0.09820797 0.14199957]
#
# Band 246 Statistics:
# Min: 0.0019650005269795656
# Max: 0.6886153221130371
# Mean: 0.14715637266635895
# Standard Deviation: 0.048463623970746994
# First 5 valid pixel values in Band 246: [0.21965376 0.1364448  0.1364448  0.09814759 0.13969259]
#
# Band 247 Statistics:
# Min: 0.001605879981070757
# Max: 0.6878805160522461
# Mean: 0.1437552124261856
# Standard Deviation: 0.047918595373630524
# First 5 valid pixel values in Band 247: [0.21709344 0.1340105  0.1340105  0.09489866 0.13617241]
#
# Band 248 Statistics:
# Min: 0.002113013295456767
# Max: 0.6818088293075562
# Mean: 0.13947449624538422
# Standard Deviation: 0.047209203243255615
# First 5 valid pixel values in Band 248: [0.21147338 0.13022375 0.13022375 0.09259095 0.13249801]
#
# Band 249 Statistics:
# Min: 0.0012621345231309533
# Max: 0.6732075214385986
# Mean: 0.13560977578163147
# Standard Deviation: 0.04647362604737282
# First 5 valid pixel values in Band 249: [0.20813227 0.12721348 0.12721348 0.08904367 0.12746643]
#
# Band 250 Statistics:
# Min: 0.001661478541791439
# Max: 0.6637541055679321
# Mean: 0.13201649487018585
# Standard Deviation: 0.04597703740000725
# First 5 valid pixel values in Band 250: [0.20339413 0.12307202 0.12307202 0.08625937 0.12379677]
#
# Band 251 Statistics:
# Min: 0.0018650945276021957
# Max: 0.6699646711349487
# Mean: 0.1286608874797821
# Standard Deviation: 0.045506369322538376
# First 5 valid pixel values in Band 251: [0.19916879 0.11994566 0.11994566 0.08401288 0.12081698]
#
# Band 252 Statistics:
# Min: 0.0022703383583575487
# Max: 0.6648005843162537
# Mean: 0.1266889125108719
# Standard Deviation: 0.045179583132267
# First 5 valid pixel values in Band 252: [0.19779074 0.1183549  0.1183549  0.08160773 0.11797719]
#
# Band 253 Statistics:
# Min: 0.001941871945746243
# Max: 0.664692759513855
# Mean: 0.1250753253698349
# Standard Deviation: 0.044948674738407135
# First 5 valid pixel values in Band 253: [0.19620687 0.11647233 0.11647233 0.08082099 0.11656992]
#
# Band 254 Statistics:
# Min: 0.0019041845807805657
# Max: 0.668798565864563
# Mean: 0.12309779226779938
# Standard Deviation: 0.04466414824128151
# First 5 valid pixel values in Band 254: [0.19510889 0.1137813  0.1137813  0.07941475 0.11600621]
#
# Band 255 Statistics:
# Min: 0.0015753575135022402
# Max: 0.6636752486228943
# Mean: 0.12000986933708191
# Standard Deviation: 0.04407216235995293
# First 5 valid pixel values in Band 255: [0.19180118 0.11262131 0.11262131 0.07636896 0.11039186]
#
# Band 256 Statistics:
# Min: 0.0016100154025480151
# Max: 0.6649894714355469
# Mean: 0.11772748082876205
# Standard Deviation: 0.0438479445874691
# First 5 valid pixel values in Band 256: [0.18999124 0.11226737 0.11226737 0.07411214 0.10760649]
#
# Band 257 Statistics:
# Min: 0.0013843380147591233
# Max: 0.6681756377220154
# Mean: 0.11584223061800003
# Standard Deviation: 0.04327429458498955
# First 5 valid pixel values in Band 257: [0.18971063 0.10701236 0.10701236 0.07336866 0.11056387]
#
# Band 258 Statistics:
# Min: 0.0014200402656570077
# Max: 0.661042332649231
# Mean: 0.11438796669244766
# Standard Deviation: 0.042640697211027145
# First 5 valid pixel values in Band 258: [0.18454708 0.11097101 0.11097101 0.07300323 0.10389918]
#
# Band 259 Statistics:
# Min: 0.00129887112416327
# Max: 0.6655978560447693
# Mean: 0.11320328712463379
# Standard Deviation: 0.04250425845384598
# First 5 valid pixel values in Band 259: [0.18492404 0.10848571 0.10848571 0.07177489 0.10304034]
#
# Band 260 Statistics:
# Min: 0.0012334210332483053
# Max: 0.6665270924568176
# Mean: 0.11179277300834656
# Standard Deviation: 0.04217764735221863
# First 5 valid pixel values in Band 260: [0.18593834 0.10451952 0.10451952 0.07089633 0.104109  ]
#
# Band 261 Statistics:
# Min: 0.001236675656400621
# Max: 0.6709414720535278
# Mean: 0.10930682718753815
# Standard Deviation: 0.041513603180646896
# First 5 valid pixel values in Band 261: [0.17930177 0.10512859 0.10512859 0.06774406 0.10089662]
#
# Band 262 Statistics:
# Min: 0.0011493313359096646
# Max: 0.6529350280761719
# Mean: 0.1079002097249031
# Standard Deviation: 0.041203130036592484
# First 5 valid pixel values in Band 262: [0.17828117 0.10376688 0.10376688 0.0681893  0.0973116 ]
#
# Band 263 Statistics:
# Min: 0.0011469456367194653
# Max: 0.670655369758606
# Mean: 0.10864262282848358
# Standard Deviation: 0.04189665615558624
# First 5 valid pixel values in Band 263: [0.18009685 0.10522144 0.10522144 0.06667459 0.09712847]
#
# Band 264 Statistics:
# Min: 0.0011501377448439598
# Max: 0.6729068756103516
# Mean: 0.1081949770450592
# Standard Deviation: 0.04197283834218979
# First 5 valid pixel values in Band 264: [0.18129595 0.10120858 0.10120858 0.06700493 0.10251732]
#
# Band 265 Statistics:
# Min: 0.0011410065926611423
# Max: 0.664156436920166
# Mean: 0.10707398504018784
# Standard Deviation: 0.041742656379938126
# First 5 valid pixel values in Band 265: [0.17853332 0.1038296  0.1038296  0.06611682 0.09749016]
#
# Band 266 Statistics:
# Min: 0.0011271877447143197
# Max: 0.6682572960853577
# Mean: 0.10607459396123886
# Standard Deviation: 0.041629206389188766
# First 5 valid pixel values in Band 266: [0.1770239  0.10190298 0.10190298 0.06652876 0.09828597]
#
# Band 267 Statistics:
# Min: 0.0011483932612463832
# Max: 0.6616573333740234
# Mean: 0.10528898984193802
# Standard Deviation: 0.04179611802101135
# First 5 valid pixel values in Band 267: [0.17808719 0.1036186  0.1036186  0.06630948 0.09345457]
#
# Band 268 Statistics:
# Min: 0.0010033904109150171
# Max: 0.6707431077957153
# Mean: 0.10391762852668762
# Standard Deviation: 0.04190876707434654
# First 5 valid pixel values in Band 268: [0.17496954 0.10165614 0.10165614 0.06343545 0.09380582]
#
# Band 269 Statistics:
# Min: 0.00101902661845088
# Max: 0.6802824139595032
# Mean: 0.1031392440199852
# Standard Deviation: 0.04185033589601517
# First 5 valid pixel values in Band 269: [0.17604086 0.09674165 0.09674165 0.06198157 0.09611657]
#
# Band 270 Statistics:
# Min: 0.0008119751582853496
# Max: 0.6701963543891907
# Mean: 0.10268878936767578
# Standard Deviation: 0.041815150529146194
# First 5 valid pixel values in Band 270: [0.17321624 0.097123   0.097123   0.06398895 0.0967757 ]
#
# Band 271 Statistics:
# Min: 0.0009577698656357825
# Max: 0.6402291059494019
# Mean: 0.10091353207826614
# Standard Deviation: 0.041157715022563934
# First 5 valid pixel values in Band 271: [0.16973837 0.09982827 0.09982827 0.06362443 0.08940791]
#
# Band 272 Statistics:
# Min: 0.0008703662897460163
# Max: 0.6710513234138489
# Mean: 0.09771494567394257
# Standard Deviation: 0.04081021994352341
# First 5 valid pixel values in Band 272: [0.16949818 0.09593702 0.09593702 0.06025061 0.08606852]
#
# Band 273 Statistics:
# Min: 0.0008699770551174879
# Max: 0.6577638387680054
# Mean: 0.09645909816026688
# Standard Deviation: 0.04040560871362686
# First 5 valid pixel values in Band 273: [0.16620344 0.09194673 0.09194673 0.05901248 0.09145735]
#
# Band 274 Statistics:
# Min: 0.0008721300400793552
# Max: 0.6820152401924133
# Mean: 0.0929352417588234
# Standard Deviation: 0.0393318347632885
# First 5 valid pixel values in Band 274: [0.16080345 0.09112065 0.09112065 0.05818184 0.08443144]
#
# Band 275 Statistics:
# Min: 0.0008771939319558442
# Max: 0.6291670203208923
# Mean: 0.09394359588623047
# Standard Deviation: 0.03936651349067688
# First 5 valid pixel values in Band 275: [0.16352886 0.08856019 0.08856019 0.05863874 0.09139886]
#
# Band 276 Statistics:
# Min: 0.0008655778365209699
# Max: 0.6389167308807373
# Mean: 0.08822233229875565
# Standard Deviation: 0.03823387622833252
# First 5 valid pixel values in Band 276: [0.1536301  0.08857859 0.08857859 0.05583668 0.07075299]
#
# Band 277 Statistics:
# Min: 0.0008689196547493339
# Max: 0.6464796662330627
# Mean: 0.08616430312395096
# Standard Deviation: 0.037501852959394455
# First 5 valid pixel values in Band 277: [0.15363897 0.08326142 0.08326142 0.05236994 0.07996593]

# %% [markdown]
# ### This code cell calculates and adds indices to each image in the folder

# %%
# Define output path
added_indices = r'C:\Users\SkosanaT\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\13092014_emit\AddedIndices'

# Define custom band names for the added indices
band_names = ['GI', 'IRG', 'NGRDI', 'VARI', 'VDVI']

try:
    # Open the image
    with rasterio.open(mosaic_file_path) as img:
        # Read all bands
        full_img = img.read()

        # Extract bands
        red_band = full_img[35, :, :]
        green_band = full_img[20, :, :]
        blue_band = full_img[10, :, :]

        # Calculate vegetation indices
        # 1) Greenness Index (GI) (Green/Red)
        GI = np.divide(green_band, red_band, out=np.full_like(green_band, np.nan, dtype=float), where=red_band != 0)

        # 2) IRG (Red-Green)
        IRG = red_band - green_band

        # 3) NGRDI (Green-Red)/(Green + Red)
        NGRDI = np.divide((green_band - red_band),
                          (green_band + red_band),
                          where=(green_band + red_band) != 0)

        # 4) Calculate VARI (Green-Red)/(Green+Red+Blue)
        VARI = np.divide((green_band - red_band),
                         (green_band + red_band + blue_band),
                         out=np.full_like(green_band, np.nan, dtype=float),  # Specify dtype=float
                         where=(green_band + red_band + blue_band) != 0)

        # 5) VDVI (2* Green-Red-Blue)/(2*Green+Red+Blue)
        VDVI = np.divide((2 * green_band - red_band - blue_band),
                         (2 * green_band + red_band + blue_band),
                         out=np.full_like(green_band, np.nan, dtype=float),  # Specify dtype=float
                         where=(2 * green_band + red_band + blue_band) != 0)

        # Add the calculated indices as new bands to the image
        indices = np.stack([GI, IRG, NGRDI, VARI, VDVI], axis=0)
        updated_img = np.concatenate((full_img, indices), axis=0)

        # Update band names in metadata profile
        profile = img.profile.copy()  # Copy the profile to avoid modifying the original
        if 'descriptions' not in profile:
            profile['descriptions'] = [''] * img.count
        band_names_all = profile['descriptions'] + band_names
        profile.update(count=profile['count'] + len(indices), dtype='float32', descriptions=band_names_all)

        # Write the modified image array to a new raster file
        with rasterio.open(added_indices, 'w', **profile) as dst:
            dst.write(updated_img.astype('float32'))  # Convert to float32 before writing

        print(f"Indices added to the image and saved as {added_indices}")

except Exception as e:
    print(f"Error processing the image: {e}")
# Out:
# Indices added to the image and saved as C:\Users\User\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\AddedIndices\emit_added_indices.tif

# %% [markdown]
# ### This cell prints out band numbers of each image to see if they were added as bands

# %%
# Open the image
with rasterio.open(added_indices) as img:
    # Print the number of bands
    print(f"Image '{added_indices}' has {img.count} bands.")
# Out:
# Image 'C:\Users\User\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\AddedIndices\emit_added_indices.tif' has 282 bands.

# %% [markdown]
# ### This code cell extracts pixel values

# %%
# Define paths
pntsshp_path = r'C:\Users\SkosanaT\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\Train_Val\Training_data\train_shapefile.shp'

# Open shapefile and extract points' coordinates [0]= x coordinate, [1]= y coordinate and attributes
with fiona.open(pntsshp_path, 'r') as shapefile:
    points = [[(point['geometry']['coordinates'][0], point['geometry']['coordinates'][1]),
               (int(point['properties']['ID']), point['properties']['Val_id']),
               (point['properties']['X'], point['properties']['Y'])] for point in shapefile]

# Initialize dictionary to store band pixel values associated with each point
point_pixel_values = {}

# Open the raster image
with rasterio.open(added_indices) as src:
    imagename = os.path.splitext(os.path.basename(added_indices))[0]  # Remove the file extension
    
    # Iterate over each band in the image
    for band in range(1, src.count + 1):
        
        # Iterate over each point and extract pixel values
        for point in points:
            row, col = src.index(point[0][0], point[0][1])  # Find the point within the raster image
            values = src.read(band, window=((row, row+1), (col, col+1)))  # Read the band values

            if values.size != 0:  # Check if bands are valid/not empty
                # Prepare key for the current point
                point_key = f"Point_id: {point[1][1]}, X: {point[2][0]}, Y: {point[2][1]}, Class_ID: {point[1][0]}"
                if point_key not in point_pixel_values:
                    point_pixel_values[point_key] = {}

                # Add pixel values to the dictionary
                point_pixel_values[point_key][f'{imagename}_Band_{band}'] = values[0][0]

# Print point_pixel_values
for point_key, pixel_values in point_pixel_values.items():
    print(f"Point: {point_key}, Pixel Values: {pixel_values}")
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ### This cell changes point_pixel_value dictionary to a dataframe

# %%
# Create a list of dictionaries for DataFrame creation
data_list = []

for point_key, pixel_values in point_pixel_values.items():
    data_dict = {}
    # Extracting Point ID, X, Y, and Class ID from point_key
    point_id = point_key.split(',')[0].split(':')[1].strip()  
    x_coord = point_key.split(',')[1].split(':')[1].strip()
    y_coord = point_key.split(',')[2].split(':')[1].strip()
    class_id = point_key.split(',')[3].split(':')[1].strip()
    
    # Add extracted information as separate columns
    data_dict['Point'] = point_id
    data_dict['X'] = x_coord
    data_dict['Y'] = y_coord
    data_dict['Class_ID'] = class_id
    
    # Add band pixel values as columns
    data_dict.update(pixel_values)

    data_list.append(data_dict)

# Create DataFrame from list of dictionaries
pixelvalues_df = pd.DataFrame(data_list)

# Print the DataFrame
print(pixelvalues_df)

# Save the DataFrame to a CSV file
# Define the CSV file path
csv_file_path = r'C:\Users\User\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\Band_values\pixel_values.csv'

# Save the DataFrame to a CSV file
pixelvalues_df.to_csv(csv_file_path, index=False)

print(f'DataFrame successfully saved to {csv_file_path}')
# Out:
#         Point            X             Y Class_ID  emit_added_indices2_Band_1  \
# 0     VAL_214  702104.9463  6588745.0354        6                    0.020354
# 1    VAL_2226  708475.5249  6590234.8424        3                    0.020397
# 2    VAL_3294  688484.9531  6575784.3999        8                    0.033354
# 3     VAL_205   695464.998  6568135.0354        2                    0.014485
# 4     VAL_246  696218.0801  6598498.9627        5                    0.028165
# ..        ...          ...           ...      ...                         ...
# 193  VAL_2075  694724.7618  6567514.4758        2                    0.016504
# 194   VAL_201  694615.3231  6567555.1575        2                    0.014737
# 195   VAL_125  700894.8945  6577725.0944        4                    0.040150
# 196  VAL_2062  679634.4435  6575755.0431        5                    0.024881
# 197  VAL_2889  695455.1923  6568115.2588        2                    0.017829
#
#      emit_added_indices2_Band_2  emit_added_indices2_Band_3  \
# 0                      0.021425                    0.022625
# 1                      0.021344                    0.022466
# 2                      0.035754                    0.038216
# 3                      0.015052                    0.015846
# 4                      0.029902                    0.031818
# ..                          ...                         ...
# 193                    0.017319                    0.018289
# 194                    0.015392                    0.016225
# 195                    0.045189                    0.049475
# 196                    0.026765                    0.028690
# 197                    0.018645                    0.019685
#
#      emit_added_indices2_Band_4  emit_added_indices2_Band_5  \
# 0                      0.023896                    0.025066
# 1                      0.023657                    0.024733
# 2                      0.040644                    0.042808
# 3                      0.016783                    0.017636
# 4                      0.033803                    0.035577
# ..                          ...                         ...
# 193                    0.019363                    0.020355
# 194                    0.017151                    0.018009
# 195                    0.052907                    0.055094
# 196                    0.030654                    0.032492
# 197                    0.020882                    0.021983
#
#      emit_added_indices2_Band_6  ...  emit_added_indices2_Band_273  \
# 0                      0.026269  ...                      0.044047
# 1                      0.025847  ...                      0.042299
# 2                      0.044887  ...                      0.099636
# 3                      0.018553  ...                      0.025026
# 4                      0.037388  ...                      0.077773
# ..                          ...  ...                           ...
# 193                    0.021400  ...                      0.033564
# 194                    0.018919  ...                      0.023776
# 195                    0.058361  ...                      0.151299
# 196                    0.034328  ...                      0.072517
# 197                    0.023145  ...                      0.037273
#
#      emit_added_indices2_Band_274  emit_added_indices2_Band_275  \
# 0                        0.042877                      0.044777
# 1                        0.038795                      0.040291
# 2                        0.095515                      0.093780
# 3                        0.023664                      0.027092
# 4                        0.073051                      0.073982
# ..                            ...                           ...
# 193                      0.031596                      0.031277
# 194                      0.021607                      0.023360
# 195                      0.148495                      0.151902
# 196                      0.068300                      0.066033
# 197                      0.036309                      0.039295
#
#      emit_added_indices2_Band_276  emit_added_indices2_Band_277  \
# 0                        0.041388                      0.043680
# 1                        0.036715                      0.035636
# 2                        0.091622                      0.087360
# 3                        0.024329                      0.022960
# 4                        0.073099                      0.067062
# ..                            ...                           ...
# 193                      0.028253                      0.028244
# 194                      0.021546                      0.020256
# 195                      0.146742                      0.143603
# 196                      0.064365                      0.063838
# 197                      0.037694                      0.034476
#
#      emit_added_indices2_Band_278  emit_added_indices2_Band_279  \
# 0                        1.052633                     -0.001071
# 1                        1.046457                     -0.000948
# 2                        1.071956                     -0.002400
# 3                        1.039147                     -0.000567
# 4                        1.061669                     -0.001737
# ..                            ...                           ...
# 193                      1.049361                     -0.000815
# 194                      1.044455                     -0.000655
# 195                      1.125512                     -0.005039
# 196                      1.075723                     -0.001884
# 197                      1.045785                     -0.000816
#
#      emit_added_indices2_Band_280  emit_added_indices2_Band_281  \
# 0                        0.025642                      0.016634
# 1                        0.022701                      0.014758
# 2                        0.034728                      0.022362
# 3                        0.019198                      0.012495
# 4                        0.029912                      0.019324
# ..                            ...                           ...
# 193                      0.024086                      0.015633
# 194                      0.021744                      0.014133
# 195                      0.059050                      0.037379
# 196                      0.036480                      0.023452
# 197                      0.022380                      0.014535
#
#      emit_added_indices2_Band_282
# 0                       -0.001503
# 1                       -0.002034
# 2                       -0.000430
# 3                       -0.003767
# 4                       -0.001497
# ..                            ...
# 193                     -0.002247
# 194                     -0.002871
# 195                      0.004185
# 196                     -0.000387
# 197                     -0.002987
#
# [198 rows x 286 columns]
# DataFrame successfully saved to C:\Users\User\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\Band_values\pixel_values.csv

# %% [markdown]
# ### This cell block trains the random forest classifier

# %%
# Define features 
# Find the index of the last non-band column
last_non_band_index = pixelvalues_df.columns.tolist().index('Class_ID')  #

# Select columns starting from the column following the last non-band column
#These columns are the band features used in the classification
features = pixelvalues_df.iloc[:, last_non_band_index + 1:]
#print(features)

# Define target (Class ID column)
target = pixelvalues_df['Class_ID']

# Convert features and target columns to arrays
features_array = features.values
target_array = target.values

# Train the classifier using RandomForest with 500 trees
classifier = RandomForestClassifier(n_estimators=500)
classifier.fit(features_array, target_array)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
# Define features 
# Find the index of the last non-band column
last_non_band_index = pixelvalues_df.columns.tolist().index('Class_ID')  #

# Select columns starting from the column following the last non-band column
#These columns are the band features used in the classification
features = pixelvalues_df.iloc[:, last_non_band_index + 1:]
#print(features)

# Define target (Class ID column)
target = pixelvalues_df['Class_ID']

# Convert features and target columns to arrays
features_array = features.values
target_array = target.values

# Train the classifier using RandomForest with 500 trees
classifier = RandomForestClassifier(n_estimators=500)
classifier.fit(features_array, target_array)

# Print information about features_array
print("Features Array:")
print(f"Shape: {features_array.shape}")
print(f"Data Type: {features_array.dtype}")
print("First 5 rows:\n", features_array[:5])

# Print information about target_array
print("\nTarget Array:")
print(f"Shape: {target_array.shape}")
print(f"Data Type: {target_array.dtype}")
print("First 5 values:\n", target_array[:5])


# Train the classifier using RandomForest with 500 trees
classifier = RandomForestClassifier(n_estimators=500)
classifier.fit(features_array, target_array)

# %% [markdown]
# ### This cell block performs the classification on each image in the folder using the trained classifer in the previous cell

# %%
# Define the directory where you want to save the classified images
output_folder_classified = r'C:\Users\User\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\Classified'
output_folder= r'C:\Users\User\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\AddedIndices'
os.makedirs(output_folder, exist_ok=True)

# Iterate over all .tif or .TIF files in the specified directory
for filename in os.listdir(output_folder):
    if filename.lower().endswith('.tif') or filename.endswith('.TIF'):
        image_path = os.path.join(output_folder, filename)
        
        # Open the image using rasterio
        with rasterio.open(image_path) as src:
            # Get the shape of the image
            rows, cols = src.height, src.width
        
            # Define batch size (adjust as needed based on memory constraints)
            batch_size = 1000  # You can adjust this value
        
            # Initialize the classification result array for the entire image
            classification_result = np.zeros((rows, cols), dtype=np.uint8)
        
            # Iterate over the image in batches
            for row_start in range(0, rows, batch_size):
                for col_start in range(0, cols, batch_size):
                    row_end = min(row_start + batch_size, rows)
                    col_end = min(col_start + batch_size, cols)
        
                    # Read the batch of bands
                    bands = [src.read(band_idx, window=((row_start, row_end), (col_start, col_end))) 
                             for band_idx in range(1, src.count + 1)]
        
                    # Stack the bands into a single array
                    stacked_bands = np.stack(bands, axis=-1)
        
                    # Reshape the array to 2D (rows, columns) for classification
                    reshaped_bands = stacked_bands.reshape(-1, src.count)
        
                    # Predict using the trained classifier (replace this with your classifier)
                    predicted_labels = classifier.predict(reshaped_bands)
        
                    # Create a temporary result array for this batch
                    batch_result = predicted_labels.reshape(row_end - row_start, col_end - col_start)
        
                    # Write the batch result to the corresponding window in the full classification result array
                    classification_result[row_start:row_end, col_start:col_end] = batch_result
        
            # Construct the output file path
            output_filename = 'emit_classified20240827.tif'
            output_path = os.path.join(output_folder_classified, output_filename)
        
            # Prepare metadata for the classified image
            meta = src.meta.copy()
            meta.update({
                'driver': 'GTiff',
                'dtype': 'uint8',  # Ensure data type is appropriate for classification results
                'count': 1,  # Single band
                'compress': 'lzw',  # Compression method (Lempel-Ziv-Welch)
                'crs': src.crs,  # Use the same CRS as the input raster
                'transform': src.transform,  # Use the same transform as the input raster
            })
        
            # Write the full classified image to a new GeoTIFF file
            with rasterio.open(output_path, 'w', **meta) as dst:
                dst.write(classification_result.astype('uint8'), 1)
        
        print("Classification completed and classified image saved successfully!")
# Out:
# Classification completed and classified image saved successfully!
