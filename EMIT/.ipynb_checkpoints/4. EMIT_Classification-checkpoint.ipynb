# %% [markdown]
# ## Import packages

# %%
# Import packages
import argparse
import os
#import geoviews
import warnings
import rasterio as rio
import rasterio
import pandas as pd
import fiona
import matplotlib.pyplot as plt
import numpy.ma as ma
import numpy as np
import xarray as xr
import rioxarray as rxr
from shapely.geometry import mapping, box
import geopandas as gpd
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from rasterio.features import rasterize
from rasterio.transform import from_origin
from rasterio.mask import mask

warnings.simplefilter('ignore')

# %% [markdown]
# ### Code loops through the folder and prints out metadata

# %%
# Define the path to the specific TIFF file
mosaic_file_path = r'C:\Users\SkosanaT\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\04092024_EMIT\Projected\11092024_EMIT_PROJECTED.tif'

print(f"\nProcessing file: {mosaic_file_path}")

# Open the image
with rasterio.open(mosaic_file_path) as img:
    # Print the original image metadata
    metadata = img.meta
    print("Metadata:", metadata)
    
    # Get NoData value
    nodata = img.nodatavals[0] if img.nodatavals else None
    if nodata is not None:
        print(f"NoData value: {nodata}")
    
    # Loop through each band and print its statistics
    for band in range(1, img.count + 1):
        band_data = img.read(band)
        
        # Mask NoData values
        if nodata is not None:
            band_data = np.ma.masked_equal(band_data, nodata)
        
        # Calculate statistics ignoring NaN values
        valid_data = band_data[np.isfinite(band_data)]
        
        if valid_data.size > 0:
            print(f"\nBand {band} Statistics:")
            print(f"Min: {valid_data.min()}")
            print(f"Max: {valid_data.max()}")
            print(f"Mean: {valid_data.mean()}")
            print(f"Standard Deviation: {valid_data.std()}")
            print(f"First 5 valid pixel values in Band {band}: {valid_data.flatten()[:5]}")
        else:
            print(f"\nBand {band} contains only NaN values.")
# Out:
# Processing file: C:\Users\SkosanaT\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\04092024_EMIT\Projected\11092024_EMIT_PROJECTED.tif
# Metadata: {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 3.3999999521443642e+38, 'width': 690, 'height': 738, 'count': 239, 'crs': CRS.from_epsg(32735), 'transform': Affine(56.83226354475221, 0.0, 671653.2808171478,
#        0.0, -56.83226354475206, 6605159.773967972)}
# NoData value: 3.3999999521443642e+38
#
# Band 1 Statistics:
# Min: 0.0006547213415615261
# Max: 0.2552863657474518
# Mean: 0.027963803071433712
# Standard Deviation: 0.00796014054386021
# First 5 valid pixel values in Band 1: [-- -- -- -- --]
#
# Band 2 Statistics:
# Min: 0.0006817427929490805
# Max: 0.29830697178840637
# Mean: 0.0305522966987486
# Standard Deviation: 0.009243662746829258
# First 5 valid pixel values in Band 2: [-- -- -- -- --]
#
# Band 3 Statistics:
# Min: 0.0007240716367959976
# Max: 0.3201538920402527
# Mean: 0.032909052670409555
# Standard Deviation: 0.010257189430432254
# First 5 valid pixel values in Band 3: [-- -- -- -- --]
#
# Band 4 Statistics:
# Min: 0.00077319290721789
# Max: 0.33024656772613525
# Mean: 0.03453502004478103
# Standard Deviation: 0.010588142650338998
# First 5 valid pixel values in Band 4: [-- -- -- -- --]
#
# Band 5 Statistics:
# Min: 0.0008176998235285282
# Max: 0.33906280994415283
# Mean: 0.036367540565135574
# Standard Deviation: 0.011217604624478794
# First 5 valid pixel values in Band 5: [-- -- -- -- --]
#
# Band 6 Statistics:
# Min: 0.0008634019759483635
# Max: 0.3467486500740051
# Mean: 0.03816628893918829
# Standard Deviation: 0.011797308824042457
# First 5 valid pixel values in Band 6: [-- -- -- -- --]
#
# Band 7 Statistics:
# Min: 0.0009063085890375078
# Max: 0.353407084941864
# Mean: 0.03972345882047485
# Standard Deviation: 0.012187237242543237
# First 5 valid pixel values in Band 7: [-- -- -- -- --]
#
# Band 8 Statistics:
# Min: 0.0009394632652401924
# Max: 0.3580584228038788
# Mean: 0.04104781457902747
# Standard Deviation: 0.012488030933315606
# First 5 valid pixel values in Band 8: [-- -- -- -- --]
#
# Band 9 Statistics:
# Min: 0.0009673390886746347
# Max: 0.3635750114917755
# Mean: 0.04198149312089336
# Standard Deviation: 0.012568502616362894
# First 5 valid pixel values in Band 9: [-- -- -- -- --]
#
# Band 10 Statistics:
# Min: 0.000989900203421712
# Max: 0.3672354221343994
# Mean: 0.04299883484488591
# Standard Deviation: 0.012795850060766464
# First 5 valid pixel values in Band 10: [-- -- -- -- --]
#
# Band 11 Statistics:
# Min: 0.0037551745772361755
# Max: 0.3726010024547577
# Mean: 0.044293266425280975
# Standard Deviation: 0.013085711533672589
# First 5 valid pixel values in Band 11: [-- -- -- -- --]
#
# Band 12 Statistics:
# Min: 0.0031000617891550064
# Max: 0.3765912652015686
# Mean: 0.044888612970560716
# Standard Deviation: 0.01361413779774623
# First 5 valid pixel values in Band 12: [-- -- -- -- --]
#
# Band 13 Statistics:
# Min: 0.0035396269522607327
# Max: 0.38353481888771057
# Mean: 0.04726315073238321
# Standard Deviation: 0.014234019609067608
# First 5 valid pixel values in Band 13: [-- -- -- -- --]
#
# Band 14 Statistics:
# Min: 0.0040362924337387085
# Max: 0.38837841153144836
# Mean: 0.05005213635335369
# Standard Deviation: 0.01480933802086552
# First 5 valid pixel values in Band 14: [-- -- -- -- --]
#
# Band 15 Statistics:
# Min: 0.004554539918899536
# Max: 0.39367032051086426
# Mean: 0.05381042434653628
# Standard Deviation: 0.015253713048073521
# First 5 valid pixel values in Band 15: [-- -- -- -- --]
#
# Band 16 Statistics:
# Min: 0.004611171782016754
# Max: 0.3955373167991638
# Mean: 0.05831926696126518
# Standard Deviation: 0.015503558024992871
# First 5 valid pixel values in Band 16: [-- -- -- -- --]
#
# Band 17 Statistics:
# Min: 0.0051935710944235325
# Max: 0.4007338583469391
# Mean: 0.0633683835834593
# Standard Deviation: 0.01584222992541518
# First 5 valid pixel values in Band 17: [-- -- -- -- --]
#
# Band 18 Statistics:
# Min: 0.00545897800475359
# Max: 0.4050530195236206
# Mean: 0.06773799241138909
# Standard Deviation: 0.016354741574652155
# First 5 valid pixel values in Band 18: [-- -- -- -- --]
#
# Band 19 Statistics:
# Min: 0.005608438979834318
# Max: 0.4082067906856537
# Mean: 0.07072784759282681
# Standard Deviation: 0.016959289738335232
# First 5 valid pixel values in Band 19: [-- -- -- -- --]
#
# Band 20 Statistics:
# Min: 0.005624921526759863
# Max: 0.4116182327270508
# Mean: 0.07354680157530513
# Standard Deviation: 0.01767084723948095
# First 5 valid pixel values in Band 20: [-- -- -- -- --]
#
# Band 21 Statistics:
# Min: 0.0055076610296964645
# Max: 0.4165678918361664
# Mean: 0.07535018920113933
# Standard Deviation: 0.018533506302785736
# First 5 valid pixel values in Band 21: [-- -- -- -- --]
#
# Band 22 Statistics:
# Min: 0.004482707940042019
# Max: 0.41568148136138916
# Mean: 0.07527263537135864
# Standard Deviation: 0.01953208186160703
# First 5 valid pixel values in Band 22: [-- -- -- -- --]
#
# Band 23 Statistics:
# Min: 0.0038153405766934156
# Max: 0.4160959720611572
# Mean: 0.0743103139684939
# Standard Deviation: 0.020518455831044197
# First 5 valid pixel values in Band 23: [-- -- -- -- --]
#
# Band 24 Statistics:
# Min: 0.0033816942013800144
# Max: 0.41784539818763733
# Mean: 0.07430611253354721
# Standard Deviation: 0.021497164896028546
# First 5 valid pixel values in Band 24: [-- -- -- -- --]
#
# Band 25 Statistics:
# Min: 0.0030769880395382643
# Max: 0.41848140954971313
# Mean: 0.07449117650461178
# Standard Deviation: 0.02233587844955353
# First 5 valid pixel values in Band 25: [-- -- -- -- --]
#
# Band 26 Statistics:
# Min: 0.0027494861278682947
# Max: 0.419315367937088
# Mean: 0.0754131303919754
# Standard Deviation: 0.0231156264121931
# First 5 valid pixel values in Band 26: [-- -- -- -- --]
#
# Band 27 Statistics:
# Min: 0.0030160557944327593
# Max: 0.4185260832309723
# Mean: 0.07640043547110055
# Standard Deviation: 0.023784055528007768
# First 5 valid pixel values in Band 27: [-- -- -- -- --]
#
# Band 28 Statistics:
# Min: 0.0029439504723995924
# Max: 0.41976386308670044
# Mean: 0.07649076230578605
# Standard Deviation: 0.024434538187296552
# First 5 valid pixel values in Band 28: [-- -- -- -- --]
#
# Band 29 Statistics:
# Min: 0.00216340902261436
# Max: 0.42195770144462585
# Mean: 0.0761196462632775
# Standard Deviation: 0.02506550298039647
# First 5 valid pixel values in Band 29: [-- -- -- -- --]
#
# Band 30 Statistics:
# Min: 0.0018151614349335432
# Max: 0.4207969605922699
# Mean: 0.07638489899846788
# Standard Deviation: 0.025598505456420565
# First 5 valid pixel values in Band 30: [-- -- -- -- --]
#
# Band 31 Statistics:
# Min: 0.0016661167610436678
# Max: 0.42027193307876587
# Mean: 0.07735114066950469
# Standard Deviation: 0.026158891663638672
# First 5 valid pixel values in Band 31: [-- -- -- -- --]
#
# Band 32 Statistics:
# Min: 0.001354128704406321
# Max: 0.41932180523872375
# Mean: 0.07736876580960607
# Standard Deviation: 0.026807875447419235
# First 5 valid pixel values in Band 32: [-- -- -- -- --]
#
# Band 33 Statistics:
# Min: 0.00120296620298177
# Max: 0.419772207736969
# Mean: 0.07643169318310351
# Standard Deviation: 0.02732146291430126
# First 5 valid pixel values in Band 33: [-- -- -- -- --]
#
# Band 34 Statistics:
# Min: 0.0009708130965009332
# Max: 0.41937056183815
# Mean: 0.07602666842757401
# Standard Deviation: 0.02780885387350225
# First 5 valid pixel values in Band 34: [-- -- -- -- --]
#
# Band 35 Statistics:
# Min: 0.0009540224564261734
# Max: 0.4195248782634735
# Mean: 0.07488623188964638
# Standard Deviation: 0.028120454314619295
# First 5 valid pixel values in Band 35: [-- -- -- -- --]
#
# Band 36 Statistics:
# Min: 0.0009770970791578293
# Max: 0.42059627175331116
# Mean: 0.07523072545526524
# Standard Deviation: 0.028805712358504473
# First 5 valid pixel values in Band 36: [-- -- -- -- --]
#
# Band 37 Statistics:
# Min: 0.0008807691629044712
# Max: 0.4234863519668579
# Mean: 0.07599520184882418
# Standard Deviation: 0.029244531356023003
# First 5 valid pixel values in Band 37: [-- -- -- -- --]
#
# Band 38 Statistics:
# Min: 0.0012012571096420288
# Max: 0.4212872385978699
# Mean: 0.0791702736347184
# Standard Deviation: 0.029614804380406215
# First 5 valid pixel values in Band 38: [-- -- -- -- --]
#
# Band 39 Statistics:
# Min: 0.0012245269026607275
# Max: 0.4257127642631531
# Mean: 0.08911302165273365
# Standard Deviation: 0.02975268264357381
# First 5 valid pixel values in Band 39: [-- -- -- -- --]
#
# Band 40 Statistics:
# Min: 0.0028960632625967264
# Max: 0.43236222863197327
# Mean: 0.10633786863374156
# Standard Deviation: 0.029372565019778054
# First 5 valid pixel values in Band 40: [-- -- -- -- --]
#
# Band 41 Statistics:
# Min: 0.004623986780643463
# Max: 0.4335542321205139
# Mean: 0.12529953098168656
# Standard Deviation: 0.028248363373564157
# First 5 valid pixel values in Band 41: [-- -- -- -- --]
#
# Band 42 Statistics:
# Min: 0.0066731213591992855
# Max: 0.43604418635368347
# Mean: 0.1443354052914623
# Standard Deviation: 0.02720364352648242
# First 5 valid pixel values in Band 42: [-- -- -- -- --]
#
# Band 43 Statistics:
# Min: 0.008679649792611599
# Max: 0.43658486008644104
# Mean: 0.16429447062241007
# Standard Deviation: 0.02628134435297289
# First 5 valid pixel values in Band 43: [-- -- -- -- --]
#
# Band 44 Statistics:
# Min: 0.011563179083168507
# Max: 0.43796640634536743
# Mean: 0.18236828862942284
# Standard Deviation: 0.026729895955430197
# First 5 valid pixel values in Band 44: [-- -- -- -- --]
#
# Band 45 Statistics:
# Min: 0.014590670354664326
# Max: 0.4391724467277527
# Mean: 0.19690001580960606
# Standard Deviation: 0.028511110139699057
# First 5 valid pixel values in Band 45: [-- -- -- -- --]
#
# Band 46 Statistics:
# Min: 0.014201880432665348
# Max: 0.44003114104270935
# Mean: 0.2081551539315791
# Standard Deviation: 0.030306949271656256
# First 5 valid pixel values in Band 46: [-- -- -- -- --]
#
# Band 47 Statistics:
# Min: 0.014756563119590282
# Max: 0.43995657563209534
# Mean: 0.21326331155977832
# Standard Deviation: 0.03159208832224395
# First 5 valid pixel values in Band 47: [-- -- -- -- --]
#
# Band 48 Statistics:
# Min: 0.01503814198076725
# Max: 0.44244107604026794
# Mean: 0.21719633667005994
# Standard Deviation: 0.0325277952302145
# First 5 valid pixel values in Band 48: [-- -- -- -- --]
#
# Band 49 Statistics:
# Min: 0.01526310108602047
# Max: 0.44008851051330566
# Mean: 0.22024489144070497
# Standard Deviation: 0.033000182039785324
# First 5 valid pixel values in Band 49: [-- -- -- -- --]
#
# Band 50 Statistics:
# Min: 0.015406721271574497
# Max: 0.4426085352897644
# Mean: 0.22329426561166466
# Standard Deviation: 0.033502938446685185
# First 5 valid pixel values in Band 50: [-- -- -- -- --]
#
# Band 51 Statistics:
# Min: 0.01550864614546299
# Max: 0.4430268704891205
# Mean: 0.22588464707303782
# Standard Deviation: 0.03392523618515885
# First 5 valid pixel values in Band 51: [-- -- -- -- --]
#
# Band 52 Statistics:
# Min: 0.015588674694299698
# Max: 0.4437771737575531
# Mean: 0.2283633330248532
# Standard Deviation: 0.03435375966758032
# First 5 valid pixel values in Band 52: [-- -- -- -- --]
#
# Band 53 Statistics:
# Min: 0.015665927901864052
# Max: 0.4455648362636566
# Mean: 0.2307623604127464
# Standard Deviation: 0.034780177463378484
# First 5 valid pixel values in Band 53: [-- -- -- -- --]
#
# Band 54 Statistics:
# Min: 0.015735413879156113
# Max: 0.449072927236557
# Mean: 0.23305470509300674
# Standard Deviation: 0.035204629118455885
# First 5 valid pixel values in Band 54: [-- -- -- -- --]
#
# Band 55 Statistics:
# Min: 0.01578071527183056
# Max: 0.4515058100223541
# Mean: 0.23501242917810614
# Standard Deviation: 0.03553626755049089
# First 5 valid pixel values in Band 55: [-- -- -- -- --]
#
# Band 56 Statistics:
# Min: 0.01583104208111763
# Max: 0.454158753156662
# Mean: 0.23704380289148697
# Standard Deviation: 0.03591312252823581
# First 5 valid pixel values in Band 56: [-- -- -- -- --]
#
# Band 57 Statistics:
# Min: 0.01587723195552826
# Max: 0.45668596029281616
# Mean: 0.23903309798870961
# Standard Deviation: 0.03628109305437064
# First 5 valid pixel values in Band 57: [-- -- -- -- --]
#
# Band 58 Statistics:
# Min: 0.01592174358665943
# Max: 0.45915254950523376
# Mean: 0.24097645846829338
# Standard Deviation: 0.036649448630036864
# First 5 valid pixel values in Band 58: [-- -- -- -- --]
#
# Band 59 Statistics:
# Min: 0.015976721420884132
# Max: 0.46191516518592834
# Mean: 0.24293797428818212
# Standard Deviation: 0.037049269497231675
# First 5 valid pixel values in Band 59: [-- -- -- -- --]
#
# Band 60 Statistics:
# Min: 0.016025647521018982
# Max: 0.4646119177341461
# Mean: 0.24482665988010405
# Standard Deviation: 0.03742457477497834
# First 5 valid pixel values in Band 60: [-- -- -- -- --]
#
# Band 61 Statistics:
# Min: 0.016071343794465065
# Max: 0.46691155433654785
# Mean: 0.2466458410453363
# Standard Deviation: 0.037785193743238146
# First 5 valid pixel values in Band 61: [-- -- -- -- --]
#
# Band 62 Statistics:
# Min: 0.016112230718135834
# Max: 0.4694260060787201
# Mean: 0.2484168543254054
# Standard Deviation: 0.0381487534794482
# First 5 valid pixel values in Band 62: [-- -- -- -- --]
#
# Band 63 Statistics:
# Min: 0.0161440372467041
# Max: 0.4713459014892578
# Mean: 0.2501466887229951
# Standard Deviation: 0.038489340999926513
# First 5 valid pixel values in Band 63: [-- -- -- -- --]
#
# Band 64 Statistics:
# Min: 0.016165753826498985
# Max: 0.4731062948703766
# Mean: 0.2518660476498956
# Standard Deviation: 0.03883170834226605
# First 5 valid pixel values in Band 64: [-- -- -- -- --]
#
# Band 65 Statistics:
# Min: 0.016175344586372375
# Max: 0.47470229864120483
# Mean: 0.2535169946838593
# Standard Deviation: 0.039154894038669265
# First 5 valid pixel values in Band 65: [-- -- -- -- --]
#
# Band 66 Statistics:
# Min: 0.01602991111576557
# Max: 0.47537440061569214
# Mean: 0.25497642697761463
# Standard Deviation: 0.03946123255326583
# First 5 valid pixel values in Band 66: [-- -- -- -- --]
#
# Band 67 Statistics:
# Min: 0.015638846904039383
# Max: 0.4761812686920166
# Mean: 0.2565535315832228
# Standard Deviation: 0.039766932718249944
# First 5 valid pixel values in Band 67: [-- -- -- -- --]
#
# Band 68 Statistics:
# Min: 0.015216502360999584
# Max: 0.4771738350391388
# Mean: 0.2581030175782254
# Standard Deviation: 0.040085492894526974
# First 5 valid pixel values in Band 68: [-- -- -- -- --]
#
# Band 69 Statistics:
# Min: 0.014811418019235134
# Max: 0.4774197041988373
# Mean: 0.2595317785935363
# Standard Deviation: 0.040321355075202285
# First 5 valid pixel values in Band 69: [-- -- -- -- --]
#
# Band 70 Statistics:
# Min: 0.014242295175790787
# Max: 0.4768590033054352
# Mean: 0.2608111034847971
# Standard Deviation: 0.040518241370955554
# First 5 valid pixel values in Band 70: [-- -- -- -- --]
#
# Band 71 Statistics:
# Min: 0.013251857832074165
# Max: 0.47223085165023804
# Mean: 0.2613564224275329
# Standard Deviation: 0.040516214420057026
# First 5 valid pixel values in Band 71: [-- -- -- -- --]
#
# Band 72 Statistics:
# Min: 0.01211159024387598
# Max: 0.46842625737190247
# Mean: 0.26178246239113223
# Standard Deviation: 0.04037576558051928
# First 5 valid pixel values in Band 72: [-- -- -- -- --]
#
# Band 73 Statistics:
# Min: 0.010733600705862045
# Max: 0.46430474519729614
# Mean: 0.2622693468447625
# Standard Deviation: 0.04019238043911757
# First 5 valid pixel values in Band 73: [-- -- -- -- --]
#
# Band 74 Statistics:
# Min: 0.008904402144253254
# Max: 0.4571164846420288
# Mean: 0.26205567616271297
# Standard Deviation: 0.039807430673849786
# First 5 valid pixel values in Band 74: [-- -- -- -- --]
#
# Band 75 Statistics:
# Min: 0.007698132656514645
# Max: 0.4503285586833954
# Mean: 0.2619857861358752
# Standard Deviation: 0.03952391286953512
# First 5 valid pixel values in Band 75: [-- -- -- -- --]
#
# Band 76 Statistics:
# Min: 0.007295331452041864
# Max: 0.44790005683898926
# Mean: 0.2628842023475337
# Standard Deviation: 0.03955523321419254
# First 5 valid pixel values in Band 76: [-- -- -- -- --]
#
# Band 77 Statistics:
# Min: 0.0073374006897211075
# Max: 0.4479798972606659
# Mean: 0.2642506728722584
# Standard Deviation: 0.03975645783596012
# First 5 valid pixel values in Band 77: [-- -- -- -- --]
#
# Band 78 Statistics:
# Min: 0.007476917468011379
# Max: 0.44983306527137756
# Mean: 0.2655681561115053
# Standard Deviation: 0.040075764492799364
# First 5 valid pixel values in Band 78: [-- -- -- -- --]
#
# Band 79 Statistics:
# Min: 0.007736947853118181
# Max: 0.4543106257915497
# Mean: 0.26788840860248225
# Standard Deviation: 0.040582184956132715
# First 5 valid pixel values in Band 79: [-- -- -- -- --]
#
# Band 80 Statistics:
# Min: 0.008233790285885334
# Max: 0.4605439007282257
# Mean: 0.2707637646399523
# Standard Deviation: 0.04120519524782005
# First 5 valid pixel values in Band 80: [-- -- -- -- --]
#
# Band 81 Statistics:
# Min: 0.008591722697019577
# Max: 0.4670098125934601
# Mean: 0.2737090749709515
# Standard Deviation: 0.04183821974973786
# First 5 valid pixel values in Band 81: [-- -- -- -- --]
#
# Band 82 Statistics:
# Min: 0.009002047590911388
# Max: 0.47335803508758545
# Mean: 0.27656486180090695
# Standard Deviation: 0.0424302368859204
# First 5 valid pixel values in Band 82: [-- -- -- -- --]
#
# Band 83 Statistics:
# Min: 0.00951028149574995
# Max: 0.47988632321357727
# Mean: 0.2794853651890469
# Standard Deviation: 0.043042175072475285
# First 5 valid pixel values in Band 83: [-- -- -- -- --]
#
# Band 84 Statistics:
# Min: 0.009947357699275017
# Max: 0.4864051043987274
# Mean: 0.28234976375564264
# Standard Deviation: 0.043654591371222004
# First 5 valid pixel values in Band 84: [-- -- -- -- --]
#
# Band 85 Statistics:
# Min: 0.010139773599803448
# Max: 0.49263274669647217
# Mean: 0.28507968427059877
# Standard Deviation: 0.04424374812207838
# First 5 valid pixel values in Band 85: [-- -- -- -- --]
#
# Band 86 Statistics:
# Min: 0.010498602874577045
# Max: 0.4983026087284088
# Mean: 0.28771346181530266
# Standard Deviation: 0.044816354242605216
# First 5 valid pixel values in Band 86: [-- -- -- -- --]
#
# Band 87 Statistics:
# Min: 0.01081262156367302
# Max: 0.5030753016471863
# Mean: 0.2901397222136533
# Standard Deviation: 0.0453261396131076
# First 5 valid pixel values in Band 87: [-- -- -- -- --]
#
# Band 88 Statistics:
# Min: 0.011016473174095154
# Max: 0.5071716904640198
# Mean: 0.29240139561546924
# Standard Deviation: 0.045780736532281305
# First 5 valid pixel values in Band 88: [-- -- -- -- --]
#
# Band 89 Statistics:
# Min: 0.011123977601528168
# Max: 0.5104230642318726
# Mean: 0.29445269200316704
# Standard Deviation: 0.04616327754373279
# First 5 valid pixel values in Band 89: [-- -- -- -- --]
#
# Band 90 Statistics:
# Min: 0.011233662255108356
# Max: 0.5128870606422424
# Mean: 0.2964285392952258
# Standard Deviation: 0.046510871163893394
# First 5 valid pixel values in Band 90: [-- -- -- -- --]
#
# Band 91 Statistics:
# Min: 0.011204645037651062
# Max: 0.5143574476242065
# Mean: 0.298166374895888
# Standard Deviation: 0.046781543123502606
# First 5 valid pixel values in Band 91: [-- -- -- -- --]
#
# Band 92 Statistics:
# Min: 0.0109834223985672
# Max: 0.5151345729827881
# Mean: 0.29973734203247265
# Standard Deviation: 0.047027176888373504
# First 5 valid pixel values in Band 92: [-- -- -- -- --]
#
# Band 93 Statistics:
# Min: 0.010741659440100193
# Max: 0.5151098370552063
# Mean: 0.3009500866314999
# Standard Deviation: 0.04720673025439651
# First 5 valid pixel values in Band 93: [-- -- -- -- --]
#
# Band 94 Statistics:
# Min: 0.010534561239182949
# Max: 0.514387309551239
# Mean: 0.30186762218383356
# Standard Deviation: 0.04733756265166354
# First 5 valid pixel values in Band 94: [-- -- -- -- --]
#
# Band 95 Statistics:
# Min: 0.010178583674132824
# Max: 0.5136417746543884
# Mean: 0.3025013238938417
# Standard Deviation: 0.047482536971661826
# First 5 valid pixel values in Band 95: [-- -- -- -- --]
#
# Band 96 Statistics:
# Min: 0.009841474704444408
# Max: 0.5104095935821533
# Mean: 0.3023439669000833
# Standard Deviation: 0.04746749908272204
# First 5 valid pixel values in Band 96: [-- -- -- -- --]
#
# Band 97 Statistics:
# Min: 0.009300614707171917
# Max: 0.500913143157959
# Mean: 0.30097862104245715
# Standard Deviation: 0.04710272894134506
# First 5 valid pixel values in Band 97: [-- -- -- -- --]
#
# Band 98 Statistics:
# Min: 0.008348671719431877
# Max: 0.490912526845932
# Mean: 0.2980587924545763
# Standard Deviation: 0.04635608103906841
# First 5 valid pixel values in Band 98: [-- -- -- -- --]
#
# Band 99 Statistics:
# Min: 0.006995456758886576
# Max: 0.4938727021217346
# Mean: 0.2943068708805051
# Standard Deviation: 0.04577299227758754
# First 5 valid pixel values in Band 99: [-- -- -- -- --]
#
# Band 100 Statistics:
# Min: 0.005962930154055357
# Max: 0.4965347349643707
# Mean: 0.2894620942201108
# Standard Deviation: 0.045379141415798234
# First 5 valid pixel values in Band 100: [-- -- -- -- --]
#
# Band 101 Statistics:
# Min: 0.00544675113633275
# Max: 0.4991249144077301
# Mean: 0.286422054786069
# Standard Deviation: 0.04530202579960695
# First 5 valid pixel values in Band 101: [-- -- -- -- --]
#
# Band 102 Statistics:
# Min: 0.005382769275456667
# Max: 0.5013329386711121
# Mean: 0.2854562549485352
# Standard Deviation: 0.045358143290292856
# First 5 valid pixel values in Band 102: [-- -- -- -- --]
#
# Band 103 Statistics:
# Min: 0.005623160395771265
# Max: 0.5042669177055359
# Mean: 0.2853100160923795
# Standard Deviation: 0.04548517933586999
# First 5 valid pixel values in Band 103: [-- -- -- -- --]
#
# Band 104 Statistics:
# Min: 0.006014871411025524
# Max: 0.5066741108894348
# Mean: 0.28533790783642327
# Standard Deviation: 0.04563887889248323
# First 5 valid pixel values in Band 104: [-- -- -- -- --]
#
# Band 105 Statistics:
# Min: 0.006415312644094229
# Max: 0.5083876252174377
# Mean: 0.2853039428900474
# Standard Deviation: 0.045793156981672044
# First 5 valid pixel values in Band 105: [-- -- -- -- --]
#
# Band 106 Statistics:
# Min: 0.006610398180782795
# Max: 0.5104483366012573
# Mean: 0.28567023089736865
# Standard Deviation: 0.045973887732883995
# First 5 valid pixel values in Band 106: [-- -- -- -- --]
#
# Band 107 Statistics:
# Min: 0.006946624722331762
# Max: 0.5118833184242249
# Mean: 0.28664878767313445
# Standard Deviation: 0.04620308245954167
# First 5 valid pixel values in Band 107: [-- -- -- -- --]
#
# Band 108 Statistics:
# Min: 0.007311011198908091
# Max: 0.5133786797523499
# Mean: 0.2881697553238527
# Standard Deviation: 0.046432052298334456
# First 5 valid pixel values in Band 108: [-- -- -- -- --]
#
# Band 109 Statistics:
# Min: 0.007692796178162098
# Max: 0.5156800746917725
# Mean: 0.29031886561577774
# Standard Deviation: 0.046687072766222616
# First 5 valid pixel values in Band 109: [-- -- -- -- --]
#
# Band 110 Statistics:
# Min: 0.008215293288230896
# Max: 0.5178265571594238
# Mean: 0.2930080410484211
# Standard Deviation: 0.047001139403493444
# First 5 valid pixel values in Band 110: [-- -- -- -- --]
#
# Band 111 Statistics:
# Min: 0.008608059026300907
# Max: 0.5198261141777039
# Mean: 0.2957998825204882
# Standard Deviation: 0.04734238124286195
# First 5 valid pixel values in Band 111: [-- -- -- -- --]
#
# Band 112 Statistics:
# Min: 0.008903397247195244
# Max: 0.5223243236541748
# Mean: 0.2985797382546195
# Standard Deviation: 0.047755365864479926
# First 5 valid pixel values in Band 112: [-- -- -- -- --]
#
# Band 113 Statistics:
# Min: 0.009166593663394451
# Max: 0.5262278318405151
# Mean: 0.30103736079834653
# Standard Deviation: 0.04813917941339557
# First 5 valid pixel values in Band 113: [-- -- -- -- --]
#
# Band 114 Statistics:
# Min: 0.009356755763292313
# Max: 0.5275394320487976
# Mean: 0.30327168872299515
# Standard Deviation: 0.04851991882072132
# First 5 valid pixel values in Band 114: [-- -- -- -- --]
#
# Band 115 Statistics:
# Min: 0.009336966089904308
# Max: 0.5299414992332458
# Mean: 0.30517115505239023
# Standard Deviation: 0.048875196081459356
# First 5 valid pixel values in Band 115: [-- -- -- -- --]
#
# Band 116 Statistics:
# Min: 0.009374992921948433
# Max: 0.5323262214660645
# Mean: 0.30674009778819755
# Standard Deviation: 0.049200674603499146
# First 5 valid pixel values in Band 116: [-- -- -- -- --]
#
# Band 117 Statistics:
# Min: 0.009316499345004559
# Max: 0.534608781337738
# Mean: 0.3080556048266856
# Standard Deviation: 0.0495151444636038
# First 5 valid pixel values in Band 117: [-- -- -- -- --]
#
# Band 118 Statistics:
# Min: 0.009200065396726131
# Max: 0.5369158387184143
# Mean: 0.30908252228768857
# Standard Deviation: 0.04983131303982813
# First 5 valid pixel values in Band 118: [-- -- -- -- --]
#
# Band 119 Statistics:
# Min: 0.009125471115112305
# Max: 0.5391770601272583
# Mean: 0.3096124332911744
# Standard Deviation: 0.050139054080114445
# First 5 valid pixel values in Band 119: [-- -- -- -- --]
#
# Band 120 Statistics:
# Min: 0.008944336324930191
# Max: 0.5413884520530701
# Mean: 0.3094444080266527
# Standard Deviation: 0.050425600426091066
# First 5 valid pixel values in Band 120: [-- -- -- -- --]
#
# Band 121 Statistics:
# Min: 0.008763994090259075
# Max: 0.5436724424362183
# Mean: 0.30838375055269357
# Standard Deviation: 0.05069515260614892
# First 5 valid pixel values in Band 121: [-- -- -- -- --]
#
# Band 122 Statistics:
# Min: 0.00844297930598259
# Max: 0.5457160472869873
# Mean: 0.30633849523398216
# Standard Deviation: 0.050975250975586764
# First 5 valid pixel values in Band 122: [-- -- -- -- --]
#
# Band 123 Statistics:
# Min: 0.008095033466815948
# Max: 0.5476176738739014
# Mean: 0.3032803004596354
# Standard Deviation: 0.05131390104804002
# First 5 valid pixel values in Band 123: [-- -- -- -- --]
#
# Band 124 Statistics:
# Min: -0.009999999776482582
# Max: -0.009999999776482582
# Mean: -0.009999995850791699
# Standard Deviation: 3.925690883477273e-09
# First 5 valid pixel values in Band 124: [-- -- -- -- --]
#
# Band 125 Statistics:
# Min: -0.3917819857597351
# Max: 0.5276793837547302
# Mean: 0.14747594176409498
# Standard Deviation: 0.05142333554540186
# First 5 valid pixel values in Band 125: [-- -- -- -- --]
#
# Band 126 Statistics:
# Min: -0.0003829389752354473
# Max: 0.5463781952857971
# Mean: 0.15092184142065376
# Standard Deviation: 0.05353455601310318
# First 5 valid pixel values in Band 126: [-- -- -- -- --]
#
# Band 127 Statistics:
# Min: -0.00038693551323376596
# Max: 0.5755207538604736
# Mean: 0.15514025884052607
# Standard Deviation: 0.0560579578275408
# First 5 valid pixel values in Band 127: [-- -- -- -- --]
#
# Band 128 Statistics:
# Min: -0.0019550579600036144
# Max: 0.602011501789093
# Mean: 0.1599584130240306
# Standard Deviation: 0.05777076711406113
# First 5 valid pixel values in Band 128: [-- -- -- -- --]
#
# Band 129 Statistics:
# Min: -0.00016604202392045408
# Max: 0.5611980557441711
# Mean: 0.1572660403234928
# Standard Deviation: 0.055831067343824654
# First 5 valid pixel values in Band 129: [-- -- -- -- --]
#
# Band 130 Statistics:
# Min: 0.0002369872381677851
# Max: 0.5707284212112427
# Mean: 0.1584029502267329
# Standard Deviation: 0.05521432115044413
# First 5 valid pixel values in Band 130: [-- -- -- -- --]
#
# Band 131 Statistics:
# Min: 0.0005252869450487196
# Max: 0.5657628178596497
# Mean: 0.1597118056626667
# Standard Deviation: 0.05454880333845344
# First 5 valid pixel values in Band 131: [-- -- -- -- --]
#
# Band 132 Statistics:
# Min: 0.0008098607650026679
# Max: 0.5761653780937195
# Mean: 0.16584588461815303
# Standard Deviation: 0.05551174650840021
# First 5 valid pixel values in Band 132: [-- -- -- -- --]
#
# Band 133 Statistics:
# Min: 0.0017108683241531253
# Max: 0.5759279727935791
# Mean: 0.17055367682594524
# Standard Deviation: 0.055549544558831335
# First 5 valid pixel values in Band 133: [-- -- -- -- --]
#
# Band 134 Statistics:
# Min: 0.0011700409231707454
# Max: 0.5733221769332886
# Mean: 0.17466047906962395
# Standard Deviation: 0.055364628789625565
# First 5 valid pixel values in Band 134: [-- -- -- -- --]
#
# Band 135 Statistics:
# Min: 0.0019955793395638466
# Max: 0.5777266621589661
# Mean: 0.17922000802048307
# Standard Deviation: 0.05550752718484484
# First 5 valid pixel values in Band 135: [-- -- -- -- --]
#
# Band 136 Statistics:
# Min: 0.0025548527482897043
# Max: 0.5771536231040955
# Mean: 0.18408665142260747
# Standard Deviation: 0.055594486417737767
# First 5 valid pixel values in Band 136: [-- -- -- -- --]
#
# Band 137 Statistics:
# Min: 0.002584079047665
# Max: 0.5794171690940857
# Mean: 0.1880653380170898
# Standard Deviation: 0.05551132070514121
# First 5 valid pixel values in Band 137: [-- -- -- -- --]
#
# Band 138 Statistics:
# Min: 0.002560665365308523
# Max: 0.5811986923217773
# Mean: 0.19196818991578493
# Standard Deviation: 0.05543900617231235
# First 5 valid pixel values in Band 138: [-- -- -- -- --]
#
# Band 139 Statistics:
# Min: 0.002956462325528264
# Max: 0.5819517970085144
# Mean: 0.19588228848546543
# Standard Deviation: 0.055417165308914565
# First 5 valid pixel values in Band 139: [-- -- -- -- --]
#
# Band 140 Statistics:
# Min: 0.002923630177974701
# Max: 0.5835916996002197
# Mean: 0.1998942973594102
# Standard Deviation: 0.055531358696275
# First 5 valid pixel values in Band 140: [-- -- -- -- --]
#
# Band 141 Statistics:
# Min: 0.003201219951733947
# Max: 0.5843249559402466
# Mean: 0.20322242830407913
# Standard Deviation: 0.05541451265378664
# First 5 valid pixel values in Band 141: [-- -- -- -- --]
#
# Band 142 Statistics:
# Min: 0.003201353596523404
# Max: 0.5854088068008423
# Mean: 0.20611132854675016
# Standard Deviation: 0.05540032084303771
# First 5 valid pixel values in Band 142: [-- -- -- -- --]
#
# Band 143 Statistics:
# Min: 0.003316570771858096
# Max: 0.5824013948440552
# Mean: 0.20795827292264346
# Standard Deviation: 0.05505113287638717
# First 5 valid pixel values in Band 143: [-- -- -- -- --]
#
# Band 144 Statistics:
# Min: 0.0032737278379499912
# Max: 0.5835040211677551
# Mean: 0.2112105531048524
# Standard Deviation: 0.05513271078927758
# First 5 valid pixel values in Band 144: [-- -- -- -- --]
#
# Band 145 Statistics:
# Min: 0.0033901638817042112
# Max: 0.5893604755401611
# Mean: 0.21550469275380202
# Standard Deviation: 0.055524839583842536
# First 5 valid pixel values in Band 145: [-- -- -- -- --]
#
# Band 146 Statistics:
# Min: 0.0037433479446917772
# Max: 0.5908591151237488
# Mean: 0.21893717673854254
# Standard Deviation: 0.055800610522044485
# First 5 valid pixel values in Band 146: [-- -- -- -- --]
#
# Band 147 Statistics:
# Min: 0.003303186036646366
# Max: 0.5874930620193481
# Mean: 0.2206734378052668
# Standard Deviation: 0.05571351362001903
# First 5 valid pixel values in Band 147: [-- -- -- -- --]
#
# Band 148 Statistics:
# Min: 0.0034394662361592054
# Max: 0.5905330181121826
# Mean: 0.22437071662502184
# Standard Deviation: 0.056098716960289556
# First 5 valid pixel values in Band 148: [-- -- -- -- --]
#
# Band 149 Statistics:
# Min: 0.003687130054458976
# Max: 0.5903459191322327
# Mean: 0.22829529066539161
# Standard Deviation: 0.056600146853098346
# First 5 valid pixel values in Band 149: [-- -- -- -- --]
#
# Band 150 Statistics:
# Min: 0.0037074496503919363
# Max: 0.5959338545799255
# Mean: 0.2316351342145582
# Standard Deviation: 0.05706866298172123
# First 5 valid pixel values in Band 150: [-- -- -- -- --]
#
# Band 151 Statistics:
# Min: 0.0036487197503447533
# Max: 0.5967840552330017
# Mean: 0.23403893340428375
# Standard Deviation: 0.057320518443872474
# First 5 valid pixel values in Band 151: [-- -- -- -- --]
#
# Band 152 Statistics:
# Min: 0.0037507093511521816
# Max: 0.5966804027557373
# Mean: 0.23584897263267215
# Standard Deviation: 0.05745307047844538
# First 5 valid pixel values in Band 152: [-- -- -- -- --]
#
# Band 153 Statistics:
# Min: 0.003798202844336629
# Max: 0.5974771976470947
# Mean: 0.23698742493650451
# Standard Deviation: 0.057628113754420104
# First 5 valid pixel values in Band 153: [-- -- -- -- --]
#
# Band 154 Statistics:
# Min: 0.003555652452632785
# Max: 0.5953388214111328
# Mean: 0.2376759622009028
# Standard Deviation: 0.05784319383832593
# First 5 valid pixel values in Band 154: [-- -- -- -- --]
#
# Band 155 Statistics:
# Min: 0.003350519575178623
# Max: 0.5961292386054993
# Mean: 0.2374091911651294
# Standard Deviation: 0.057918143384831686
# First 5 valid pixel values in Band 155: [-- -- -- -- --]
#
# Band 156 Statistics:
# Min: 0.003927542828023434
# Max: 0.5943729281425476
# Mean: 0.2369700568631685
# Standard Deviation: 0.05786699078582846
# First 5 valid pixel values in Band 156: [-- -- -- -- --]
#
# Band 157 Statistics:
# Min: 0.003561458084732294
# Max: 0.5952492356300354
# Mean: 0.2365642769740157
# Standard Deviation: 0.057813108834235384
# First 5 valid pixel values in Band 157: [-- -- -- -- --]
#
# Band 158 Statistics:
# Min: 0.0035193576477468014
# Max: 0.5960100293159485
# Mean: 0.23530543709062118
# Standard Deviation: 0.05770788496430639
# First 5 valid pixel values in Band 158: [-- -- -- -- --]
#
# Band 159 Statistics:
# Min: 0.0028528098482638597
# Max: 0.5956310629844666
# Mean: 0.2332258472920587
# Standard Deviation: 0.057617839534242064
# First 5 valid pixel values in Band 159: [-- -- -- -- --]
#
# Band 160 Statistics:
# Min: 0.0034022305626422167
# Max: 0.5972768068313599
# Mean: 0.23121523171998232
# Standard Deviation: 0.057534799895588795
# First 5 valid pixel values in Band 160: [-- -- -- -- --]
#
# Band 161 Statistics:
# Min: 0.002913243370130658
# Max: 0.5985991954803467
# Mean: 0.22905773462483675
# Standard Deviation: 0.05760877406428426
# First 5 valid pixel values in Band 161: [-- -- -- -- --]
#
# Band 162 Statistics:
# Min: 0.0032944451086223125
# Max: 0.5992193222045898
# Mean: 0.22634479658306855
# Standard Deviation: 0.05750780057595387
# First 5 valid pixel values in Band 162: [-- -- -- -- --]
#
# Band 163 Statistics:
# Min: 0.0029843999072909355
# Max: 0.5999084115028381
# Mean: 0.2240719889769771
# Standard Deviation: 0.05745045666707864
# First 5 valid pixel values in Band 163: [-- -- -- -- --]
#
# Band 164 Statistics:
# Min: 0.0025025762151926756
# Max: 0.6026955842971802
# Mean: 0.22177739496251966
# Standard Deviation: 0.057532427585536824
# First 5 valid pixel values in Band 164: [-- -- -- -- --]
#
# Band 165 Statistics:
# Min: 0.0030557720456272364
# Max: 0.6008822321891785
# Mean: 0.221633405440561
# Standard Deviation: 0.057751322969630765
# First 5 valid pixel values in Band 165: [-- -- -- -- --]
#
# Band 166 Statistics:
# Min: 0.0032052258029580116
# Max: 0.6041976809501648
# Mean: 0.22082637646399522
# Standard Deviation: 0.05802321595441403
# First 5 valid pixel values in Band 166: [-- -- -- -- --]
#
# Band 167 Statistics:
# Min: 0.0026967476587742567
# Max: 0.6115322709083557
# Mean: 0.21915026902036996
# Standard Deviation: 0.05831424232302223
# First 5 valid pixel values in Band 167: [-- -- -- -- --]
#
# Band 168 Statistics:
# Min: 0.0024938469287008047
# Max: 0.6128739714622498
# Mean: 0.21780600263750502
# Standard Deviation: 0.058638896005198775
# First 5 valid pixel values in Band 168: [-- -- -- -- --]
#
# Band 169 Statistics:
# Min: 0.0021310632582753897
# Max: 0.6128822565078735
# Mean: 0.2159007523058889
# Standard Deviation: 0.0587556643034366
# First 5 valid pixel values in Band 169: [-- -- -- -- --]
#
# Band 170 Statistics:
# Min: -0.009999999776482582
# Max: -0.009999999776482582
# Mean: -0.009999995850791699
# Standard Deviation: 3.925690883477273e-09
# First 5 valid pixel values in Band 170: [-- -- -- -- --]
#
# Band 171 Statistics:
# Min: 0.0006741158431395888
# Max: 0.6591126918792725
# Mean: 0.12413532380129767
# Standard Deviation: 0.057640470432314524
# First 5 valid pixel values in Band 171: [-- -- -- -- --]
#
# Band 172 Statistics:
# Min: 0.0007079020724631846
# Max: 0.6617669463157654
# Mean: 0.1271024526740085
# Standard Deviation: 0.058314268056216916
# First 5 valid pixel values in Band 172: [-- -- -- -- --]
#
# Band 173 Statistics:
# Min: 0.0007426269585266709
# Max: 0.6649433970451355
# Mean: 0.1299877620153006
# Standard Deviation: 0.058864776733541055
# First 5 valid pixel values in Band 173: [-- -- -- -- --]
#
# Band 174 Statistics:
# Min: 0.0007756202248856425
# Max: 0.665618360042572
# Mean: 0.1324780481049038
# Standard Deviation: 0.059234392825977894
# First 5 valid pixel values in Band 174: [-- -- -- -- --]
#
# Band 175 Statistics:
# Min: 0.0008095898665487766
# Max: 0.6648293733596802
# Mean: 0.13446658806850315
# Standard Deviation: 0.05939912440463921
# First 5 valid pixel values in Band 175: [-- -- -- -- --]
#
# Band 176 Statistics:
# Min: 0.00086387520423159
# Max: 0.6640079021453857
# Mean: 0.13692608237961562
# Standard Deviation: 0.05926613784500358
# First 5 valid pixel values in Band 176: [-- -- -- -- --]
#
# Band 177 Statistics:
# Min: 0.000925660424400121
# Max: 0.6643648743629456
# Mean: 0.13833235005295574
# Standard Deviation: 0.05895627146501816
# First 5 valid pixel values in Band 177: [-- -- -- -- --]
#
# Band 178 Statistics:
# Min: 0.0009914818219840527
# Max: 0.6639763712882996
# Mean: 0.13873841914221963
# Standard Deviation: 0.05835039304149415
# First 5 valid pixel values in Band 178: [-- -- -- -- --]
#
# Band 179 Statistics:
# Min: 0.001040684524923563
# Max: 0.6635002493858337
# Mean: 0.1384204757534627
# Standard Deviation: 0.05765145657259861
# First 5 valid pixel values in Band 179: [-- -- -- -- --]
#
# Band 180 Statistics:
# Min: 0.0010889414697885513
# Max: 0.661392331123352
# Mean: 0.13791247969172554
# Standard Deviation: 0.05699484075691192
# First 5 valid pixel values in Band 180: [-- -- -- -- --]
#
# Band 181 Statistics:
# Min: 0.0011361005017533898
# Max: 0.6623339653015137
# Mean: 0.1367904796608775
# Standard Deviation: 0.05614686376020812
# First 5 valid pixel values in Band 181: [-- -- -- -- --]
#
# Band 182 Statistics:
# Min: 0.001181107945740223
# Max: 0.6654255986213684
# Mean: 0.1358665335060822
# Standard Deviation: 0.05536579743861148
# First 5 valid pixel values in Band 182: [-- -- -- -- --]
#
# Band 183 Statistics:
# Min: 0.0012398656690493226
# Max: 0.6643438339233398
# Mean: 0.13481729943650966
# Standard Deviation: 0.05444925841608836
# First 5 valid pixel values in Band 183: [-- -- -- -- --]
#
# Band 184 Statistics:
# Min: 0.0012980859028175473
# Max: 0.6650890111923218
# Mean: 0.13408640238917852
# Standard Deviation: 0.05379811515420045
# First 5 valid pixel values in Band 184: [-- -- -- -- --]
#
# Band 185 Statistics:
# Min: 0.00018362347327638417
# Max: 0.6658891439437866
# Mean: 0.13494613808598369
# Standard Deviation: 0.053680643406197166
# First 5 valid pixel values in Band 185: [-- -- -- -- --]
#
# Band 186 Statistics:
# Min: 0.0007470971322618425
# Max: 0.6664341688156128
# Mean: 0.1347363475054241
# Standard Deviation: 0.053224578158739745
# First 5 valid pixel values in Band 186: [-- -- -- -- --]
#
# Band 187 Statistics:
# Min: 0.0013663507997989655
# Max: 0.6576461791992188
# Mean: 0.1345416997640127
# Standard Deviation: 0.05259686397321564
# First 5 valid pixel values in Band 187: [-- -- -- -- --]
#
# Band 188 Statistics:
# Min: 0.0009697339846752584
# Max: 0.6525948643684387
# Mean: 0.13429365443542998
# Standard Deviation: 0.052053484985265616
# First 5 valid pixel values in Band 188: [-- -- -- -- --]
#
# Band 189 Statistics:
# Min: 0.0004426184168551117
# Max: 0.6504212021827698
# Mean: 0.1346206272943209
# Standard Deviation: 0.05175594302975925
# First 5 valid pixel values in Band 189: [-- -- -- -- --]
#
# Band 190 Statistics:
# Min: 0.0012074537808075547
# Max: 0.6459975242614746
# Mean: 0.1342965464365405
# Standard Deviation: 0.05111203955190633
# First 5 valid pixel values in Band 190: [-- -- -- -- --]
#
# Band 191 Statistics:
# Min: 0.0004661621351260692
# Max: 0.6469123959541321
# Mean: 0.13533006730007918
# Standard Deviation: 0.05111162344984132
# First 5 valid pixel values in Band 191: [-- -- -- -- --]
#
# Band 192 Statistics:
# Min: 0.0011241770116612315
# Max: 0.6489686369895935
# Mean: 0.13773041215514492
# Standard Deviation: 0.05159270633612482
# First 5 valid pixel values in Band 192: [-- -- -- -- --]
#
# Band 193 Statistics:
# Min: 0.0013867825036868453
# Max: 0.6541919112205505
# Mean: 0.13950319276922601
# Standard Deviation: 0.05188968120634948
# First 5 valid pixel values in Band 193: [-- -- -- -- --]
#
# Band 194 Statistics:
# Min: 0.0009793671779334545
# Max: 0.6491588950157166
# Mean: 0.14046373880474236
# Standard Deviation: 0.051781178835179874
# First 5 valid pixel values in Band 194: [-- -- -- -- --]
#
# Band 195 Statistics:
# Min: 0.0012394434306770563
# Max: 0.6521677374839783
# Mean: 0.1414355797112626
# Standard Deviation: 0.05170284179348171
# First 5 valid pixel values in Band 195: [-- -- -- -- --]
#
# Band 196 Statistics:
# Min: 0.0009786179289221764
# Max: 0.6501314640045166
# Mean: 0.1419598995126014
# Standard Deviation: 0.051323788265192204
# First 5 valid pixel values in Band 196: [-- -- -- -- --]
#
# Band 197 Statistics:
# Min: 0.0014349519042298198
# Max: 0.6453328132629395
# Mean: 0.14172203242126044
# Standard Deviation: 0.05065625862238638
# First 5 valid pixel values in Band 197: [-- -- -- -- --]
#
# Band 198 Statistics:
# Min: 0.0014701558975502849
# Max: 0.6400802135467529
# Mean: 0.14199248272511336
# Standard Deviation: 0.05010322886192333
# First 5 valid pixel values in Band 198: [-- -- -- -- --]
#
# Band 199 Statistics:
# Min: 0.0009640700300224125
# Max: 0.644781231880188
# Mean: 0.14260475149355792
# Standard Deviation: 0.04989350819797192
# First 5 valid pixel values in Band 199: [-- -- -- -- --]
#
# Band 200 Statistics:
# Min: 0.0012657924089580774
# Max: 0.6458116769790649
# Mean: 0.14314534683447985
# Standard Deviation: 0.04945294312959959
# First 5 valid pixel values in Band 200: [-- -- -- -- --]
#
# Band 201 Statistics:
# Min: 0.0012152877170592546
# Max: 0.6417007446289062
# Mean: 0.1433223373024442
# Standard Deviation: 0.04887075727902515
# First 5 valid pixel values in Band 201: [-- -- -- -- --]
#
# Band 202 Statistics:
# Min: 0.0019742778968065977
# Max: 0.6430227756500244
# Mean: 0.14336340371821368
# Standard Deviation: 0.04818077989945631
# First 5 valid pixel values in Band 202: [-- -- -- -- --]
#
# Band 203 Statistics:
# Min: 0.0012917686253786087
# Max: 0.6371133327484131
# Mean: 0.14241465062055916
# Standard Deviation: 0.047296182836595486
# First 5 valid pixel values in Band 203: [-- -- -- -- --]
#
# Band 204 Statistics:
# Min: 0.0008043822017498314
# Max: 0.638792872428894
# Mean: 0.14364016822449127
# Standard Deviation: 0.04764304627017166
# First 5 valid pixel values in Band 204: [-- -- -- -- --]
#
# Band 205 Statistics:
# Min: 0.0013777983840554953
# Max: 0.6386095285415649
# Mean: 0.1452500006426669
# Standard Deviation: 0.04856554921839121
# First 5 valid pixel values in Band 205: [-- -- -- -- --]
#
# Band 206 Statistics:
# Min: 0.001165675581432879
# Max: 0.6376548409461975
# Mean: 0.14493017745318815
# Standard Deviation: 0.04877102339203822
# First 5 valid pixel values in Band 206: [-- -- -- -- --]
#
# Band 207 Statistics:
# Min: 0.0016419695457443595
# Max: 0.63252192735672
# Mean: 0.14313279876299473
# Standard Deviation: 0.04852296221715866
# First 5 valid pixel values in Band 207: [-- -- -- -- --]
#
# Band 208 Statistics:
# Min: 0.0014373048907145858
# Max: 0.6310530304908752
# Mean: 0.13968910024061448
# Standard Deviation: 0.047860248751033625
# First 5 valid pixel values in Band 208: [-- -- -- -- --]
#
# Band 209 Statistics:
# Min: 0.0016076324973255396
# Max: 0.6249918341636658
# Mean: 0.13540061606050324
# Standard Deviation: 0.047021855191726414
# First 5 valid pixel values in Band 209: [-- -- -- -- --]
#
# Band 210 Statistics:
# Min: 0.0011652637040242553
# Max: 0.6162616610527039
# Mean: 0.13162240940967188
# Standard Deviation: 0.04618057995246373
# First 5 valid pixel values in Band 210: [-- -- -- -- --]
#
# Band 211 Statistics:
# Min: 0.0009049408254213631
# Max: 0.607712984085083
# Mean: 0.12798959811467234
# Standard Deviation: 0.045607057274245584
# First 5 valid pixel values in Band 211: [-- -- -- -- --]
#
# Band 212 Statistics:
# Min: 0.0007558754296042025
# Max: 0.6127870082855225
# Mean: 0.12471939555891456
# Standard Deviation: 0.04507672595203655
# First 5 valid pixel values in Band 212: [-- -- -- -- --]
#
# Band 213 Statistics:
# Min: 0.0010153228649869561
# Max: 0.6086392998695374
# Mean: 0.1228007536554894
# Standard Deviation: 0.04469963815307985
# First 5 valid pixel values in Band 213: [-- -- -- -- --]
#
# Band 214 Statistics:
# Min: 0.0007971906452439725
# Max: 0.6082430481910706
# Mean: 0.12126729416664096
# Standard Deviation: 0.04447428627071408
# First 5 valid pixel values in Band 214: [-- -- -- -- --]
#
# Band 215 Statistics:
# Min: 0.0015268108109012246
# Max: 0.6110581755638123
# Mean: 0.11934247462751026
# Standard Deviation: 0.04419035552317736
# First 5 valid pixel values in Band 215: [-- -- -- -- --]
#
# Band 216 Statistics:
# Min: 0.0019593180622905493
# Max: 0.6072238683700562
# Mean: 0.11615937753853431
# Standard Deviation: 0.043526172421792145
# First 5 valid pixel values in Band 216: [-- -- -- -- --]
#
# Band 217 Statistics:
# Min: 0.0020350932609289885
# Max: 0.6090689301490784
# Mean: 0.11384966478493794
# Standard Deviation: 0.04324752150182386
# First 5 valid pixel values in Band 217: [-- -- -- -- --]
#
# Band 218 Statistics:
# Min: 0.001744648558087647
# Max: 0.6092934012413025
# Mean: 0.11211387768506237
# Standard Deviation: 0.042680435490301365
# First 5 valid pixel values in Band 218: [-- -- -- -- --]
#
# Band 219 Statistics:
# Min: 0.0016874501015990973
# Max: 0.6072031855583191
# Mean: 0.11059050003341868
# Standard Deviation: 0.04204449078132215
# First 5 valid pixel values in Band 219: [-- -- -- -- --]
#
# Band 220 Statistics:
# Min: 0.0017048512818291783
# Max: 0.6090642809867859
# Mean: 0.10944458476005388
# Standard Deviation: 0.04189745853338716
# First 5 valid pixel values in Band 220: [-- -- -- -- --]
#
# Band 221 Statistics:
# Min: 0.001520743826404214
# Max: 0.6089929342269897
# Mean: 0.10809089527357045
# Standard Deviation: 0.04156598041614091
# First 5 valid pixel values in Band 221: [-- -- -- -- --]
#
# Band 222 Statistics:
# Min: 0.0014738815370947123
# Max: 0.6128872036933899
# Mean: 0.10570949302577866
# Standard Deviation: 0.040906196111828295
# First 5 valid pixel values in Band 222: [-- -- -- -- --]
#
# Band 223 Statistics:
# Min: 0.0014319514157250524
# Max: 0.5988335013389587
# Mean: 0.10440908062642029
# Standard Deviation: 0.04060472064273896
# First 5 valid pixel values in Band 223: [-- -- -- -- --]
#
# Band 224 Statistics:
# Min: 0.0013781319139525294
# Max: 0.6146285533905029
# Mean: 0.10498129517948401
# Standard Deviation: 0.0412848424703392
# First 5 valid pixel values in Band 224: [-- -- -- -- --]
#
# Band 225 Statistics:
# Min: 0.0013918487820774317
# Max: 0.6128764748573303
# Mean: 0.10464796795148636
# Standard Deviation: 0.041392091378445926
# First 5 valid pixel values in Band 225: [-- -- -- -- --]
#
# Band 226 Statistics:
# Min: 0.0013782777823507786
# Max: 0.6085202693939209
# Mean: 0.10340568477444961
# Standard Deviation: 0.04113957548661495
# First 5 valid pixel values in Band 226: [-- -- -- -- --]
#
# Band 227 Statistics:
# Min: 0.0013059801422059536
# Max: 0.6104719042778015
# Mean: 0.10262825864258465
# Standard Deviation: 0.04108213144413201
# First 5 valid pixel values in Band 227: [-- -- -- -- --]
#
# Band 228 Statistics:
# Min: 0.0013428493402898312
# Max: 0.6078681945800781
# Mean: 0.10155734259801956
# Standard Deviation: 0.04117625738680701
# First 5 valid pixel values in Band 228: [-- -- -- -- --]
#
# Band 229 Statistics:
# Min: 0.001202761079184711
# Max: 0.6139219403266907
# Mean: 0.1001195601459111
# Standard Deviation: 0.041197504765900464
# First 5 valid pixel values in Band 229: [-- -- -- -- --]
#
# Band 230 Statistics:
# Min: 0.0012666063848882914
# Max: 0.6191538572311401
# Mean: 0.0994262912463625
# Standard Deviation: 0.04118494750373602
# First 5 valid pixel values in Band 230: [-- -- -- -- --]
#
# Band 231 Statistics:
# Min: 0.0011191540397703648
# Max: 0.6103222370147705
# Mean: 0.09896237410155166
# Standard Deviation: 0.0411694567976566
# First 5 valid pixel values in Band 231: [-- -- -- -- --]
#
# Band 232 Statistics:
# Min: 0.0011358213378116488
# Max: 0.5918101072311401
# Mean: 0.09706152603829267
# Standard Deviation: 0.04049590208485456
# First 5 valid pixel values in Band 232: [-- -- -- -- --]
#
# Band 233 Statistics:
# Min: 0.0010633183410391212
# Max: 0.6162815093994141
# Mean: 0.09389100915414751
# Standard Deviation: 0.04001071603783486
# First 5 valid pixel values in Band 233: [-- -- -- -- --]
#
# Band 234 Statistics:
# Min: 0.0010653793578967452
# Max: 0.5999586582183838
# Mean: 0.09272419917275915
# Standard Deviation: 0.03962637029982815
# First 5 valid pixel values in Band 234: [-- -- -- -- --]
#
# Band 235 Statistics:
# Min: 0.0010233852081000805
# Max: 0.619839608669281
# Mean: 0.08922062016071815
# Standard Deviation: 0.038510978743972225
# First 5 valid pixel values in Band 235: [-- -- -- -- --]
#
# Band 236 Statistics:
# Min: 0.0010040863417088985
# Max: 0.5750567317008972
# Mean: 0.09004360334341036
# Standard Deviation: 0.038701288207837664
# First 5 valid pixel values in Band 236: [-- -- -- -- --]
#
# Band 237 Statistics:
# Min: 0.000992338638752699
# Max: 0.5898335576057434
# Mean: 0.08450413588292151
# Standard Deviation: 0.037298744583676144
# First 5 valid pixel values in Band 237: [-- -- -- -- --]
#
# Band 238 Statistics:
# Min: 0.0009748362354002893
# Max: 0.5879806876182556
# Mean: 0.08255894380263443
# Standard Deviation: 0.036617448142356235
# First 5 valid pixel values in Band 238: [-- -- -- -- --]
#
# Band 239 Statistics:
# Min: 0.0013822963228449225
# Max: 0.5867933034896851
# Mean: 0.08259483674975064
# Standard Deviation: 0.03679033383711637
# First 5 valid pixel values in Band 239: [-- -- -- -- --]

# %% [markdown]
# ### This code cell calculates and adds indices to each image in the folder

# %%
# Define the output directory and the file name
output_folder = r'C:\Users\SkosanaT\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\13092014_emit\AddedIndices'
added_indices = os.path.join(output_folder, 'emit_with_indices.tif')

# Create the folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Define custom band names for the added indices
band_names = ['GI', 'IRG', 'NGRDI', 'VARI', 'VDVI']

# Define the NoData value (this is used in place of NaN for visualization or processing)
nodata_value = np.nan

try:
    # Open the image
    with rasterio.open(mosaic_file_path) as img:
        # Read all bands
        full_img = img.read()

        # Extract bands
        red_band = full_img[35, :, :]
        green_band = full_img[20, :, :]
        blue_band = full_img[11, :, :]

        # Calculate vegetation indices
        # 1) Greenness Index (GI) (Green/Red)
        GI = np.divide(green_band, red_band, out=np.full_like(green_band, np.nan, dtype=float), where=red_band != 0)

        # 2) IRG (Red-Green)
        IRG = red_band - green_band

        # 3) NGRDI (Green-Red)/(Green + Red)
        NGRDI = np.divide((green_band - red_band),
                          (green_band + red_band),
                          where=(green_band + red_band) != 0)

        # 4) Calculate VARI (Green-Red)/(Green+Red+Blue)
        VARI = np.divide((green_band - red_band),
                         (green_band + red_band + blue_band),
                         out=np.full_like(green_band, np.nan, dtype=float),
                         where=(green_band + red_band + blue_band) != 0)

        # 5) VDVI (2* Green-Red-Blue)/(2*Green+Red+Blue)
        VDVI = np.divide((2 * green_band - red_band - blue_band),
                         (2 * green_band + red_band + blue_band),
                         out=np.full_like(green_band, np.nan, dtype=float),
                         where=(2 * green_band + red_band + blue_band) != 0)

        # Add the calculated indices as new bands to the image
        indices = np.stack([GI, IRG, NGRDI, VARI, VDVI], axis=0)
        updated_img = np.concatenate((full_img, indices), axis=0)

        # Replace NaN values with the NoData value
        updated_img = np.nan_to_num(updated_img, nan=nodata_value)

        # Update band names in metadata profile
        profile = img.profile.copy()  # Copy the profile to avoid modifying the original
        if 'descriptions' not in profile:
            profile['descriptions'] = [''] * img.count
        band_names_all = profile['descriptions'] + band_names
        profile.update(count=profile['count'] + len(indices), dtype='float32', descriptions=band_names_all)

        # Update the NoData value in the profile
        profile.update(nodata=nodata_value)

        # Write the modified image array to a new raster file
        with rasterio.open(added_indices, 'w', **profile) as dst:
            dst.write(updated_img.astype('float32'))  # Convert to float32 before writing

        print(f"Indices added to the image and saved as {added_indices}")

except Exception as e:
    print(f"Error processing the image: {e}")
# Out:
# Indices added to the image and saved as C:\Users\SkosanaT\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\13092014_emit\AddedIndices\emit_with_indices.tif

# %% [markdown]
# ### This cell prints out band numbers of each image to see if they were added as bands

# %%
# Open the image
with rasterio.open(added_indices) as img:
    # Print the number of bands
    print(f"Image '{added_indices}' has {img.count} bands.")
# Out:
# Image 'C:\Users\SkosanaT\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\13092014_emit\AddedIndices\emit_with_indices.tif' has 244 bands.

# %% [markdown]
# ### This code cell extracts pixel values

# %%
# Define paths
pntsshp_path = r'C:\Users\SkosanaT\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\Train_Val\Training_data\train_shapefile.shp'

# Open shapefile and extract points' coordinates [0]= x coordinate, [1]= y coordinate and attributes
with fiona.open(pntsshp_path, 'r') as shapefile:
    points = [[(point['geometry']['coordinates'][0], point['geometry']['coordinates'][1]),
               (int(point['properties']['ID']), point['properties']['Val_id']),
               (point['properties']['X'], point['properties']['Y'])] for point in shapefile]

# Initialize dictionary to store band pixel values associated with each point
point_pixel_values = {}

# Open the raster image
with rasterio.open(added_indices) as src:
    imagename = os.path.splitext(os.path.basename(added_indices))[0]  # Remove the file extension
    
    # Iterate over each band in the image
    for band in range(1, src.count + 1):
        
        # Iterate over each point and extract pixel values
        for point in points:
            row, col = src.index(point[0][0], point[0][1])  # Find the point within the raster image
            values = src.read(band, window=((row, row+1), (col, col+1)))  # Read the band values

            if values.size != 0:  # Check if bands are valid/not empty
                # Prepare key for the current point
                point_key = f"Point_id: {point[1][1]}, X: {point[2][0]}, Y: {point[2][1]}, Class_ID: {point[1][0]}"
                if point_key not in point_pixel_values:
                    point_pixel_values[point_key] = {}

                # Add pixel values to the dictionary
                point_pixel_values[point_key][f'{imagename}_Band_{band}'] = values[0][0]

# Print point_pixel_values
for point_key, pixel_values in point_pixel_values.items():
    print(f"Point: {point_key}, Pixel Values: {pixel_values}")
# Out:
# Point: Point_id: VAL_2887, X: 29.04363001, Y: -31.00724936, Class_ID: 2, Pixel Values: {'emit_with_indices_Band_1': 0.014077551, 'emit_with_indices_Band_2': 0.0146824, 'emit_with_indices_Band_3': 0.015493203, 'emit_with_indices_Band_4': 0.016422171, 'emit_with_indices_Band_5': 0.017275201, 'emit_with_indices_Band_6': 0.018191405, 'emit_with_indices_Band_7': 0.019070683, 'emit_with_indices_Band_8': 0.01982663, 'emit_with_indices_Band_9': 0.0205006, 'emit_with_indices_Band_10': 0.02109761, 'emit_with_indices_Band_11': 0.02150335, 'emit_with_indices_Band_12': 0.021148553, 'emit_with_indices_Band_13': 0.022244748, 'emit_with_indices_Band_14': 0.023743507, 'emit_with_indices_Band_15': 0.025868444, 'emit_with_indices_Band_16': 0.029225541, 'emit_with_indices_Band_17': 0.03247009, 'emit_with_indices_Band_18': 0.035206117, 'emit_with_indices_Band_19': 0.03679722, 'emit_with_indices_Band_20': 0.038043544, 'emit_with_indices_Band_21': 0.038513046, 'emit_with_indices_Band_22': 0.036433224, 'emit_with_indices_Band_23': 0.03484942, 'emit_with_indices_Band_24': 0.03378267, 'emit_with_indices_Band_25': 0.032683283, 'emit_with_indices_Band_26': 0.03273532, 'emit_with_indices_Band_27': 0.033149883, 'emit_with_indices_Band_28': 0.032166287, 'emit_with_indices_Band_29': 0.030963073, 'emit_with_indices_Band_30': 0.03029591, 'emit_with_indices_Band_31': 0.03065715, 'emit_with_indices_Band_32': 0.029950855, 'emit_with_indices_Band_33': 0.028657256, 'emit_with_indices_Band_34': 0.027518539, 'emit_with_indices_Band_35': 0.026418794, 'emit_with_indices_Band_36': 0.026656693, 'em
427, 'emit_with_indices_Band_75': 0.29087618, 'emit_with_indices_Band_76': 0.2929997, 'emit_with_indices_Band_77': 0.2950122, 'emit_with_indices_Band_78': 0.29811922, 'emit_with_indices_Band_79': 0.29980946, 'emit_with_indices_Band_80': 0.30137932, 'emit_with_indices_Band_81': 0.30305848, 'emit_with_indices_Band_82': 0.30448082, 'emit_with_indices_Band_83': 0.30605897, 'emit_with_indices_Band_84': 0.30722374, 'emit_with_indices_Band_85': 0.3084513, 'emit_with_indices_Band_86': 0.30948016, 'emit_with_indices_Band_87': 0.3106165, 'emit_with_indices_Band_88': 0.3114767, 'emit_with_indices_Band_89': 0.3122558, 'emit_with_indices_Band_90': 0.31322974, 'emit_with_indices_Band_91': 0.31414142, 'emit_with_indices_Band_92': 0.31478497, 'emit_with_indices_Band_93': 0.3154638, 'emit_with_indices_Band_94': 0.31596833, 'emit_with_indices_Band_95': 0.3161691, 'emit_with_indices_Band_96': 0.31635538, 'emit_w ...
# Point: Point_id: None, X: 28.87735908, Y: -30.69680145, Class_ID: 7, Pixel Values: {'emit_with_indices_Band_1': 0.026848366, 'emit_with_indices_Band_2': 0.028683577, 'emit_with_indices_Band_3': 0.03065501, 'emit_with_indices_Band_4': 0.032565627, 'emit_with_indices_Band_5': 0.0341525, 'emit_with_indices_Band_6': 0.035726182, 'emit_with_indices_Band_7': 0.03731537, 'emit_with_indices_Band_8': 0.038819313, 'emit_with_indices_Band_9': 0.04008651, 'emit_with_indices_Band_10': 0.04116239, 'emit_with_indices_Band_11': 0.041505124, 'emit_with_indices_Band_12': 0.04196361, 'emit_with_indices_Band_13': 0.04501047, 'emit_with_indices_Band_14': 0.04802492, 'emit_with_indices_Band_15': 0.052988183, 'emit_with_indices_Band_16': 0.059131864, 'emit_with_indices_Band_17': 0.06624494, 'emit_with_indices_Band_18': 0.07174067, 'emit_with_indices_Band_19': 0.076002315, 'emit_with_indices_Band_20': 0.07972152, 'emit_with_indices_Band_21': 0.08192024, 'emit_with_indices_Band_22': 0.08233009, 'emit_with_indices_Band_23': 0.08105136, 'emit_with_indices_Band_24': 0.08134654, 'emit_with_indices_Band_25': 0.08217232, 'emit_with_indices_Band_26': 0.084179565, 'emit_with_indices_Band_27': 0.08525932, 'emit_with_indices_Band_28': 0.08510937, 'emit_with_indices_Band_29': 0.08506048, 'emit_with_indices_Band_30': 0.08568638, 'emit_with_indices_Band_31': 0.086886816, 'emit_with_indices_Band_32': 0.08649659, 'emit_with_indices_Band_33': 0.08490564, 'emit_with_indices_Band_34': 0.083828464, 'emit_with_indices_Band_35': 0.0825436, 'emit_with_indices_Band_36': 0.08071667, 'emit_with_indices_Band_37': 0.0817823, 'emit_with_indices_Band_38': 0.08561045, 'emit_with_indices_Band_39': 0.100343995, 'emit_with_indices_Band_40': 0.12534215, 'emit_with_indices_Band_41': 0.152836, 'emit_with_indices_Band_42': 0.18057331, 'emit_with_indices_Band_43': 0.20943543, 'emit_with_indices_Band_44': 0.23537736, 'emit_with_indices_Band_45': 0.2546806, 
073178, 'emit_with_indices_Band_87': 0.20796973, 'emit_with_indices_Band_88': 0.20863059, 'emit_with_indices_Band_89': 0.20920938, 'emit_with_indices_Band_90': 0.20980039, 'emit_with_indices_Band_91': 0.21044542, 'emit_with_indices_Band_92': 0.21106224, 'emit_with_indices_Band_93': 0.21163458, 'emit_with_indices_Band_94': 0.21210553, 'emit_with_indices_Band_95': 0.2125366, 'emit_with_indices_Band_96': 0.213 ...
# Point: Point_id: None, X: 28.9919507, Y: -30.76609343, Class_ID: 6, Pixel Values: {'emit_with_indices_Band_1': 0.02238939, 'emit_with_indices_Band_2': 0.023560617, 'emit_with_indices_Band_3': 0.02483291, 'emit_with_indices_Band_4': 0.026177833, 'emit_with_indices_Band_5': 0.027416687, 'emit_with_indices_Band_6': 0.028682234, 'emit_with_indices_Band_7': 0.02993058, 'emit_with_indices_Band_8': 0.031090768, 'emit_with_indices_Band_9': 0.03211639, 'emit_with_indices_Band_10': 0.033059478, 'emit_with_indices_Band_11': 0.033305272, 'emit_with_indices_Band_12': 0.033321418, 'emit_with_indices_Band_13': 0.035600413, 'emit_with_indices_Band_14': 0.038197767, 'emit_with_indices_Band_15': 0.040989663, 'emit_with_indices_Band_16': 0.04502482, 'emit_with_indices_Band_17': 0.048947755, 'emit_with_indices_Band_18': 0.052828297, 'emit_with_indices_Band_19': 0.05481802, 'emit_with_indices_Band_20': 0.0576991, 'emit_with_indices_Band_21': 0.05866901, 'emit_with_indices_Band_22': 0.058729496, 'emit_with_indices_Band_23': 0.057431903, 'emit_with_indices_Band_24': 0.05632161, 'emit_with_indices_Band_25': 0.05598407, 'emit_with_indices_Band_26': 0.05634934, 'emit_with_indices_Band_27': 0.057369202, 'emit_with_indices_Band_28': 0.05630159, 'emit_with_indices_Band_29': 0.055604976, 'emit_with_indices_Band_30': 0.055383835, 'emit_with_indices_Band_31': 0.055807292, 'emit_with_indices_Band_32': 0.055286862, 'emit_with_indices_Band_33': 0.053623073, 'emit_with_indices_Band_34': 0.05271558, 'emit_with_indices_Band_35': 0.050959356, 'emit_with_indices_Band_36': 0.04945064, 'emit_with_indices_Band_37': 0.050663494, 'emit_with_indices_Band_38': 0.054153163, 'emit_with_indices_Band_39': 0.06570309, 'emit_with_indices_Band_40': 0.08395601, 'emit_with_indices_Band_41': 0.1035678, 'emit_with_indices_Band_42': 0.12222787, 'emit_with_indices_Band_43': 0.13922487, 'emit_with_indices_Band_44': 0.15276259, 'emit_with_indices_Band_45': 0.1650597, 'emit_with_indices_Band_46': 0.17410344, 'emit_with_indices_Band_47': 0.17762321, 'emit_with_indices_Band_48': 0.1806755, 'emit_with_indices_Band_49': 0.18328878, 'emit_with_indices_Band_50': 0.18611154, 'emit_with_indices_Band_51': 0.18876338, 'emit_with_indices_Band_52': 0.19139734, 'emit_with_indices_Band_53': 0.19404364, 'emit_with_indices_Band_54': 0.19666366, 'emit_with_indices_Band_55': 0.19895557, 'emit_with_indices_Band_56': 0.20138349, 'emit_with_indices_Band_57': 0.20383433, 'emit_with_
_83': 0.27297676, 'emit_with_indices_Band_84': 0.27431113, 'emit_with_indices_Band_85': 0.2755835, 'emit_with_indices_Band_86': 0.2769756, 'emit_with_indices_Band_87': 0.27809888, 'emit_with_indices_Band_88': 0.27926522, 'emit_with_indices_Band_89': 0.28038567, 'emit_with_indices_Band_90': 0.28164843, 'emit_with_indices_Band_91': 0.28268975, 'emit_with_indices_Band_92': 0.28383416, 'emit_with_indices_Band_93': 0.28487024, 'emit_with_indices_Band_94': 0.28557813, 'emit_with_indices_Band_95': 0.28611028, 'emit_with_indices_Band_96': 0.2865596, 'emit_wit ...

# %% [markdown]
# ### This cell changes point_pixel_value dictionary to a dataframe

# %%
# Create a list of dictionaries for DataFrame creation
data_list = []

for point_key, pixel_values in point_pixel_values.items():
    data_dict = {}
    # Extracting Point ID, X, Y, and Class ID from point_key
    point_id = point_key.split(',')[0].split(':')[1].strip()  
    x_coord = point_key.split(',')[1].split(':')[1].strip()
    y_coord = point_key.split(',')[2].split(':')[1].strip()
    class_id = point_key.split(',')[3].split(':')[1].strip()
    
    # Add extracted information as separate columns
    data_dict['Point'] = point_id
    data_dict['X'] = x_coord
    data_dict['Y'] = y_coord
    data_dict['Class_ID'] = class_id
    
    # Add band pixel values as columns
    data_dict.update(pixel_values)

    data_list.append(data_dict)

# Create DataFrame from list of dictionaries
pixelvalues_df = pd.DataFrame(data_list)

# Print the DataFrame
print(pixelvalues_df)

# Save the DataFrame to a CSV file
# Define the CSV file folder
csv_file_folder = r'C:\Users\SkosanaT\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\13092014_emit\band_values'

# Create the folder if it doesn't exist
os.makedirs(csv_file_folder, exist_ok=True)

# Define the CSV file path
csv_file_path = os.path.join(csv_file_folder, 'emit_pixel_values.csv')

# Save the DataFrame to a CSV file
pixelvalues_df.to_csv(csv_file_path, index=False)

print(f'DataFrame successfully saved to {csv_file_path}')
# Out:
#         Point            X             Y Class_ID  emit_with_indices_Band_1  \
# 0    VAL_2887  29.04363001  -31.00724936        2                  0.014078
# 1     NVAL254  29.02381883  -31.00773088        2                  0.011136
# 2        None   28.8769605  -30.69760225        7                  0.027810
# 3     NVAL279  29.11025967  -30.90116542        5                  0.023897
# 4    VAL_2214   29.1825931  -30.81179621        7                  0.029157
# ..        ...          ...           ...      ...                       ...
# 163  VAL_2224   29.1769613  -30.80323135        3                  0.011529
# 164      None  29.04422791  -31.01097117        4                  0.049852
# 165  VAL_1342  28.87787196  -30.69598924        7                  0.025091
# 166      None  28.99859574  -30.89497315        8                  0.067832
# 167  VAL_3303  28.99487763  -30.90048499        8                  0.080128
#
#      emit_with_indices_Band_2  emit_with_indices_Band_3  \
# 0                    0.014682                  0.015493
# 1                    0.011664                  0.012343
# 2                    0.029736                  0.031755
# 3                    0.025307                  0.026830
# 4                    0.030898                  0.032674
# ..                        ...                       ...
# 163                  0.011932                  0.012551
# 164                  0.056915                  0.061146
# 165                  0.026806                  0.028673
# 166                  0.073942                  0.079418
# 167                  0.086629                  0.091486
#
#      emit_with_indices_Band_4  emit_with_indices_Band_5  \
# 0                    0.016422                  0.017275
# 1                    0.013099                  0.013794
# 2                    0.033690                  0.035331
# 3                    0.028415                  0.029842
# 4                    0.034404                  0.035901
# ..                        ...                       ...
# 163                  0.013297                  0.013993
# 164                  0.066207                  0.069217
# 165                  0.030481                  0.031971
# 166                  0.083195                  0.086814
# 167                  0.095692                  0.098697
#
#      emit_with_indices_Band_6  ...  emit_with_indices_Band_235  \
# 0                    0.018191  ...                    0.023579
# 1                    0.014547  ...                    0.015076
# 2                    0.036927  ...                    0.090730
# 3                    0.031298  ...                    0.066789
# 4                    0.037360  ...                    0.089695
# ..                        ...  ...                         ...
# 163                  0.014721  ...                    0.012951
# 164                  0.073111  ...                    0.169798
# 165                  0.033446  ...                    0.084319
# 166                  0.090348  ...                    0.191809
# 167                  0.102677  ...                    0.186707
#
#      emit_with_indices_Band_236  emit_with_indices_Band_237  \
# 0                      0.024692                    0.020790
# 1                      0.018460                    0.011963
# 2                      0.090250                    0.087190
# 3                      0.068557                    0.063190
# 4                      0.090275                    0.085030
# ..                          ...                         ...
# 163                    0.013455                    0.013774
# 164                    0.161915                    0.163498
# 165                    0.088383                    0.081759
# 166                    0.187245                    0.186434
# 167                    0.184066                    0.190148
#
#      emit_with_indices_Band_238  emit_with_indices_Band_239  \
# 0                      0.020536                    0.019985
# 1                      0.013242                    0.013348
# 2                      0.084637                    0.083834
# 3                      0.062166                    0.061563
# 4                      0.081976                    0.081417
# ..                          ...                         ...
# 163                    0.012645                    0.012141
# 164                    0.155025                    0.155761
# 165                    0.080148                    0.081539
# 166                    0.179694                    0.178231
# 167                    0.175290                    0.173057
#
#      emit_with_indices_Band_240  emit_with_indices_Band_241  \
# 0                      1.042966                   -0.000605
# 1                      1.047426                   -0.000528
# 2                      1.069259                   -0.001926
# 3                      1.059028                   -0.001411
# 4                      1.059733                   -0.001742
# ..                          ...                         ...
# 163                    1.035010                   -0.000404
# 164                    1.141687                   -0.007063
# 165                    1.068339                   -0.001715
# 166                    1.090073                   -0.006110
# 167                    1.081135                   -0.006501
#
#      emit_with_indices_Band_242  emit_with_indices_Band_243  \
# 0                      0.021031                    0.013668
# 1                      0.023164                    0.015028
# 2                      0.033470                    0.021568
# 3                      0.028668                    0.018552
# 4                      0.029000                    0.018782
# ..                          ...                         ...
# 163                    0.017204                    0.011208
# 164                    0.066157                    0.042065
# 165                    0.033041                    0.021282
# 166                    0.043095                    0.027622
# 167                    0.038986                    0.025175
#
#      emit_with_indices_Band_244
# 0                     -0.003495
# 1                     -0.003227
# 2                     -0.000784
# 3                     -0.001103
# 4                     -0.000277
# ..                          ...
# 163                   -0.004487
# 164                    0.012597
# 165                   -0.001414
# 166                    0.002147
# 167                    0.004766
#
# [168 rows x 248 columns]
# DataFrame successfully saved to C:\Users\SkosanaT\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\13092014_emit\band_values\emit_pixel_values.csv

# %% [markdown]
# ### This cell block trains the random forest classifier

# %%
# Define features 
# Find the index of the last non-band column
last_non_band_index = pixelvalues_df.columns.tolist().index('Class_ID')  #

# Select columns starting from the column following the last non-band column
#These columns are the band features used in the classification
features = pixelvalues_df.iloc[:, last_non_band_index + 1:]
#print(features)

# Define target (Class ID column)
target = pixelvalues_df['Class_ID']

# Convert features and target columns to arrays
features_array = features.values
target_array = target.values

# Train the classifier using RandomForest with 500 trees
classifier = RandomForestClassifier(n_estimators=500)
classifier.fit(features_array, target_array)

# Print information about features_array
print("Features Array:")
print(f"Shape: {features_array.shape}")
print(f"Data Type: {features_array.dtype}")
print("First 5 rows:\n", features_array[:5])

# Print information about target_array
print("\nTarget Array:")
print(f"Shape: {target_array.shape}")
print(f"Data Type: {target_array.dtype}")
print("First 5 values:\n", target_array[:5])


# Train the classifier using RandomForest with 500 trees
classifier = RandomForestClassifier(n_estimators=500)
classifier.fit(features_array, target_array)
# Out:
# Features Array:
# Shape: (168, 244)
# Data Type: float32
# First 5 rows:
#  [[ 0.01407755  0.0146824   0.0154932  ...  0.02103096  0.01366794
#   -0.00349456]
#  [ 0.011136    0.01166414  0.01234332 ...  0.0231638   0.01502806
#   -0.00322683]
#  [ 0.02780972  0.0297358   0.03175525 ...  0.03347041  0.02156837
#   -0.00078445]
#  [ 0.02389675  0.02530733  0.0268297  ...  0.02866809  0.0185521
#   -0.00110304]
#  [ 0.02915678  0.03089841  0.03267423 ...  0.02900042  0.0187818
#   -0.00027665]]
#
# Target Array:
# Shape: (168,)
# Data Type: object
# First 5 values:
#  ['2' '2' '7' '5' '7']
# RandomForestClassifier(n_estimators=500)

# %% [markdown]
# ### This cell block performs the classification

# %%
# Define the output folder
classified_folder = r'C:\Users\SkosanaT\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\13092014_emit\classified'

# Create the output folder if it doesn't exist
os.makedirs(classified_folder, exist_ok=True)

# Open the TIFF file using rasterio
with rasterio.open(added_indices) as src:
    # Read all bands into a numpy array
    bands = [src.read(band_idx) for band_idx in range(1, src.count + 1)]
    stacked_bands = np.stack(bands, axis=-1)
    
    # Flatten the array to 2D (rows, columns)
    rows, cols, num_bands = stacked_bands.shape
    reshaped_bands = stacked_bands.reshape(rows * cols, num_bands)
    
    # Proceed with classification
    predicted_labels = classifier.predict(reshaped_bands)
    
    # Create an array to store classification results
    classification_result = np.full(rows * cols, fill_value=np.nan, dtype=np.float32)
    classification_result[:] = predicted_labels  # No masking applied
    
    # Reshape back to 2D
    classification_result_2d = classification_result.reshape(rows, cols)
    
    # Prepare the output file path
    output_file_name = os.path.basename(added_indices).replace('.tif', '_classified_2.tif')
    output_path = os.path.join(classified_folder, output_file_name)

    # Update metadata for the new GeoTIFF
    meta = src.meta.copy()
    meta.update({
        'driver': 'GTiff',
        'dtype': 'float32',
        'count': 1,
        'compress': 'lzw',
        'nodata': np.nan,
        'crs': src.crs,  # Use the same CRS as the input raster
        'transform': src.transform,  # Use the same transform as the input raster
    })
    
    # Save the classification result to a new GeoTIFF
    with rasterio.open(output_path, 'w', **meta) as dst:
        dst.write(classification_result_2d, 1)

    print(f"Classification completed and saved as {output_path}")
# Out:
# Classification completed and saved as C:\Users\SkosanaT\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\data\EMIT\13092014_emit\classified\emit_with_indices_classified_2.tif
