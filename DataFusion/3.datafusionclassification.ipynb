# %% [markdown]
# ## Import packages

# %%
# Import packages
import argparse
import os
#import geoviews
import warnings
import rasterio as rio
import rasterio
import pandas as pd
import fiona
import matplotlib.pyplot as plt
import numpy.ma as ma
import numpy as np
import xarray as xr
import rioxarray as rxr
from shapely.geometry import mapping, box
import geopandas as gpd

warnings.simplefilter('ignore')

# %% [markdown]
# ### Code loops through the folder and prints out metadata

# %%
# Define the path to the specific TIFF file
image_file_path = r'C:\Users\User\Documents\DataFusion\DataFusion\SimpleFusion\FusedImage\04102014fused_image.tif'

print(f"\nProcessing file: {mosaic_file_path}")

# Open the image
with rasterio.open(image_file_path) as img:
    # Print the original image metadata
    metadata = img.meta
    print("Metadata:", metadata)
    
    # Explicitly set NoData value to 0 (if it's not already set)
    nodata = 0
    
    # Loop through each band and print its statistics
    for band in range(1, img.count + 1):
        band_data = img.read(band)
        
        # Mask NoData values (0 in this case)
        band_data = np.ma.masked_equal(band_data, nodata)
        
        # Calculate statistics ignoring masked values (NoData)
        valid_data = band_data[~band_data.mask]
        
        if valid_data.size > 0:
            print(f"\nBand {band} Statistics:")
            print(f"Min: {valid_data.min()}")
            print(f"Max: {valid_data.max()}")
            print(f"Mean: {valid_data.mean()}")
            print(f"Standard Deviation: {valid_data.std()}")
            print(f"First 5 valid pixel values in Band {band}: {valid_data.flatten()[:5]}")
        else:
            print(f"\nBand {band} contains only NaN values.")
# Out:
# Processing file: C:\Users\User\Documents\DataFusion\DataFusion\SimpleFusion\FusedImage\04102014fused_image.tif
# Metadata: {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 3890, 'height': 4159, 'count': 28, 'crs': CRS.from_epsg(32735), 'transform': Affine(10.0, 0.0, 671770.0,
#        0.0, -10.0, 6604990.0)}
#
# Band 1 Statistics:
# Min: 0.00019999999494757503
# Max: 1.8167999982833862
# Mean: 0.040264517995412356
# Standard Deviation: 0.018357353086230356
# First 5 valid pixel values in Band 1: [0.049400001764297485 0.04960000142455101 0.04619999974966049
#  0.04830000177025795 0.05009999871253967]
#
# Band 2 Statistics:
# Min: 0.00019999999494757503
# Max: 1.7128000259399414
# Mean: 0.0718706353937605
# Standard Deviation: 0.02367691043929165
# First 5 valid pixel values in Band 2: [0.08479999750852585 0.08789999783039093 0.08160000294446945
#  0.07829999923706055 0.08699999749660492]
#
# Band 3 Statistics:
# Min: 9.999999747378752e-05
# Max: 1.6535999774932861
# Mean: 0.0662405328309843
# Standard Deviation: 0.03407090045002641
# First 5 valid pixel values in Band 3: [0.07729999721050262 0.0738999992609024 0.0714000016450882
#  0.08129999786615372 0.07880000025033951]
#
# Band 4 Statistics:
# Min: 0.0026000000070780516
# Max: 1.077299952507019
# Mean: 0.12064720861039989
# Standard Deviation: 0.03264821594041784
# First 5 valid pixel values in Band 4: [0.1454000025987625 0.14429999887943268 0.14429999887943268
#  0.14030000567436218 0.1462000012397766]
#
# Band 5 Statistics:
# Min: 9.999999747378752e-05
# Max: 1.1130000352859497
# Mean: 0.22629873123643723
# Standard Deviation: 0.04049546154801492
# First 5 valid pixel values in Band 5: [0.23549999296665192 0.23839999735355377 0.23839999735355377
#  0.20720000565052032 0.2328999936580658]
#
# Band 6 Statistics:
# Min: 9.999999747378752e-05
# Max: 1.0807000398635864
# Mean: 0.25802584206377605
# Standard Deviation: 0.04893611305741884
# First 5 valid pixel values in Band 6: [0.26600000262260437 0.2678000032901764 0.2678000032901764
#  0.22920000553131104 0.2574999928474426]
#
# Band 7 Statistics:
# Min: 9.999999747378752e-05
# Max: 1.5736000537872314
# Mean: 0.2615286082718771
# Standard Deviation: 0.051663347127814015
# First 5 valid pixel values in Band 7: [0.2696000039577484 0.2888000011444092 0.28139999508857727
#  0.24220000207424164 0.2651999890804291]
#
# Band 8 Statistics:
# Min: 9.999999747378752e-05
# Max: 0.9156000018119812
# Mean: 0.279164774699754
# Standard Deviation: 0.05155844548349399
# First 5 valid pixel values in Band 8: [0.28700000047683716 0.29159998893737793 0.29159998893737793
#  0.25589999556541443 0.2822999954223633]
#
# Band 9 Statistics:
# Min: 0.0010999999940395355
# Max: 0.5784000158309937
# Mean: 0.27706414148218295
# Standard Deviation: 0.0461739384069902
# First 5 valid pixel values in Band 9: [0.274399995803833 0.274399995803833 0.274399995803833 0.274399995803833
#  0.274399995803833]
#
# Band 10 Statistics:
# Min: 0.003100000089034438
# Max: 1.207200050354004
# Mean: 0.22013853708166087
# Standard Deviation: 0.0502116337594054
# First 5 valid pixel values in Band 10: [0.2583000063896179 0.25929999351501465 0.25929999351501465
#  0.267300009727478 0.26489999890327454]
#
# Band 11 Statistics:
# Min: 0.00279999990016222
# Max: 1.2826000452041626
# Mean: 0.13649645241407468
# Standard Deviation: 0.048487074180429246
# First 5 valid pixel values in Band 11: [0.16429999470710754 0.1607999950647354 0.1607999950647354
#  0.17319999635219574 0.16380000114440918]
#
# Band 12 Statistics:
# Min: nan
# Max: nan
# Mean: nan
# Standard Deviation: --
# First 5 valid pixel values in Band 12: [nan nan nan nan nan]
#
# Band 13 Statistics:
# Min: -0.7527999877929688
# Max: 1.4007999897003174
# Mean: -0.03160639659036536
# Standard Deviation: 0.008454668495544717
# First 5 valid pixel values in Band 13: [-0.03539999946951866 -0.03830000013113022 -0.03539999946951866
#  -0.029999999329447746 -0.03689999878406525]
#
# Band 14 Statistics:
# Min: nan
# Max: nan
# Mean: nan
# Standard Deviation: --
# First 5 valid pixel values in Band 14: [nan nan nan nan nan]
#
# Band 15 Statistics:
# Min: nan
# Max: nan
# Mean: nan
# Standard Deviation: --
# First 5 valid pixel values in Band 15: [nan nan nan nan nan]
#
# Band 16 Statistics:
# Min: nan
# Max: nan
# Mean: nan
# Standard Deviation: --
# First 5 valid pixel values in Band 16: [nan nan nan nan nan]
#
# Band 17 Statistics:
# Min: -48.21072769165039
# Max: 120.12406158447266
# Mean: 0.002973162801936269
# Standard Deviation: 13.359848022460938
# First 5 valid pixel values in Band 17: [-48.206905 -48.20631  -48.205715 -48.205906 -48.2065  ]
#
# Band 18 Statistics:
# Min: -36.696598052978516
# Max: 28.38992691040039
# Mean: 0.0009384468430653214
# Standard Deviation: 6.762485980987549
# First 5 valid pixel values in Band 18: [-17.20273  -17.202951 -17.203173 -17.203102 -17.202879]
#
# Band 19 Statistics:
# Min: -12.046552658081055
# Max: 55.38852310180664
# Mean: 0.00012588796380441636
# Standard Deviation: 1.8232983350753784
# First 5 valid pixel values in Band 19: [-1.8718477 -1.871787  -1.871726  -1.8717456 -1.8718064]
#
# Band 20 Statistics:
# Min: -19.291601181030273
# Max: 5.249500751495361
# Mean: -7.502833614125848e-05
# Standard Deviation: 1.029328465461731
# First 5 valid pixel values in Band 20: [1.7123271 1.7123523 1.7123774 1.7123693 1.7123442]
#
# Band 21 Statistics:
# Min: -4.634456157684326
# Max: 7.983998775482178
# Mean: -8.394454198423773e-05
# Standard Deviation: 0.9180344939231873
# First 5 valid pixel values in Band 21: [2.5064054 2.5064409 2.5064762 2.506465  2.5064294]
#
# Band 22 Statistics:
# Min: -6.332432270050049
# Max: 29.4808406829834
# Mean: -2.202598778922038e-07
# Standard Deviation: 0.5827888250350952
# First 5 valid pixel values in Band 22: [0.23553129 0.2354875  0.23544373 0.2354578  0.23550157]
#
# Band 23 Statistics:
# Min: -14.263359069824219
# Max: 4.051198959350586
# Mean: 8.203611287171952e-06
# Standard Deviation: 0.3602721691131592
# First 5 valid pixel values in Band 23: [-0.02899035 -0.02898276 -0.02897517 -0.0289776  -0.02898519]
#
# Band 24 Statistics:
# Min: -4.431552410125732
# Max: 3.2261767387390137
# Mean: 1.4876341083436273e-05
# Standard Deviation: 0.2930449843406677
# First 5 valid pixel values in Band 24: [-0.03298124 -0.03299876 -0.03301628 -0.03301065 -0.03299313]
#
# Band 25 Statistics:
# Min: -2.250995397567749
# Max: 2.946110486984253
# Mean: 5.964708179817535e-06
# Standard Deviation: 0.24804159998893738
# First 5 valid pixel values in Band 25: [-0.03525374 -0.03523921 -0.03522468 -0.03522934 -0.03524388]
#
# Band 26 Statistics:
# Min: -2.300799608230591
# Max: 3.789971351623535
# Mean: -4.4224478301657655e-07
# Standard Deviation: 0.22079503536224365
# First 5 valid pixel values in Band 26: [-0.01750374 -0.01751369 -0.01752364 -0.01752044 -0.01751049]
#
# Band 27 Statistics:
# Min: -3.4994871616363525
# Max: 1.1566386222839355
# Mean: -3.0671009199068067e-07
# Standard Deviation: 0.15580667555332184
# First 5 valid pixel values in Band 27: [-0.00923789 -0.00924818 -0.00925847 -0.00925516 -0.00924487]
#
# Band 28 Statistics:
# Min: -3.0387086868286133
# Max: 1.5717277526855469
# Mean: -5.86611395192449e-06
# Standard Deviation: 0.1456952542066574
# First 5 valid pixel values in Band 28: [0.01288961 0.01284343 0.01279726 0.01281209 0.01285826]

# %% [markdown]
# ### Normalize bands to from 0-1

# %%
# Function to normalize bands
def min_max_normalize_with_nodata(bands, nodata_value=0, new_nodata_value=-9999):
    normalized_bands = np.full_like(bands, new_nodata_value, dtype=np.float32)

    for i in range(bands.shape[0]):  # Loop over each band
        band = bands[i, :, :]
        
        # Create a mask for NoData values
        valid_mask = band != nodata_value
        
        # Calculate min and max values only from valid data
        if valid_mask.any():
            min_val = band[valid_mask].min()
            max_val = band[valid_mask].max()
            
            # Avoid division by zero
            if min_val != max_val:
                normalized_band = np.where(valid_mask, (band - min_val) / (max_val - min_val), new_nodata_value)
            else:
                normalized_band = np.where(valid_mask, 1.0, new_nodata_value)
        else:
            normalized_band = np.full(band.shape, new_nodata_value, dtype=np.float32)
        
        normalized_bands[i, :, :] = normalized_band
    
    return normalized_bands

# Path to your TIFF file
tif_path = r'C:\Users\User\Documents\DataFusion\DataFusion\SimpleFusion\FusedImage\04102014fused_image.tif'
output_tif_path = r'C:\Users\User\Documents\DataFusion\DataFusion\Normalized_Image\Normalized_FusedImage.tif'

with rasterio.open(tif_path) as src:
    # Read the bands from the TIFF file
    bands = src.read()  # Read all bands
    meta = src.meta.copy()  # Copy metadata

# Normalize the bands while handling NoData values
fused_bands_normalized = min_max_normalize_with_nodata(bands, nodata_value=0, new_nodata_value=-9999)

# Update metadata for the output TIFF
meta.update({
    'dtype': 'float32',  # Update data type
    'count': fused_bands_normalized.shape[0],  # Number of bands
})

# Save the normalized data to a new TIFF file
with rasterio.open(output_tif_path, 'w', **meta) as dst:
    dst.write(fused_bands_normalized)

print(f'Normalized TIFF saved to {output_tif_path}')
# Out:
# Normalized TIFF saved to C:\Users\User\Documents\DataFusion\DataFusion\Normalized_Image\Normalized_FusedImage.tif

# %% [markdown]
# ### This code cell extracts pixel values

# %%
# Define paths
pntsshp_path = r'C:\Users\User\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\Train_Val\Training_data\train_shapefile.shp'

# Open shapefile and extract points' coordinates [0]= x coordinate, [1]= y coordinate and attributes
with fiona.open(pntsshp_path, 'r') as shapefile:
    points = [[(point['geometry']['coordinates'][0], point['geometry']['coordinates'][1]),
               (int(point['properties']['ID']), point['properties']['Val_id']),
               (point['properties']['X'], point['properties']['Y'])] for point in shapefile]

# Initialize dictionary to store band pixel values associated with each point
point_pixel_values = {}

# Open the raster image
with rasterio.open(output_tif_path) as src:
    imagename = os.path.splitext(os.path.basename(output_tif_path))[0]  # Remove the file extension
    
    # Iterate over each band in the image
    for band in range(1, src.count + 1):
        
        # Iterate over each point and extract pixel values
        for point in points:
            row, col = src.index(point[0][0], point[0][1])  # Find the point within the raster image
            values = src.read(band, window=((row, row+1), (col, col+1)))  # Read the band values

            if values.size != 0:  # Check if bands are valid/not empty
                # Prepare key for the current point
                point_key = f"Point_id: {point[1][1]}, X: {point[2][0]}, Y: {point[2][1]}, Class_ID: {point[1][0]}"
                if point_key not in point_pixel_values:
                    point_pixel_values[point_key] = {}

                # Add pixel values to the dictionary
                point_pixel_values[point_key][f'{imagename}_Band_{band}'] = values[0][0]

# Print point_pixel_values
for point_key, pixel_values in point_pixel_values.items():
    print(f"Point: {point_key}, Pixel Values: {pixel_values}")
# Out:
# Point: Point_id: VAL_2887, X: 29.04363001, Y: -31.00724936, Class_ID: 2, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.0072663217), 'Normalized_FusedImage_Band_2': np.float32(0.016991708), 'Normalized_FusedImage_Band_3': np.float32(0.013244633), 'Normalized_FusedImage_Band_4': np.float32(0.07099656), 'Normalized_FusedImage_Band_5': np.float32(0.20262377), 'Normalized_FusedImage_Band_6': np.float32(0.24329078), 'Normalized_FusedImage_Band_7': np.float32(0.13759135), 'Normalized_FusedImage_Band_8': np.float32(0.31130534), 'Normalized_FusedImage_Band_9': np.float32(0.4460419), 'Normalized_FusedImage_Band_10': np.float32(0.12175069), 'Normalized_FusedImage_Band_11': np.float32(0.056024376), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.34217125), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.18939239), 'Normalized_FusedImage_Band_18': np.float32(0.73729014), 'Normalized_FusedImage_Band_19': np.float32(0.19705409), 'Normalized_FusedImage_Band_20': np.float32(0.69057035), 'Normalized_FusedImage_Band_21': np.float32(0.43454546), 'Normalized_FusedImage_Band_22': np.float32(0.18786737), 'Normalized_FusedImage_Band_23': np.float32(0.8342222), 'Normalized_FusedImage_Band_24': np.float32(0.5366677), 'Normalized_FusedImage_Band_25': np.float32(0.46213052), 'Normalized_FusedImage_Band_26': np.float32(0.38541195), 'Normalized_FusedImage_Band_27': np.float32(0.69129443), 'Normalized_FusedImage_Band_28': np.float32(0.6035106)}
# Point: Point_id: NVAL254, X: 29.02381883, Y: -31.00773088, Class_ID: 2, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.005449741), 'Normalized_FusedImage_Band_2': np.float32(0.013780218), 'Normalized_FusedImage_Band_3': np.float32(0.0065920777), 'Normalized_FusedImage_Band_4': np.float32(0.049967434), 'Normalized_FusedImage_Band_5': np.float32(0.2091832), 'Normalized_FusedImage_Band_6': np.float32(0.2758653), 'Normalized_FusedImage_Band_7': np.float32(0.19046712), 'Normalized_FusedImage_Band_8': np.float32(0.35696343), 'Normalized_FusedImage_Band_9': np.float32(0.5525723), 'Normalized_FusedImage_Band_10': np.float32(0.08620546), 'Normalized_FusedImage_Band_11': np.float32(0.026879199), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3431928), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.18190208), 'Normalized_FusedImage_Band_18': np.float32(0.7952776), 'Normalized_FusedImage_Band_19': np.float32(0.19022189), 'Normalized_FusedImage_Band_20': np.float32(0.64316154), 'Normalized_FusedImage_Band_21': np.float32(0.48827723), 'Normalized_FusedImage_Band_22': np.float32(0.20026715), 'Normalized_FusedImage_Band_23': np.float32(0.85191447), 'Normalized_FusedImage_Band_24': np.float32(0.53908235), 'Normalized_FusedImage_Band_25': np.float32(0.39958313), 'Normalized_FusedImage_Band_26': np.float32(0.41315484), 'Normalized_FusedImage_Band_27': np.float32(0.65228516), 'Normalized_FusedImage_Band_28': np.float32(0.6867385)}
# Point: Point_id: None, X: 28.8769605, Y: -30.69760225, Class_ID: 7, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.020477816), 'Normalized_FusedImage_Band_2': np.float32(0.04688777), 'Normalized_FusedImage_Band_3': np.float32(0.042878743), 'Normalized_FusedImage_Band_4': np.float32(0.13678236), 'Normalized_FusedImage_Band_5': np.float32(0.2656124), 'Normalized_FusedImage_Band_6': np.float32(0.3047381), 'Normalized_FusedImage_Band_7': np.float32(0.21321894), 'Normalized_FusedImage_Band_8': np.float32(0.37312946), 'Normalized_FusedImage_Band_9': np.float32(0.5716265), 'Normalized_FusedImage_Band_10': np.float32(0.19375467), 'Normalized_FusedImage_Band_11': np.float32(0.11892483), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.32954124), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.3169959), 'Normalized_FusedImage_Band_18': np.float32(0.64019305), 'Normalized_FusedImage_Band_19': np.float32(0.18832366), 'Normalized_FusedImage_Band_20': np.float32(0.7492041), 'Normalized_FusedImage_Band_21': np.float32(0.49706128), 'Normalized_FusedImage_Band_22': np.float32(0.13908824), 'Normalized_FusedImage_Band_23': np.float32(0.7641085), 'Normalized_FusedImage_Band_24': np.float32(0.580333), 'Normalized_FusedImage_Band_25': np.float32(0.47089604), 'Normalized_FusedImage_Band_26': np.float32(0.46592027), 'Normalized_FusedImage_Band_27': np.float32(0.7600006), 'Normalized_FusedImage_Band_28': np.float32(0.6540181)}
# Point: Point_id: NVAL279, X: 29.11025967, Y: -30.90116542, Class_ID: 5, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.017174942), 'Normalized_FusedImage_Band_2': np.float32(0.04741329), 'Normalized_FusedImage_Band_3': np.float32(0.032839432), 'Normalized_FusedImage_Band_4': np.float32(0.13613102), 'Normalized_FusedImage_Band_5': np.float32(0.2611196), 'Normalized_FusedImage_Band_6': np.float32(0.305571), 'Normalized_FusedImage_Band_7': np.float32(0.20813474), 'Normalized_FusedImage_Band_8': np.float32(0.38186786), 'Normalized_FusedImage_Band_9': np.float32(0.60557765), 'Normalized_FusedImage_Band_10': np.float32(0.18735985), 'Normalized_FusedImage_Band_11': np.float32(0.08923268), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.32633728), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.27004623), 'Normalized_FusedImage_Band_18': np.float32(0.606878), 'Normalized_FusedImage_Band_19': np.float32(0.17774214), 'Normalized_FusedImage_Band_20': np.float32(0.8332227), 'Normalized_FusedImage_Band_21': np.float32(0.32124454), 'Normalized_FusedImage_Band_22': np.float32(0.15365402), 'Normalized_FusedImage_Band_23': np.float32(0.76757675), 'Normalized_FusedImage_Band_24': np.float32(0.60807735), 'Normalized_FusedImage_Band_25': np.float32(0.53671473), 'Normalized_FusedImage_Band_26': np.float32(0.34387156), 'Normalized_FusedImage_Band_27': np.float32(0.781345), 'Normalized_FusedImage_Band_28': np.float32(0.64361745)}
# Point: Point_id: VAL_2214, X: 29.1825931, Y: -30.81179621, Class_ID: 7, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.017174942), 'Normalized_FusedImage_Band_2': np.float32(0.03269882), 'Normalized_FusedImage_Band_3': np.float32(0.036951922), 'Normalized_FusedImage_Band_4': np.float32(0.086907975), 'Normalized_FusedImage_Band_5': np.float32(0.15338305), 'Normalized_FusedImage_Band_6': np.float32(0.17814176), 'Normalized_FusedImage_Band_7': np.float32(0.11738163), 'Normalized_FusedImage_Band_8': np.float32(0.22545058), 'Normalized_FusedImage_Band_9': np.float32(0.36670706), 'Normalized_FusedImage_Band_10': np.float32(0.159123), 'Normalized_FusedImage_Band_11': np.float32(0.08985778), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.33803862), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.30326888), 'Normalized_FusedImage_Band_18': np.float32(0.58448976), 'Normalized_FusedImage_Band_19': np.float32(0.18034692), 'Normalized_FusedImage_Band_20': np.float32(0.76240116), 'Normalized_FusedImage_Band_21': np.float32(0.39470086), 'Normalized_FusedImage_Band_22': np.float32(0.17506075), 'Normalized_FusedImage_Band_23': np.float32(0.76727265), 'Normalized_FusedImage_Band_24': np.float32(0.67806107), 'Normalized_FusedImage_Band_25': np.float32(0.38098365), 'Normalized_FusedImage_Band_26': np.float32(0.42618763), 'Normalized_FusedImage_Band_27': np.float32(0.806603), 'Normalized_FusedImage_Band_28': np.float32(0.7417226)}
# Point: Point_id: VAL_2236, X: 29.17297013, Y: -30.80211131, Class_ID: 4, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.02504679), 'Normalized_FusedImage_Band_2': np.float32(0.05383627), 'Normalized_FusedImage_Band_3': np.float32(0.043846387), 'Normalized_FusedImage_Band_4': np.float32(0.14450546), 'Normalized_FusedImage_Band_5': np.float32(0.32267052), 'Normalized_FusedImage_Band_6': np.float32(0.39552101), 'Normalized_FusedImage_Band_7': np.float32(0.2632984), 'Normalized_FusedImage_Band_8': np.float32(0.49929002), 'Normalized_FusedImage_Band_9': np.float32(0.71158844), 'Normalized_FusedImage_Band_10': np.float32(0.22705753), 'Normalized_FusedImage_Band_11': np.float32(0.123300515), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.32786962), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.40359113), 'Normalized_FusedImage_Band_18': np.float32(0.4596434), 'Normalized_FusedImage_Band_19': np.float32(0.3327838), 'Normalized_FusedImage_Band_20': np.float32(0.86857325), 'Normalized_FusedImage_Band_21': np.float32(0.44920108), 'Normalized_FusedImage_Band_22': np.float32(0.17115377), 'Normalized_FusedImage_Band_23': np.float32(0.84842014), 'Normalized_FusedImage_Band_24': np.float32(0.684121), 'Normalized_FusedImage_Band_25': np.float32(0.325496), 'Normalized_FusedImage_Band_26': np.float32(0.31063193), 'Normalized_FusedImage_Band_27': np.float32(0.8681922), 'Normalized_FusedImage_Band_28': np.float32(0.6837638)}
# Point: Point_id: VAL_3167, X: 29.00564829, Y: -30.88214972, Class_ID: 8, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.15094131), 'Normalized_FusedImage_Band_2': np.float32(0.15380123), 'Normalized_FusedImage_Band_3': np.float32(0.13492592), 'Normalized_FusedImage_Band_4': np.float32(0.19847399), 'Normalized_FusedImage_Band_5': np.float32(0.23353401), 'Normalized_FusedImage_Band_6': np.float32(0.25763464), 'Normalized_FusedImage_Band_7': np.float32(0.17051162), 'Normalized_FusedImage_Band_8': np.float32(0.32168218), 'Normalized_FusedImage_Band_9': np.float32(0.54304516), 'Normalized_FusedImage_Band_10': np.float32(0.23087783), 'Normalized_FusedImage_Band_11': np.float32(0.21370527), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3545691), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.49767014), 'Normalized_FusedImage_Band_18': np.float32(0.3197759), 'Normalized_FusedImage_Band_19': np.float32(0.40090987), 'Normalized_FusedImage_Band_20': np.float32(0.71341956), 'Normalized_FusedImage_Band_21': np.float32(0.44874695), 'Normalized_FusedImage_Band_22': np.float32(0.42705524), 'Normalized_FusedImage_Band_23': np.float32(0.5824619), 'Normalized_FusedImage_Band_24': np.float32(0.6523774), 'Normalized_FusedImage_Band_25': np.float32(0.4398414), 'Normalized_FusedImage_Band_26': np.float32(0.33800623), 'Normalized_FusedImage_Band_27': np.float32(0.7010051), 'Normalized_FusedImage_Band_28': np.float32(0.5191383)}
# Point: Point_id: None, X: 28.87735908, Y: -30.69680145, Class_ID: 7, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.020312672), 'Normalized_FusedImage_Band_2': np.float32(0.046245474), 'Normalized_FusedImage_Band_3': np.float32(0.0446326), 'Normalized_FusedImage_Band_4': np.float32(0.13845724), 'Normalized_FusedImage_Band_5': np.float32(0.2492587), 'Normalized_FusedImage_Band_6': np.float32(0.2907644), 'Normalized_FusedImage_Band_7': np.float32(0.20305052), 'Normalized_FusedImage_Band_8': np.float32(0.35477883), 'Normalized_FusedImage_Band_9': np.float32(0.56019396), 'Normalized_FusedImage_Band_10': np.float32(0.20521551), 'Normalized_FusedImage_Band_11': np.float32(0.12962961), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.32991272), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.32079613), 'Normalized_FusedImage_Band_18': np.float32(0.6700828), 'Normalized_FusedImage_Band_19': np.float32(0.19304971), 'Normalized_FusedImage_Band_20': np.float32(0.73905456), 'Normalized_FusedImage_Band_21': np.float32(0.5319877), 'Normalized_FusedImage_Band_22': np.float32(0.13732266), 'Normalized_FusedImage_Band_23': np.float32(0.7650755), 'Normalized_FusedImage_Band_24': np.float32(0.58242065), 'Normalized_FusedImage_Band_25': np.float32(0.49711472), 'Normalized_FusedImage_Band_26': np.float32(0.46594757), 'Normalized_FusedImage_Band_27': np.float32(0.7387434), 'Normalized_FusedImage_Band_28': np.float32(0.6399249)}
# Point: Point_id: VAL_359, X: 29.14022165, Y: -30.93691823, Class_ID: 4, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.04750633), 'Normalized_FusedImage_Band_2': np.float32(0.07625832), 'Normalized_FusedImage_Band_3': np.float32(0.10275174), 'Normalized_FusedImage_Band_4': np.float32(0.16962874), 'Normalized_FusedImage_Band_5': np.float32(0.17162368), 'Normalized_FusedImage_Band_6': np.float32(0.18461965), 'Normalized_FusedImage_Band_7': np.float32(0.12856689), 'Normalized_FusedImage_Band_8': np.float32(0.21922447), 'Normalized_FusedImage_Band_9': np.float32(0.32703966), 'Normalized_FusedImage_Band_10': np.float32(0.1783905), 'Normalized_FusedImage_Band_11': np.float32(0.15049225), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.32898402), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.335086), 'Normalized_FusedImage_Band_18': np.float32(0.33421704), 'Normalized_FusedImage_Band_19': np.float32(0.30060828), 'Normalized_FusedImage_Band_20': np.float32(0.7140398), 'Normalized_FusedImage_Band_21': np.float32(0.45954347), 'Normalized_FusedImage_Band_22': np.float32(0.16749106), 'Normalized_FusedImage_Band_23': np.float32(0.74804467), 'Normalized_FusedImage_Band_24': np.float32(0.49310672), 'Normalized_FusedImage_Band_25': np.float32(0.43654704), 'Normalized_FusedImage_Band_26': np.float32(0.3738533), 'Normalized_FusedImage_Band_27': np.float32(0.736483), 'Normalized_FusedImage_Band_28': np.float32(0.6395413)}
# Point: Point_id: None, X: 28.9919507, Y: -30.76609343, Class_ID: 6, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.011009579), 'Normalized_FusedImage_Band_2': np.float32(0.022772394), 'Normalized_FusedImage_Band_3': np.float32(0.013426066), 'Normalized_FusedImage_Band_4': np.float32(0.05890016), 'Normalized_FusedImage_Band_5': np.float32(0.17117439), 'Normalized_FusedImage_Band_6': np.float32(0.21700905), 'Normalized_FusedImage_Band_7': np.float32(0.15055609), 'Normalized_FusedImage_Band_8': np.float32(0.28115785), 'Normalized_FusedImage_Band_9': np.float32(0.4460419), 'Normalized_FusedImage_Band_10': np.float32(0.12739806), 'Normalized_FusedImage_Band_11': np.float32(0.06000937), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3407318), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.24919885), 'Normalized_FusedImage_Band_18': np.float32(0.5700422), 'Normalized_FusedImage_Band_19': np.float32(0.1511499), 'Normalized_FusedImage_Band_20': np.float32(0.81689763), 'Normalized_FusedImage_Band_21': np.float32(0.25353795), 'Normalized_FusedImage_Band_22': np.float32(0.17746004), 'Normalized_FusedImage_Band_23': np.float32(0.77621233), 'Normalized_FusedImage_Band_24': np.float32(0.569548), 'Normalized_FusedImage_Band_25': np.float32(0.42231378), 'Normalized_FusedImage_Band_26': np.float32(0.37329128), 'Normalized_FusedImage_Band_27': np.float32(0.8065587), 'Normalized_FusedImage_Band_28': np.float32(0.59695345)}
# Point: Point_id: None, X: 29.18245905, Y: -30.78250913, Class_ID: 5, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.023395354), 'Normalized_FusedImage_Band_2': np.float32(0.051267076), 'Normalized_FusedImage_Band_3': np.float32(0.035500456), 'Normalized_FusedImage_Band_4': np.float32(0.11807947), 'Normalized_FusedImage_Band_5': np.float32(0.29185012), 'Normalized_FusedImage_Band_6': np.float32(0.35332224), 'Normalized_FusedImage_Band_7': np.float32(0.24448681), 'Normalized_FusedImage_Band_8': np.float32(0.44598582), 'Normalized_FusedImage_Band_9': np.float32(0.66326), 'Normalized_FusedImage_Band_10': np.float32(0.18951914), 'Normalized_FusedImage_Band_11': np.float32(0.09001406), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.32851967), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.33165646), 'Normalized_FusedImage_Band_18': np.float32(0.7602146), 'Normalized_FusedImage_Band_19': np.float32(0.18092008), 'Normalized_FusedImage_Band_20': np.float32(0.8445742), 'Normalized_FusedImage_Band_21': np.float32(0.443577), 'Normalized_FusedImage_Band_22': np.float32(0.16953783), 'Normalized_FusedImage_Band_23': np.float32(0.79406196), 'Normalized_FusedImage_Band_24': np.float32(0.5618481), 'Normalized_FusedImage_Band_25': np.float32(0.50163794), 'Normalized_FusedImage_Band_26': np.float32(0.35440385), 'Normalized_FusedImage_Band_27': np.float32(0.7744901), 'Normalized_FusedImage_Band_28': np.float32(0.67481977)}
# Point: Point_id: None, X: 28.87756994, Y: -30.69763057, Class_ID: 7, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.01849609), 'Normalized_FusedImage_Band_2': np.float32(0.04262525), 'Normalized_FusedImage_Band_3': np.float32(0.033444207), 'Normalized_FusedImage_Band_4': np.float32(0.12729134), 'Normalized_FusedImage_Band_5': np.float32(0.26183844), 'Normalized_FusedImage_Band_6': np.float32(0.29853785), 'Normalized_FusedImage_Band_7': np.float32(0.2094058), 'Normalized_FusedImage_Band_8': np.float32(0.37323868), 'Normalized_FusedImage_Band_9': np.float32(0.5700675), 'Normalized_FusedImage_Band_10': np.float32(0.19018354), 'Normalized_FusedImage_Band_11': np.float32(0.10923581), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.33125928), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.30976436), 'Normalized_FusedImage_Band_18': np.float32(0.66440994), 'Normalized_FusedImage_Band_19': np.float32(0.18105826), 'Normalized_FusedImage_Band_20': np.float32(0.7368228), 'Normalized_FusedImage_Band_21': np.float32(0.5096867), 'Normalized_FusedImage_Band_22': np.float32(0.13917054), 'Normalized_FusedImage_Band_23': np.float32(0.7615038), 'Normalized_FusedImage_Band_24': np.float32(0.5593937), 'Normalized_FusedImage_Band_25': np.float32(0.4967503), 'Normalized_FusedImage_Band_26': np.float32(0.4694815), 'Normalized_FusedImage_Band_27': np.float32(0.7527189), 'Normalized_FusedImage_Band_28': np.float32(0.63115126)}
# Point: Point_id: VAL_4646, X: 28.98980557, Y: -30.98547278, Class_ID: 1, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.009192998), 'Normalized_FusedImage_Band_2': np.float32(0.025867103), 'Normalized_FusedImage_Band_3': np.float32(0.010825521), 'Normalized_FusedImage_Band_4': np.float32(0.06708849), 'Normalized_FusedImage_Band_5': np.float32(0.24332826), 'Normalized_FusedImage_Band_6': np.float32(0.29918563), 'Normalized_FusedImage_Band_7': np.float32(0.21830316), 'Normalized_FusedImage_Band_8': np.float32(0.37651557), 'Normalized_FusedImage_Band_9': np.float32(0.6253248), 'Normalized_FusedImage_Band_10': np.float32(0.11593722), 'Normalized_FusedImage_Band_11': np.float32(0.04469448), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3367385), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.17854089), 'Normalized_FusedImage_Band_18': np.float32(0.7121302), 'Normalized_FusedImage_Band_19': np.float32(0.19653596), 'Normalized_FusedImage_Band_20': np.float32(0.7084963), 'Normalized_FusedImage_Band_21': np.float32(0.3932153), 'Normalized_FusedImage_Band_22': np.float32(0.18664226), 'Normalized_FusedImage_Band_23': np.float32(0.795899), 'Normalized_FusedImage_Band_24': np.float32(0.5909605), 'Normalized_FusedImage_Band_25': np.float32(0.46785676), 'Normalized_FusedImage_Band_26': np.float32(0.36355904), 'Normalized_FusedImage_Band_27': np.float32(0.72905236), 'Normalized_FusedImage_Band_28': np.float32(0.6551469)}
# Point: Point_id: None, X: 28.99103016, Y: -30.7661988, Class_ID: 6, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.01178025), 'Normalized_FusedImage_Band_2': np.float32(0.02493285), 'Normalized_FusedImage_Band_3': np.float32(0.013909888), 'Normalized_FusedImage_Band_4': np.float32(0.06383177), 'Normalized_FusedImage_Band_5': np.float32(0.17836283), 'Normalized_FusedImage_Band_6': np.float32(0.22108087), 'Normalized_FusedImage_Band_7': np.float32(0.15754686), 'Normalized_FusedImage_Band_8': np.float32(0.2865101), 'Normalized_FusedImage_Band_9': np.float32(0.45695478), 'Normalized_FusedImage_Band_10': np.float32(0.12565403), 'Normalized_FusedImage_Band_11': np.float32(0.057587117), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3396638), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.24215212), 'Normalized_FusedImage_Band_18': np.float32(0.59804547), 'Normalized_FusedImage_Band_19': np.float32(0.1581695), 'Normalized_FusedImage_Band_20': np.float32(0.8037455), 'Normalized_FusedImage_Band_21': np.float32(0.2797015), 'Normalized_FusedImage_Band_22': np.float32(0.17683218), 'Normalized_FusedImage_Band_23': np.float32(0.78230995), 'Normalized_FusedImage_Band_24': np.float32(0.5838447), 'Normalized_FusedImage_Band_25': np.float32(0.4317209), 'Normalized_FusedImage_Band_26': np.float32(0.36272332), 'Normalized_FusedImage_Band_27': np.float32(0.80332977), 'Normalized_FusedImage_Band_28': np.float32(0.6036525)}
# Point: Point_id: NVAL_323, X: 28.98671738, Y: -30.98619987, Class_ID: 1, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.008257184), 'Normalized_FusedImage_Band_2': np.float32(0.024582507), 'Normalized_FusedImage_Band_3': np.float32(0.009736923), 'Normalized_FusedImage_Band_4': np.float32(0.06383177), 'Normalized_FusedImage_Band_5': np.float32(0.2391949), 'Normalized_FusedImage_Band_6': np.float32(0.29585415), 'Normalized_FusedImage_Band_7': np.float32(0.20305052), 'Normalized_FusedImage_Band_8': np.float32(0.36439106), 'Normalized_FusedImage_Band_9': np.float32(0.61579764), 'Normalized_FusedImage_Band_10': np.float32(0.10439333), 'Normalized_FusedImage_Band_11': np.float32(0.03938115), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.33697063), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.18398562), 'Normalized_FusedImage_Band_18': np.float32(0.7247723), 'Normalized_FusedImage_Band_19': np.float32(0.19638963), 'Normalized_FusedImage_Band_20': np.float32(0.72016704), 'Normalized_FusedImage_Band_21': np.float32(0.39351717), 'Normalized_FusedImage_Band_22': np.float32(0.18549187), 'Normalized_FusedImage_Band_23': np.float32(0.7903974), 'Normalized_FusedImage_Band_24': np.float32(0.6069863), 'Normalized_FusedImage_Band_25': np.float32(0.46955425), 'Normalized_FusedImage_Band_26': np.float32(0.3667606), 'Normalized_FusedImage_Band_27': np.float32(0.73429024), 'Normalized_FusedImage_Band_28': np.float32(0.6221906)}
# Point: Point_id: VAL_214, X: 29.11073321, Y: -30.81655014, Class_ID: 6, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.013486735), 'Normalized_FusedImage_Band_2': np.float32(0.035384797), 'Normalized_FusedImage_Band_3': np.float32(0.022497732), 'Normalized_FusedImage_Band_4': np.float32(0.08541919), 'Normalized_FusedImage_Band_5': np.float32(0.22832242), 'Normalized_FusedImage_Band_6': np.float32(0.2712382), 'Normalized_FusedImage_Band_7': np.float32(0.18665396), 'Normalized_FusedImage_Band_8': np.float32(0.3437466), 'Normalized_FusedImage_Band_9': np.float32(0.5168889), 'Normalized_FusedImage_Band_10': np.float32(0.13553692), 'Normalized_FusedImage_Band_11': np.float32(0.063838094), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3327916), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.16830026), 'Normalized_FusedImage_Band_18': np.float32(0.5635961), 'Normalized_FusedImage_Band_19': np.float32(0.19974358), 'Normalized_FusedImage_Band_20': np.float32(0.7614976), 'Normalized_FusedImage_Band_21': np.float32(0.27822682), 'Normalized_FusedImage_Band_22': np.float32(0.16372639), 'Normalized_FusedImage_Band_23': np.float32(0.7692821), 'Normalized_FusedImage_Band_24': np.float32(0.5927021), 'Normalized_FusedImage_Band_25': np.float32(0.4279798), 'Normalized_FusedImage_Band_26': np.float32(0.3575592), 'Normalized_FusedImage_Band_27': np.float32(0.7291284), 'Normalized_FusedImage_Band_28': np.float32(0.66372424)}
# Point: Point_id: NVAL269, X: 28.97918246, Y: -30.80797809, Class_ID: 3, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.010734339), 'Normalized_FusedImage_Band_2': np.float32(0.021312624), 'Normalized_FusedImage_Band_3': np.float32(0.013184155), 'Normalized_FusedImage_Band_4': np.float32(0.04912999), 'Normalized_FusedImage_Band_5': np.float32(0.17935124), 'Normalized_FusedImage_Band_6': np.float32(0.21839719), 'Normalized_FusedImage_Band_7': np.float32(0.1585637), 'Normalized_FusedImage_Band_8': np.float32(0.27897325), 'Normalized_FusedImage_Band_9': np.float32(0.4356487), 'Normalized_FusedImage_Band_10': np.float32(0.09592227), 'Normalized_FusedImage_Band_11': np.float32(0.038677916), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.34166047), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.2025473), 'Normalized_FusedImage_Band_18': np.float32(0.669271), 'Normalized_FusedImage_Band_19': np.float32(0.20418483), 'Normalized_FusedImage_Band_20': np.float32(0.7577506), 'Normalized_FusedImage_Band_21': np.float32(0.3338711), 'Normalized_FusedImage_Band_22': np.float32(0.20980488), 'Normalized_FusedImage_Band_23': np.float32(0.7980602), 'Normalized_FusedImage_Band_24': np.float32(0.53511643), 'Normalized_FusedImage_Band_25': np.float32(0.38435343), 'Normalized_FusedImage_Band_26': np.float32(0.37230045), 'Normalized_FusedImage_Band_27': np.float32(0.76595086), 'Normalized_FusedImage_Band_28': np.float32(0.67272097)}
# Point: Point_id: VAL_214, X: 29.10792721, Y: -30.8162265, Class_ID: 6, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.0105141485), 'Normalized_FusedImage_Band_2': np.float32(0.028261123), 'Normalized_FusedImage_Band_3': np.float32(0.017054733), 'Normalized_FusedImage_Band_4': np.float32(0.07797525), 'Normalized_FusedImage_Band_5': np.float32(0.22257164), 'Normalized_FusedImage_Band_6': np.float32(0.27438462), 'Normalized_FusedImage_Band_7': np.float32(0.18830633), 'Normalized_FusedImage_Band_8': np.float32(0.33555436), 'Normalized_FusedImage_Band_9': np.float32(0.5369825), 'Normalized_FusedImage_Band_10': np.float32(0.13304542), 'Normalized_FusedImage_Band_11': np.float32(0.06157212), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.33594912), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.14096719), 'Normalized_FusedImage_Band_18': np.float32(0.5378356), 'Normalized_FusedImage_Band_19': np.float32(0.19600639), 'Normalized_FusedImage_Band_20': np.float32(0.7560785), 'Normalized_FusedImage_Band_21': np.float32(0.24951145), 'Normalized_FusedImage_Band_22': np.float32(0.15438677), 'Normalized_FusedImage_Band_23': np.float32(0.7685819), 'Normalized_FusedImage_Band_24': np.float32(0.5674254), 'Normalized_FusedImage_Band_25': np.float32(0.42388257), 'Normalized_FusedImage_Band_26': np.float32(0.3483505), 'Normalized_FusedImage_Band_27': np.float32(0.73402125), 'Normalized_FusedImage_Band_28': np.float32(0.6508168)}
# Point: Point_id: None, X: 29.1255999, Y: -30.89673122, Class_ID: 4, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.044258505), 'Normalized_FusedImage_Band_2': np.float32(0.072988436), 'Normalized_FusedImage_Band_3': np.float32(0.08993045), 'Normalized_FusedImage_Band_4': np.float32(0.14683168), 'Normalized_FusedImage_Band_5': np.float32(0.17719471), 'Normalized_FusedImage_Band_6': np.float32(0.19516934), 'Normalized_FusedImage_Band_7': np.float32(0.13314267), 'Normalized_FusedImage_Band_8': np.float32(0.25046423), 'Normalized_FusedImage_Band_9': np.float32(0.39927247), 'Normalized_FusedImage_Band_10': np.float32(0.23104393), 'Normalized_FusedImage_Band_11': np.float32(0.15768088), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.32884473), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.4381578), 'Normalized_FusedImage_Band_18': np.float32(0.37953714), 'Normalized_FusedImage_Band_19': np.float32(0.2573019), 'Normalized_FusedImage_Band_20': np.float32(0.80039614), 'Normalized_FusedImage_Band_21': np.float32(0.45486853), 'Normalized_FusedImage_Band_22': np.float32(0.1639253), 'Normalized_FusedImage_Band_23': np.float32(0.8363549), 'Normalized_FusedImage_Band_24': np.float32(0.6356961), 'Normalized_FusedImage_Band_25': np.float32(0.28333932), 'Normalized_FusedImage_Band_26': np.float32(0.32917303), 'Normalized_FusedImage_Band_27': np.float32(0.82782817), 'Normalized_FusedImage_Band_28': np.float32(0.6102041)}
# Point: Point_id: None, X: 28.99825737, Y: -30.8937315, Class_ID: 8, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.06825939), 'Normalized_FusedImage_Band_2': np.float32(0.09062244), 'Normalized_FusedImage_Band_3': np.float32(0.11037195), 'Normalized_FusedImage_Band_4': np.float32(0.1799572), 'Normalized_FusedImage_Band_5': np.float32(0.22760357), 'Normalized_FusedImage_Band_6': np.float32(0.24162504), 'Normalized_FusedImage_Band_7': np.float32(0.15271688), 'Normalized_FusedImage_Band_8': np.float32(0.30092847), 'Normalized_FusedImage_Band_9': np.float32(0.476009), 'Normalized_FusedImage_Band_10': np.float32(0.19807325), 'Normalized_FusedImage_Band_11': np.float32(0.15393029), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.33506685), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.45773456), 'Normalized_FusedImage_Band_18': np.float32(0.4262288), 'Normalized_FusedImage_Band_19': np.float32(0.34171608), 'Normalized_FusedImage_Band_20': np.float32(0.74372077), 'Normalized_FusedImage_Band_21': np.float32(0.5135662), 'Normalized_FusedImage_Band_22': np.float32(0.29384223), 'Normalized_FusedImage_Band_23': np.float32(0.66603625), 'Normalized_FusedImage_Band_24': np.float32(0.5629581), 'Normalized_FusedImage_Band_25': np.float32(0.58728695), 'Normalized_FusedImage_Band_26': np.float32(0.43478128), 'Normalized_FusedImage_Band_27': np.float32(0.76364064), 'Normalized_FusedImage_Band_28': np.float32(0.68349725)}
# Point: Point_id: None, X: 29.12677633, Y: -30.89731663, Class_ID: 4, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.044588793), 'Normalized_FusedImage_Band_2': np.float32(0.07941142), 'Normalized_FusedImage_Band_3': np.float32(0.10359842), 'Normalized_FusedImage_Band_4': np.float32(0.17763096), 'Normalized_FusedImage_Band_5': np.float32(0.18078892), 'Normalized_FusedImage_Band_6': np.float32(0.20016657), 'Normalized_FusedImage_Band_7': np.float32(0.12755005), 'Normalized_FusedImage_Band_8': np.float32(0.23779356), 'Normalized_FusedImage_Band_9': np.float32(0.39494196), 'Normalized_FusedImage_Band_10': np.float32(0.22672535), 'Normalized_FusedImage_Band_11': np.float32(0.16838567), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3240156), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.4586793), 'Normalized_FusedImage_Band_18': np.float32(0.35306492), 'Normalized_FusedImage_Band_19': np.float32(0.29797783), 'Normalized_FusedImage_Band_20': np.float32(0.8053683), 'Normalized_FusedImage_Band_21': np.float32(0.5140052), 'Normalized_FusedImage_Band_22': np.float32(0.13947158), 'Normalized_FusedImage_Band_23': np.float32(0.85175675), 'Normalized_FusedImage_Band_24': np.float32(0.63835293), 'Normalized_FusedImage_Band_25': np.float32(0.24866042), 'Normalized_FusedImage_Band_26': np.float32(0.2958682), 'Normalized_FusedImage_Band_27': np.float32(0.8898723), 'Normalized_FusedImage_Band_28': np.float32(0.6310105)}
# Point: Point_id: NVAL_328, X: 28.99051952, Y: -30.98598001, Class_ID: 1, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.0086975675), 'Normalized_FusedImage_Band_2': np.float32(0.02656779), 'Normalized_FusedImage_Band_3': np.float32(0.009736923), 'Normalized_FusedImage_Band_4': np.float32(0.07555597), 'Normalized_FusedImage_Band_5': np.float32(0.27971965), 'Normalized_FusedImage_Band_6': np.float32(0.33916345), 'Normalized_FusedImage_Band_7': np.float32(0.23558944), 'Normalized_FusedImage_Band_8': np.float32(0.42905518), 'Normalized_FusedImage_Band_9': np.float32(0.615278), 'Normalized_FusedImage_Band_10': np.float32(0.12349474), 'Normalized_FusedImage_Band_11': np.float32(0.045710266), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.33576337), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.19217582), 'Normalized_FusedImage_Band_18': np.float32(0.7357811), 'Normalized_FusedImage_Band_19': np.float32(0.19414078), 'Normalized_FusedImage_Band_20': np.float32(0.71815014), 'Normalized_FusedImage_Band_21': np.float32(0.40630394), 'Normalized_FusedImage_Band_22': np.float32(0.18740422), 'Normalized_FusedImage_Band_23': np.float32(0.7971306), 'Normalized_FusedImage_Band_24': np.float32(0.59964794), 'Normalized_FusedImage_Band_25': np.float32(0.47102904), 'Normalized_FusedImage_Band_26': np.float32(0.37172246), 'Normalized_FusedImage_Band_27': np.float32(0.7242635), 'Normalized_FusedImage_Band_28': np.float32(0.63802356)}
# Point: Point_id: NVAL_322, X: 28.98836376, Y: -30.98617777, Class_ID: 1, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.008477376), 'Normalized_FusedImage_Band_2': np.float32(0.02627584), 'Normalized_FusedImage_Band_3': np.float32(0.010704566), 'Normalized_FusedImage_Band_4': np.float32(0.073043644), 'Normalized_FusedImage_Band_5': np.float32(0.27962983), 'Normalized_FusedImage_Band_6': np.float32(0.33888578), 'Normalized_FusedImage_Band_7': np.float32(0.23279314), 'Normalized_FusedImage_Band_8': np.float32(0.41616604), 'Normalized_FusedImage_Band_9': np.float32(0.58894855), 'Normalized_FusedImage_Band_10': np.float32(0.12665062), 'Normalized_FusedImage_Band_11': np.float32(0.046491638), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3358098), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.19077733), 'Normalized_FusedImage_Band_18': np.float32(0.72160125), 'Normalized_FusedImage_Band_19': np.float32(0.1944453), 'Normalized_FusedImage_Band_20': np.float32(0.7228068), 'Normalized_FusedImage_Band_21': np.float32(0.39582452), 'Normalized_FusedImage_Band_22': np.float32(0.18381196), 'Normalized_FusedImage_Band_23': np.float32(0.7910292), 'Normalized_FusedImage_Band_24': np.float32(0.6152455), 'Normalized_FusedImage_Band_25': np.float32(0.47041968), 'Normalized_FusedImage_Band_26': np.float32(0.36446413), 'Normalized_FusedImage_Band_27': np.float32(0.73457325), 'Normalized_FusedImage_Band_28': np.float32(0.64562684)}
# Point: Point_id: NVAL284, X: 29.02276709, Y: -31.00594329, Class_ID: 2, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.0064406036), 'Normalized_FusedImage_Band_2': np.float32(0.015823893), 'Normalized_FusedImage_Band_3': np.float32(0.009071667), 'Normalized_FusedImage_Band_4': np.float32(0.044663627), 'Normalized_FusedImage_Band_5': np.float32(0.20145565), 'Normalized_FusedImage_Band_6': np.float32(0.26642606), 'Normalized_FusedImage_Band_7': np.float32(0.1972037), 'Normalized_FusedImage_Band_8': np.float32(0.344402), 'Normalized_FusedImage_Band_9': np.float32(0.5485882), 'Normalized_FusedImage_Band_10': np.float32(0.098912045), 'Normalized_FusedImage_Band_11': np.float32(0.03469292), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3424034), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.18688408), 'Normalized_FusedImage_Band_18': np.float32(0.79547244), 'Normalized_FusedImage_Band_19': np.float32(0.18402092), 'Normalized_FusedImage_Band_20': np.float32(0.65239316), 'Normalized_FusedImage_Band_21': np.float32(0.4773059), 'Normalized_FusedImage_Band_22': np.float32(0.20150794), 'Normalized_FusedImage_Band_23': np.float32(0.84707433), 'Normalized_FusedImage_Band_24': np.float32(0.54386455), 'Normalized_FusedImage_Band_25': np.float32(0.4119977), 'Normalized_FusedImage_Band_26': np.float32(0.41015685), 'Normalized_FusedImage_Band_27': np.float32(0.67470866), 'Normalized_FusedImage_Band_28': np.float32(0.68207836)}
# Point: Point_id: None, X: 29.18139839, Y: -30.78257611, Class_ID: 5, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.024881648), 'Normalized_FusedImage_Band_2': np.float32(0.05547121), 'Normalized_FusedImage_Band_3': np.float32(0.038766254), 'Normalized_FusedImage_Band_4': np.float32(0.14766912), 'Normalized_FusedImage_Band_5': np.float32(0.31808788), 'Normalized_FusedImage_Band_6': np.float32(0.37192303), 'Normalized_FusedImage_Band_7': np.float32(0.25516364), 'Normalized_FusedImage_Band_8': np.float32(0.4590934), 'Normalized_FusedImage_Band_9': np.float32(0.7330677), 'Normalized_FusedImage_Band_10': np.float32(0.19217674), 'Normalized_FusedImage_Band_11': np.float32(0.093217686), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.32643017), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.31865174), 'Normalized_FusedImage_Band_18': np.float32(0.7774895), 'Normalized_FusedImage_Band_19': np.float32(0.1903312), 'Normalized_FusedImage_Band_20': np.float32(0.83211136), 'Normalized_FusedImage_Band_21': np.float32(0.46658862), 'Normalized_FusedImage_Band_22': np.float32(0.16051172), 'Normalized_FusedImage_Band_23': np.float32(0.79071903), 'Normalized_FusedImage_Band_24': np.float32(0.5857493), 'Normalized_FusedImage_Band_25': np.float32(0.5437445), 'Normalized_FusedImage_Band_26': np.float32(0.33819506), 'Normalized_FusedImage_Band_27': np.float32(0.7648439), 'Normalized_FusedImage_Band_28': np.float32(0.6526644)}
# Point: Point_id: None, X: 28.87749369, Y: -30.69703765, Class_ID: 7, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.021798965), 'Normalized_FusedImage_Band_2': np.float32(0.045428004), 'Normalized_FusedImage_Band_3': np.float32(0.051466584), 'Normalized_FusedImage_Band_4': np.float32(0.14087652), 'Normalized_FusedImage_Band_5': np.float32(0.24997753), 'Normalized_FusedImage_Band_6': np.float32(0.287618), 'Normalized_FusedImage_Band_7': np.float32(0.19313632), 'Normalized_FusedImage_Band_8': np.float32(0.35314038), 'Normalized_FusedImage_Band_9': np.float32(0.56019396), 'Normalized_FusedImage_Band_10': np.float32(0.21019846), 'Normalized_FusedImage_Band_11': np.float32(0.13892795), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3318165), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.32195207), 'Normalized_FusedImage_Band_18': np.float32(0.66235745), 'Normalized_FusedImage_Band_19': np.float32(0.18422242), 'Normalized_FusedImage_Band_20': np.float32(0.73086387), 'Normalized_FusedImage_Band_21': np.float32(0.5324833), 'Normalized_FusedImage_Band_22': np.float32(0.13538988), 'Normalized_FusedImage_Band_23': np.float32(0.76138836), 'Normalized_FusedImage_Band_24': np.float32(0.571644), 'Normalized_FusedImage_Band_25': np.float32(0.4991283), 'Normalized_FusedImage_Band_26': np.float32(0.47978753), 'Normalized_FusedImage_Band_27': np.float32(0.7419558), 'Normalized_FusedImage_Band_28': np.float32(0.6352658)}
# Point: Point_id: VAL_2905, X: 29.18148151, Y: -30.8092243, Class_ID: 7, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.014917979), 'Normalized_FusedImage_Band_2': np.float32(0.027793998), 'Normalized_FusedImage_Band_3': np.float32(0.033020865), 'Normalized_FusedImage_Band_4': np.float32(0.07536987), 'Normalized_FusedImage_Band_5': np.float32(0.12606704), 'Normalized_FusedImage_Band_6': np.float32(0.14454931), 'Normalized_FusedImage_Band_7': np.float32(0.10289164), 'Normalized_FusedImage_Band_8': np.float32(0.19268158), 'Normalized_FusedImage_Band_9': np.float32(0.36843926), 'Normalized_FusedImage_Band_10': np.float32(0.14666556), 'Normalized_FusedImage_Band_11': np.float32(0.083528675), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3400353), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.30445498), 'Normalized_FusedImage_Band_18': np.float32(0.54973483), 'Normalized_FusedImage_Band_19': np.float32(0.1749417), 'Normalized_FusedImage_Band_20': np.float32(0.7537942), 'Normalized_FusedImage_Band_21': np.float32(0.39401045), 'Normalized_FusedImage_Band_22': np.float32(0.16304079), 'Normalized_FusedImage_Band_23': np.float32(0.7677644), 'Normalized_FusedImage_Band_24': np.float32(0.62739587), 'Normalized_FusedImage_Band_25': np.float32(0.40151468), 'Normalized_FusedImage_Band_26': np.float32(0.39127362), 'Normalized_FusedImage_Band_27': np.float32(0.8056601), 'Normalized_FusedImage_Band_28': np.float32(0.6634696)}
# Point: Point_id: None, X: 28.99826451, Y: -30.89437101, Class_ID: 8, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.020808103), 'Normalized_FusedImage_Band_2': np.float32(0.039238583), 'Normalized_FusedImage_Band_3': np.float32(0.094163895), 'Normalized_FusedImage_Band_4': np.float32(0.16944264), 'Normalized_FusedImage_Band_5': np.float32(0.22769344), 'Normalized_FusedImage_Band_6': np.float32(0.25384048), 'Normalized_FusedImage_Band_7': np.float32(0.14496346), 'Normalized_FusedImage_Band_8': np.float32(0.28563628), 'Normalized_FusedImage_Band_9': np.float32(0.49125236), 'Normalized_FusedImage_Band_10': np.float32(0.21833734), 'Normalized_FusedImage_Band_11': np.float32(0.14814813), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3359027), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.45562118), 'Normalized_FusedImage_Band_18': np.float32(0.41885), 'Normalized_FusedImage_Band_19': np.float32(0.33421695), 'Normalized_FusedImage_Band_20': np.float32(0.75398064), 'Normalized_FusedImage_Band_21': np.float32(0.5090745), 'Normalized_FusedImage_Band_22': np.float32(0.27398893), 'Normalized_FusedImage_Band_23': np.float32(0.6939447), 'Normalized_FusedImage_Band_24': np.float32(0.5524771), 'Normalized_FusedImage_Band_25': np.float32(0.5750495), 'Normalized_FusedImage_Band_26': np.float32(0.43528995), 'Normalized_FusedImage_Band_27': np.float32(0.7659964), 'Normalized_FusedImage_Band_28': np.float32(0.681469)}
# Point: Point_id: NVAL285, X: 28.97854164, Y: -30.80688942, Class_ID: 3, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.011009579), 'Normalized_FusedImage_Band_2': np.float32(0.020670326), 'Normalized_FusedImage_Band_3': np.float32(0.014212278), 'Normalized_FusedImage_Band_4': np.float32(0.04875779), 'Normalized_FusedImage_Band_5': np.float32(0.16066134), 'Normalized_FusedImage_Band_6': np.float32(0.20951323), 'Normalized_FusedImage_Band_7': np.float32(0.14534476), 'Normalized_FusedImage_Band_8': np.float32(0.2602949), 'Normalized_FusedImage_Band_9': np.float32(0.417807), 'Normalized_FusedImage_Band_10': np.float32(0.09401213), 'Normalized_FusedImage_Band_11': np.float32(0.039537426), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3424034), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.19748968), 'Normalized_FusedImage_Band_18': np.float32(0.6707393), 'Normalized_FusedImage_Band_19': np.float32(0.2070104), 'Normalized_FusedImage_Band_20': np.float32(0.75307536), 'Normalized_FusedImage_Band_21': np.float32(0.33984426), 'Normalized_FusedImage_Band_22': np.float32(0.20562823), 'Normalized_FusedImage_Band_23': np.float32(0.7971646), 'Normalized_FusedImage_Band_24': np.float32(0.545811), 'Normalized_FusedImage_Band_25': np.float32(0.40276355), 'Normalized_FusedImage_Band_26': np.float32(0.35807872), 'Normalized_FusedImage_Band_27': np.float32(0.77094054), 'Normalized_FusedImage_Band_28': np.float32(0.6759082)}
# ...
# Point: Point_id: None, X: 28.99743948, Y: -30.89508178, Class_ID: 8, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.09248046), 'Normalized_FusedImage_Band_2': np.float32(0.118650004), 'Normalized_FusedImage_Band_3': np.float32(0.12730572), 'Normalized_FusedImage_Band_4': np.float32(0.17437424), 'Normalized_FusedImage_Band_5': np.float32(0.17728457), 'Normalized_FusedImage_Band_6': np.float32(0.19711271), 'Normalized_FusedImage_Band_7': np.float32(0.13746424), 'Normalized_FusedImage_Band_8': np.float32(0.23604587), 'Normalized_FusedImage_Band_9': np.float32(0.39805993), 'Normalized_FusedImage_Band_10': np.float32(0.19458517), 'Normalized_FusedImage_Band_11': np.float32(0.16432254), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3332095), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.43342292), 'Normalized_FusedImage_Band_18': np.float32(0.38454616), 'Normalized_FusedImage_Band_19': np.float32(0.368625), 'Normalized_FusedImage_Band_20': np.float32(0.76328176), 'Normalized_FusedImage_Band_21': np.float32(0.49668202), 'Normalized_FusedImage_Band_22': np.float32(0.26266977), 'Normalized_FusedImage_Band_23': np.float32(0.7202673), 'Normalized_FusedImage_Band_24': np.float32(0.565261), 'Normalized_FusedImage_Band_25': np.float32(0.5654955), 'Normalized_FusedImage_Band_26': np.float32(0.4123653), 'Normalized_FusedImage_Band_27': np.float32(0.75238264), 'Normalized_FusedImage_Band_28': np.float32(0.680149)}
# Point: Point_id: VAL_3298, X: 28.99323035, Y: -30.90456363, Class_ID: 8, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.1385005), 'Normalized_FusedImage_Band_2': np.float32(0.16372767), 'Normalized_FusedImage_Band_3': np.float32(0.1954037), 'Normalized_FusedImage_Band_4': np.float32(0.26751652), 'Normalized_FusedImage_Band_5': np.float32(0.25878337), 'Normalized_FusedImage_Band_6': np.float32(0.26947993), 'Normalized_FusedImage_Band_7': np.float32(0.22211629), 'Normalized_FusedImage_Band_8': np.float32(0.32889134), 'Normalized_FusedImage_Band_9': np.float32(0.44032562), 'Normalized_FusedImage_Band_10': np.float32(0.46242008), 'Normalized_FusedImage_Band_11': np.float32(0.5306298), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.33618128), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.6945611), 'Normalized_FusedImage_Band_18': np.float32(0.05345386), 'Normalized_FusedImage_Band_19': np.float32(0.31335574), 'Normalized_FusedImage_Band_20': np.float32(0.35174915), 'Normalized_FusedImage_Band_21': np.float32(0.79096264), 'Normalized_FusedImage_Band_22': np.float32(0.46792373), 'Normalized_FusedImage_Band_23': np.float32(0.24698511), 'Normalized_FusedImage_Band_24': np.float32(0.2751573), 'Normalized_FusedImage_Band_25': np.float32(0.79318124), 'Normalized_FusedImage_Band_26': np.float32(0.24884054), 'Normalized_FusedImage_Band_27': np.float32(0.8081387), 'Normalized_FusedImage_Band_28': np.float32(0.71513045)}
# Point: Point_id: NVAL_326, X: 28.99244445, Y: -30.90773662, Class_ID: 8, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.115380384), 'Normalized_FusedImage_Band_2': np.float32(0.124956205), 'Normalized_FusedImage_Band_3': np.float32(0.12585424), 'Normalized_FusedImage_Band_4': np.float32(0.18125989), 'Normalized_FusedImage_Band_5': np.float32(0.17027585), 'Normalized_FusedImage_Band_6': np.float32(0.18017767), 'Normalized_FusedImage_Band_7': np.float32(0.11852557), 'Normalized_FusedImage_Band_8': np.float32(0.2149645), 'Normalized_FusedImage_Band_9': np.float32(0.38454875), 'Normalized_FusedImage_Band_10': np.float32(0.2447471), 'Normalized_FusedImage_Band_11': np.float32(0.2259728), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.34751114), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.49207988), 'Normalized_FusedImage_Band_18': np.float32(0.28739208), 'Normalized_FusedImage_Band_19': np.float32(0.43265346), 'Normalized_FusedImage_Band_20': np.float32(0.7378872), 'Normalized_FusedImage_Band_21': np.float32(0.4702158), 'Normalized_FusedImage_Band_22': np.float32(0.37548694), 'Normalized_FusedImage_Band_23': np.float32(0.6505173), 'Normalized_FusedImage_Band_24': np.float32(0.63629735), 'Normalized_FusedImage_Band_25': np.float32(0.63768214), 'Normalized_FusedImage_Band_26': np.float32(0.4382309), 'Normalized_FusedImage_Band_27': np.float32(0.8198123), 'Normalized_FusedImage_Band_28': np.float32(0.6072592)}
# Point: Point_id: NVAL280, X: 29.02637607, Y: -31.00703622, Class_ID: 2, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.006385556), 'Normalized_FusedImage_Band_2': np.float32(0.0155903315), 'Normalized_FusedImage_Band_3': np.float32(0.0092531), 'Normalized_FusedImage_Band_4': np.float32(0.053410254), 'Normalized_FusedImage_Band_5': np.float32(0.21897744), 'Normalized_FusedImage_Band_6': np.float32(0.27142328), 'Normalized_FusedImage_Band_7': np.float32(0.18398476), 'Normalized_FusedImage_Band_8': np.float32(0.34975427), 'Normalized_FusedImage_Band_9': np.float32(0.5666032), 'Normalized_FusedImage_Band_10': np.float32(0.08936135), 'Normalized_FusedImage_Band_11': np.float32(0.03141116), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.3425427), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.17858699), 'Normalized_FusedImage_Band_18': np.float32(0.79021883), 'Normalized_FusedImage_Band_19': np.float32(0.19267893), 'Normalized_FusedImage_Band_20': np.float32(0.63603866), 'Normalized_FusedImage_Band_21': np.float32(0.49227393), 'Normalized_FusedImage_Band_22': np.float32(0.199854), 'Normalized_FusedImage_Band_23': np.float32(0.8473963), 'Normalized_FusedImage_Band_24': np.float32(0.5491493), 'Normalized_FusedImage_Band_25': np.float32(0.39952222), 'Normalized_FusedImage_Band_26': np.float32(0.4167661), 'Normalized_FusedImage_Band_27': np.float32(0.6373411), 'Normalized_FusedImage_Band_28': np.float32(0.6993949)}
# Point: Point_id: VAL_2224, X: 29.1769613, Y: -30.80323135, Class_ID: 3, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.006770891), 'Normalized_FusedImage_Band_2': np.float32(0.017634008), 'Normalized_FusedImage_Band_3': np.float32(0.009736923), 'Normalized_FusedImage_Band_4': np.float32(0.050339628), 'Normalized_FusedImage_Band_5': np.float32(0.19561505), 'Normalized_FusedImage_Band_6': np.float32(0.25152692), 'Normalized_FusedImage_Band_7': np.float32(0.14992055), 'Normalized_FusedImage_Band_8': np.float32(0.31698528), 'Normalized_FusedImage_Band_9': np.float32(0.52121943), 'Normalized_FusedImage_Band_10': np.float32(0.10763226), 'Normalized_FusedImage_Band_11': np.float32(0.04469448), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.34124258), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.13645968), 'Normalized_FusedImage_Band_18': np.float32(0.6003022), 'Normalized_FusedImage_Band_19': np.float32(0.19826096), 'Normalized_FusedImage_Band_20': np.float32(0.7161763), 'Normalized_FusedImage_Band_21': np.float32(0.3000247), 'Normalized_FusedImage_Band_22': np.float32(0.17508058), 'Normalized_FusedImage_Band_23': np.float32(0.78808385), 'Normalized_FusedImage_Band_24': np.float32(0.5642437), 'Normalized_FusedImage_Band_25': np.float32(0.37939742), 'Normalized_FusedImage_Band_26': np.float32(0.36037263), 'Normalized_FusedImage_Band_27': np.float32(0.7218092), 'Normalized_FusedImage_Band_28': np.float32(0.69544256)}
# Point: Point_id: None, X: 29.04422791, Y: -31.01097117, Class_ID: 4, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.031817682), 'Normalized_FusedImage_Band_2': np.float32(0.050332826), 'Normalized_FusedImage_Band_3': np.float32(0.05866344), 'Normalized_FusedImage_Band_4': np.float32(0.119196065), 'Normalized_FusedImage_Band_5': np.float32(0.1810585), 'Normalized_FusedImage_Band_6': np.float32(0.20562649), 'Normalized_FusedImage_Band_7': np.float32(0.13199873), 'Normalized_FusedImage_Band_8': np.float32(0.26182416), 'Normalized_FusedImage_Band_9': np.float32(0.45834056), 'Normalized_FusedImage_Band_10': np.float32(0.20189352), 'Normalized_FusedImage_Band_11': np.float32(0.12611344), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.336367), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.41328794), 'Normalized_FusedImage_Band_18': np.float32(0.44806677), 'Normalized_FusedImage_Band_19': np.float32(0.24422207), 'Normalized_FusedImage_Band_20': np.float32(0.80360234), 'Normalized_FusedImage_Band_21': np.float32(0.441236), 'Normalized_FusedImage_Band_22': np.float32(0.17872259), 'Normalized_FusedImage_Band_23': np.float32(0.8050048), 'Normalized_FusedImage_Band_24': np.float32(0.6284244), 'Normalized_FusedImage_Band_25': np.float32(0.3465301), 'Normalized_FusedImage_Band_26': np.float32(0.34685928), 'Normalized_FusedImage_Band_27': np.float32(0.7861606), 'Normalized_FusedImage_Band_28': np.float32(0.6902329)}
# Point: Point_id: VAL_1342, X: 28.87787196, Y: -30.69598924, Class_ID: 7, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.020477816), 'Normalized_FusedImage_Band_2': np.float32(0.04770524), 'Normalized_FusedImage_Band_3': np.float32(0.041427273), 'Normalized_FusedImage_Band_4': np.float32(0.13473529), 'Normalized_FusedImage_Band_5': np.float32(0.27289063), 'Normalized_FusedImage_Band_6': np.float32(0.31861928), 'Normalized_FusedImage_Band_7': np.float32(0.21093105), 'Normalized_FusedImage_Band_8': np.float32(0.38842162), 'Normalized_FusedImage_Band_9': np.float32(0.6071366), 'Normalized_FusedImage_Band_10': np.float32(0.1802176), 'Normalized_FusedImage_Band_11': np.float32(0.104313165), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.32889116), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.324557), 'Normalized_FusedImage_Band_18': np.float32(0.6826643), 'Normalized_FusedImage_Band_19': np.float32(0.18691285), 'Normalized_FusedImage_Band_20': np.float32(0.7335275), 'Normalized_FusedImage_Band_21': np.float32(0.5432244), 'Normalized_FusedImage_Band_22': np.float32(0.1387112), 'Normalized_FusedImage_Band_23': np.float32(0.7646023), 'Normalized_FusedImage_Band_24': np.float32(0.55156916), 'Normalized_FusedImage_Band_25': np.float32(0.51889825), 'Normalized_FusedImage_Band_26': np.float32(0.44633004), 'Normalized_FusedImage_Band_27': np.float32(0.74709535), 'Normalized_FusedImage_Band_28': np.float32(0.6348151)}
# Point: Point_id: None, X: 28.99859574, Y: -30.89497315, Class_ID: 8, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.054937795), 'Normalized_FusedImage_Band_2': np.float32(0.08618475), 'Normalized_FusedImage_Band_3': np.float32(0.108557604), 'Normalized_FusedImage_Band_4': np.float32(0.1612543), 'Normalized_FusedImage_Band_5': np.float32(0.2466529), 'Normalized_FusedImage_Band_6': np.float32(0.28882104), 'Normalized_FusedImage_Band_7': np.float32(0.17368923), 'Normalized_FusedImage_Band_8': np.float32(0.35488805), 'Normalized_FusedImage_Band_9': np.float32(0.5742248), 'Normalized_FusedImage_Band_10': np.float32(0.20230879), 'Normalized_FusedImage_Band_11': np.float32(0.13048913), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.32735884), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.41207403), 'Normalized_FusedImage_Band_18': np.float32(0.51814765), 'Normalized_FusedImage_Band_19': np.float32(0.2593578), 'Normalized_FusedImage_Band_20': np.float32(0.76982605), 'Normalized_FusedImage_Band_21': np.float32(0.47524115), 'Normalized_FusedImage_Band_22': np.float32(0.23518723), 'Normalized_FusedImage_Band_23': np.float32(0.7511544), 'Normalized_FusedImage_Band_24': np.float32(0.55441076), 'Normalized_FusedImage_Band_25': np.float32(0.47003952), 'Normalized_FusedImage_Band_26': np.float32(0.40072677), 'Normalized_FusedImage_Band_27': np.float32(0.7736081), 'Normalized_FusedImage_Band_28': np.float32(0.6894024)}
# Point: Point_id: VAL_3303, X: 28.99487763, Y: -30.90048499, Class_ID: 8, Pixel Values: {'Normalized_FusedImage_Band_1': np.float32(0.05636904), 'Normalized_FusedImage_Band_2': np.float32(0.081747055), 'Normalized_FusedImage_Band_3': np.float32(0.07311763), 'Normalized_FusedImage_Band_4': np.float32(0.14134176), 'Normalized_FusedImage_Band_5': np.float32(0.21457453), 'Normalized_FusedImage_Band_6': np.float32(0.2516195), 'Normalized_FusedImage_Band_7': np.float32(0.18195106), 'Normalized_FusedImage_Band_8': np.float32(0.29361007), 'Normalized_FusedImage_Band_9': np.float32(0.43027887), 'Normalized_FusedImage_Band_10': np.float32(0.20878664), 'Normalized_FusedImage_Band_11': np.float32(0.17221439), 'Normalized_FusedImage_Band_12': np.float32(nan), 'Normalized_FusedImage_Band_13': np.float32(0.33209512), 'Normalized_FusedImage_Band_14': np.float32(nan), 'Normalized_FusedImage_Band_15': np.float32(nan), 'Normalized_FusedImage_Band_16': np.float32(nan), 'Normalized_FusedImage_Band_17': np.float32(0.43154666), 'Normalized_FusedImage_Band_18': np.float32(0.38359123), 'Normalized_FusedImage_Band_19': np.float32(0.38859734), 'Normalized_FusedImage_Band_20': np.float32(0.7517615), 'Normalized_FusedImage_Band_21': np.float32(0.4963577), 'Normalized_FusedImage_Band_22': np.float32(0.286395), 'Normalized_FusedImage_Band_23': np.float32(0.71722907), 'Normalized_FusedImage_Band_24': np.float32(0.61333776), 'Normalized_FusedImage_Band_25': np.float32(0.60050625), 'Normalized_FusedImage_Band_26': np.float32(0.45940205), 'Normalized_FusedImage_Band_27': np.float32(0.81959593), 'Normalized_FusedImage_Band_28': np.float32(0.6869595)}

# %% [markdown]
# ### This cell changes point_pixel_value dictionary to a dataframe

# %%
# Create a list of dictionaries for DataFrame creation
data_list = []

for point_key, pixel_values in point_pixel_values.items():
    data_dict = {}
    # Extracting Point ID, X, Y, and Class ID from point_key
    point_id = point_key.split(',')[0].split(':')[1].strip()  
    x_coord = point_key.split(',')[1].split(':')[1].strip()
    y_coord = point_key.split(',')[2].split(':')[1].strip()
    class_id = point_key.split(',')[3].split(':')[1].strip()
    
    # Add extracted information as separate columns
    data_dict['Point'] = point_id
    data_dict['X'] = x_coord
    data_dict['Y'] = y_coord
    data_dict['Class_ID'] = class_id
    
    # Add band pixel values as columns
    data_dict.update(pixel_values)

    data_list.append(data_dict)

# Create DataFrame from list of dictionaries
pixelvalues_df = pd.DataFrame(data_list)

# Print the DataFrame
print(pixelvalues_df)

# Save the DataFrame to a CSV file
# Define the CSV file path
csv_file_path = r'C:\Users\User\Documents\DataFusion\DataFusion\bandvalues\04102024pixel_values.csv'

# Save the DataFrame to a CSV file
pixelvalues_df.to_csv(csv_file_path, index=False)

print(f'DataFrame successfully saved to {csv_file_path}')
# Out:
#         Point            X             Y Class_ID  \
# 0    VAL_2887  29.04363001  -31.00724936        2
# 1     NVAL254  29.02381883  -31.00773088        2
# 2        None   28.8769605  -30.69760225        7
# 3     NVAL279  29.11025967  -30.90116542        5
# 4    VAL_2214   29.1825931  -30.81179621        7
# ..        ...          ...           ...      ...
# 163  VAL_2224   29.1769613  -30.80323135        3
# 164      None  29.04422791  -31.01097117        4
# 165  VAL_1342  28.87787196  -30.69598924        7
# 166      None  28.99859574  -30.89497315        8
# 167  VAL_3303  28.99487763  -30.90048499        8
#
#      Normalized_FusedImage_Band_1  Normalized_FusedImage_Band_2  \
# 0                        0.007266                      0.016992
# 1                        0.005450                      0.013780
# 2                        0.020478                      0.046888
# 3                        0.017175                      0.047413
# 4                        0.017175                      0.032699
# ..                            ...                           ...
# 163                      0.006771                      0.017634
# 164                      0.031818                      0.050333
# 165                      0.020478                      0.047705
# 166                      0.054938                      0.086185
# 167                      0.056369                      0.081747
#
#      Normalized_FusedImage_Band_3  Normalized_FusedImage_Band_4  \
# 0                        0.013245                      0.070997
# 1                        0.006592                      0.049967
# 2                        0.042879                      0.136782
# 3                        0.032839                      0.136131
# 4                        0.036952                      0.086908
# ..                            ...                           ...
# 163                      0.009737                      0.050340
# 164                      0.058663                      0.119196
# 165                      0.041427                      0.134735
# 166                      0.108558                      0.161254
# 167                      0.073118                      0.141342
#
#      Normalized_FusedImage_Band_5  Normalized_FusedImage_Band_6  ...  \
# 0                        0.202624                      0.243291  ...
# 1                        0.209183                      0.275865  ...
# 2                        0.265612                      0.304738  ...
# 3                        0.261120                      0.305571  ...
# 4                        0.153383                      0.178142  ...
# ..                            ...                           ...  ...
# 163                      0.195615                      0.251527  ...
# 164                      0.181058                      0.205626  ...
# 165                      0.272891                      0.318619  ...
# 166                      0.246653                      0.288821  ...
# 167                      0.214575                      0.251619  ...
#
#      Normalized_FusedImage_Band_19  Normalized_FusedImage_Band_20  \
# 0                         0.197054                       0.690570
# 1                         0.190222                       0.643162
# 2                         0.188324                       0.749204
# 3                         0.177742                       0.833223
# 4                         0.180347                       0.762401
# ..                             ...                            ...
# 163                       0.198261                       0.716176
# 164                       0.244222                       0.803602
# 165                       0.186913                       0.733527
# 166                       0.259358                       0.769826
# 167                       0.388597                       0.751761
#
#      Normalized_FusedImage_Band_21  Normalized_FusedImage_Band_22  \
# 0                         0.434545                       0.187867
# 1                         0.488277                       0.200267
# 2                         0.497061                       0.139088
# 3                         0.321245                       0.153654
# 4                         0.394701                       0.175061
# ..                             ...                            ...
# 163                       0.300025                       0.175081
# 164                       0.441236                       0.178723
# 165                       0.543224                       0.138711
# 166                       0.475241                       0.235187
# 167                       0.496358                       0.286395
#
#      Normalized_FusedImage_Band_23  Normalized_FusedImage_Band_24  \
# 0                         0.834222                       0.536668
# 1                         0.851914                       0.539082
# 2                         0.764108                       0.580333
# 3                         0.767577                       0.608077
# 4                         0.767273                       0.678061
# ..                             ...                            ...
# 163                       0.788084                       0.564244
# 164                       0.805005                       0.628424
# 165                       0.764602                       0.551569
# 166                       0.751154                       0.554411
# 167                       0.717229                       0.613338
#
#      Normalized_FusedImage_Band_25  Normalized_FusedImage_Band_26  \
# 0                         0.462131                       0.385412
# 1                         0.399583                       0.413155
# 2                         0.470896                       0.465920
# 3                         0.536715                       0.343872
# 4                         0.380984                       0.426188
# ..                             ...                            ...
# 163                       0.379397                       0.360373
# 164                       0.346530                       0.346859
# 165                       0.518898                       0.446330
# 166                       0.470040                       0.400727
# 167                       0.600506                       0.459402
#
#      Normalized_FusedImage_Band_27  Normalized_FusedImage_Band_28
# 0                         0.691294                       0.603511
# 1                         0.652285                       0.686738
# 2                         0.760001                       0.654018
# 3                         0.781345                       0.643617
# 4                         0.806603                       0.741723
# ..                             ...                            ...
# 163                       0.721809                       0.695443
# 164                       0.786161                       0.690233
# 165                       0.747095                       0.634815
# 166                       0.773608                       0.689402
# 167                       0.819596                       0.686960
#
# [168 rows x 32 columns]
# DataFrame successfully saved to C:\Users\User\Documents\DataFusion\DataFusion\bandvalues\04102024pixel_values.csv

# %% [markdown]
# ### This cell block trains the random forest classifier

# %%
# Define features 
# Find the index of the last non-band column
last_non_band_index = pixelvalues_df.columns.tolist().index('Class_ID')  #

# Select columns starting from the column following the last non-band column
#These columns are the band features used in the classification
features = pixelvalues_df.iloc[:, last_non_band_index + 1:]
#print(features)

# Define target (Class ID column)
target = pixelvalues_df['Class_ID']

# Convert features and target columns to arrays
features_array = features.values
target_array = target.values

# Train the classifier using RandomForest with 500 trees
classifier = RandomForestClassifier(n_estimators=500)
classifier.fit(features_array, target_array)
# Out:
# RandomForestClassifier(n_estimators=500)

# %% [markdown]
# ### This cell block performs the classification on each image in the folder using the trained classifer in the previous cell

# %%
# Define the directory where you want to save the classified images
output_folder_classified = r'C:\Users\User\Documents\DataFusion\DataFusion\Classified'
output_folder = r'C:\Users\User\Documents\DataFusion\DataFusion\AddedIndices'
os.makedirs(output_folder, exist_ok=True)
        
# Open the image using rasterio
with rasterio.open(output_tif_path) as src:
    # Get the shape of the image
    rows, cols = src.height, src.width

    # Define batch size (adjust as needed based on memory constraints)
    batch_size = 1000  # You can adjust this value

    # Initialize the classification result array for the entire image
    classification_result = np.zeros((rows, cols), dtype=np.uint8)

    # Iterate over the image in batches
    for row_start in range(0, rows, batch_size):
        for col_start in range(0, cols, batch_size):
            row_end = min(row_start + batch_size, rows)
            col_end = min(col_start + batch_size, cols)

            # Read the batch of bands
            bands = [src.read(band_idx, window=((row_start, row_end), (col_start, col_end))) 
                     for band_idx in range(1, src.count + 1)]

            # Stack the bands into a single array
            stacked_bands = np.stack(bands, axis=-1)

            # Reshape the array to 2D (rows, columns) for classification
            reshaped_bands = stacked_bands.reshape(-1, src.count)

            # Predict using the trained classifier (replace this with your classifier)
            predicted_labels = classifier.predict(reshaped_bands)

            # Create a temporary result array for this batch
            batch_result = predicted_labels.reshape(row_end - row_start, col_end - col_start)

            # Write the batch result to the corresponding window in the full classification result array
            classification_result[row_start:row_end, col_start:col_end] = batch_result

    # Construct the output file path
    output_filename = 'datafusion_classified10042014.tif'
    output_path = os.path.join(output_folder_classified, output_filename)

    # Prepare metadata for the classified image
    meta = src.meta.copy()
    meta.update({
        'driver': 'GTiff',
        'dtype': 'uint8',  # Ensure data type is appropriate for classification results
        'count': 1,  # Single band
        'compress': 'lzw',  # Compression method (Lempel-Ziv-Welch)
        'crs': src.crs,  # Use the same CRS as the input raster
        'transform': src.transform,  # Use the same transform as the input raster
    })

    # Remove the 'nodata' entry from the metadata if it exists
    meta.pop('nodata', None)

    # Write the full classified image to a new GeoTIFF file
    with rasterio.open(output_path, 'w', **meta) as dst:
        dst.write(classification_result.astype('uint8'), 1)

print(f"Classification completed and classified image '{output_filename}' saved successfully!")
# Out:
# Classification completed and classified image 'datafusion_classified10042014.tif' saved successfully!
