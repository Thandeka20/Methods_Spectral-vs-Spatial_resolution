# %% [markdown]
# # Accuracy Assessment

# %% [markdown]
# ### Import packages

# %%
import geopandas as gpd
import rasterio
import os
import numpy as np
from rasterio.sample import sample_gen
from sklearn.metrics import accuracy_score, confusion_matrix
import pandas as pd

# %% [markdown]
# #### Overall accuracy

# %%
# Define the paths
classified_image_path = r'Z:\Data\CLASSIFIED'
classified_imagelist = [os.path.join(classified_image_path, file) for file in os.listdir(classified_image_path) if file.endswith('.TIF') or file.endswith('.tif')]

validation_shapefile_path = r'C:\Users\User\OneDrive - Stellenbosch University\MAPWAPS\DataChapter1\uMzi_ROI\Train_Val\Validation_data\validation_shapefile.shp'

# Load validation shapefile as a geodataframe
validation_gdf = gpd.read_file(validation_shapefile_path)

# Initialize lists to store overall metrics
all_validation_values = []
all_classified_values = []

# Initialize lists to store detailed comparison data
comparison_data = []

# Loop through each classified image
for classified_image_file in classified_imagelist:
    print("Processing:", classified_image_file)
    
    # Open the classified image
    with rasterio.open(classified_image_file) as classified_image:
        # Generate samples of the classified image values at validation point locations
        validation_values = []
        classified_values = []
        
        for _, row in validation_gdf.iterrows():
            coords = [(row.geometry.x, row.geometry.y)]
            sampled_values = list(sample_gen(classified_image, coords))
            
            if sampled_values:
                classified_value = sampled_values[0][0]
                
                # Ensure classified values are between 1 and 8, ignoring 0 or 255 (which may be NoData)
                if 1 <= classified_value <= 8:
                    validation_value = row['ID']  # Assuming 'ID' is the ground truth column name
                    classified_values.append(classified_value)
                    validation_values.append(validation_value)
                    
                    # Store comparison data
                    comparison_data.append({'Validation Value': validation_value, 'Classified Value': classified_value})
                else:
                    # Handle NoData or invalid classified values
                    print(f"Skipping invalid value {classified_value} at coordinates {coords}")

        # Append to overall lists
        all_validation_values.extend(validation_values)
        all_classified_values.extend(classified_values)

# Calculate overall accuracy
accuracy = accuracy_score(all_validation_values, all_classified_values)
conf_matrix = confusion_matrix(all_validation_values, all_classified_values)

# Calculate User's and Producer's Accuracy
def calculate_accuracy(conf_matrix):
    total = np.sum(conf_matrix)
    user_accuracy = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
    producer_accuracy = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
    
    return user_accuracy, producer_accuracy

user_accuracy, producer_accuracy = calculate_accuracy(conf_matrix)

# Calculate Kappa Coefficient
def calculate_kappa(conf_matrix):
    total = np.sum(conf_matrix)
    sum_po = np.sum(np.diag(conf_matrix))
    sum_pe = np.sum(np.sum(conf_matrix, axis=0) * np.sum(conf_matrix, axis=1)) / total
    kappa = (sum_po - sum_pe) / (total - sum_pe)
    return kappa

kappa = calculate_kappa(conf_matrix)

print("Overall Accuracy:", accuracy)
print("Confusion Matrix:")
print(conf_matrix)

# Print User's Accuracy
print("\nUser's Accuracy:")
for i, acc in enumerate(user_accuracy):
    print(f"Class {i + 1}: {acc:.2f}")

# Print Producer's Accuracy
print("\nProducer's Accuracy:")
for i, acc in enumerate(producer_accuracy):
    print(f"Class {i + 1}: {acc:.2f}")

# Print Kappa Coefficient
print("\nKappa Coefficient:")
print(f"{kappa:.2f}")

# Create and print comparison DataFrame
comparison_df = pd.DataFrame(comparison_data)
print("\nComparison Table:")
print(comparison_df)
# Out:
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_16_2020_1377_RGB_RECT_projected_classified.tif
# Skipping invalid value 255 at coordinates [(689963.5349000003, 6570128.567)]
# Skipping invalid value 255 at coordinates [(690554.9042999996, 6594323.7953)]
# Skipping invalid value 255 at coordinates [(701864.3657, 6588811.1657)]
# Skipping invalid value 255 at coordinates [(689763.1364000002, 6570196.1107)]
# Skipping invalid value 255 at coordinates [(690387.2967999997, 6594332.7356)]
# Skipping invalid value 255 at coordinates [(690942.4511000002, 6599787.0709)]
# Skipping invalid value 255 at coordinates [(690883.9029000001, 6580352.031)]
# Skipping invalid value 255 at coordinates [(679980.5745999999, 6602618.4019)]
# Skipping invalid value 255 at coordinates [(708731.5776000004, 6592517.9952)]
# Skipping invalid value 255 at coordinates [(698056.7525000004, 6591147.1521)]
# Skipping invalid value 255 at coordinates [(698960.8870000001, 6568254.0181)]
# Skipping invalid value 255 at coordinates [(708500.1891999999, 6590365.6486)]
# Skipping invalid value 255 at coordinates [(701797.068, 6588818.8626)]
# Skipping invalid value 255 at coordinates [(703228.7085999995, 6579902.504)]
# Skipping invalid value 255 at coordinates [(692713.8925000001, 6567680.0679)]
# Skipping invalid value 255 at coordinates [(703330.7960000001, 6579902.504)]
# Skipping invalid value 255 at coordinates [(707889.0376000004, 6590427.5369)]
# Skipping invalid value 255 at coordinates [(679875.1328999996, 6602525.3526)]
# Skipping invalid value 255 at coordinates [(679845.7358999997, 6602455.2579)]
# Skipping invalid value 255 at coordinates [(702424.5541000003, 6578984.8591)]
# Skipping invalid value 255 at coordinates [(708634.9680000003, 6590346.1374)]
# Skipping invalid value 255 at coordinates [(694247.0718999999, 6567504.6648)]
# Skipping invalid value 255 at coordinates [(689174.9493000004, 6590143.8048)]
# Skipping invalid value 255 at coordinates [(701682.3980999999, 6588873.4917)]
# Skipping invalid value 255 at coordinates [(693016.0283000004, 6598394.2897)]
# Skipping invalid value 255 at coordinates [(708714.5022999998, 6589524.5199)]
# Skipping invalid value 255 at coordinates [(689803.7492000004, 6570131.5488)]
# Skipping invalid value 255 at coordinates [(690966.3459999999, 6580536.1162)]
# Skipping invalid value 255 at coordinates [(677816.0344000002, 6577293.8581)]
# Skipping invalid value 255 at coordinates [(708678.2279000003, 6590353.891)]
# Skipping invalid value 255 at coordinates [(702933.3103, 6579569.8428)]
# Skipping invalid value 255 at coordinates [(699032.5999999996, 6568255.123)]
# Skipping invalid value 255 at coordinates [(679913.3339999998, 6602465.2133)]
# Skipping invalid value 255 at coordinates [(707867.6095000003, 6590368.5783)]
# Skipping invalid value 255 at coordinates [(708733.2127999999, 6590355.6482)]
# Skipping invalid value 255 at coordinates [(690847.1199000003, 6580315.3625)]
# Skipping invalid value 255 at coordinates [(689928.6984999999, 6570127.1777)]
# Skipping invalid value 255 at coordinates [(695098.1168999998, 6567396.3136)]
# Skipping invalid value 255 at coordinates [(690380.9842999997, 6594385.0968)]
# Skipping invalid value 255 at coordinates [(693658.5997000001, 6567642.4525)]
# Skipping invalid value 255 at coordinates [(692996.8071999997, 6598449.3384)]
# Skipping invalid value 255 at coordinates [(692647.8552000001, 6567968.2175)]
# Skipping invalid value 255 at coordinates [(708400.1962000001, 6590473.1306)]
# Skipping invalid value 255 at coordinates [(690433.9988000002, 6579176.4563)]
# Skipping invalid value 255 at coordinates [(692828.1728999997, 6568093.3901)]
# Skipping invalid value 255 at coordinates [(698162.1957, 6591094.3607)]
# Skipping invalid value 255 at coordinates [(689304.2660999997, 6590074.5991)]
# Skipping invalid value 255 at coordinates [(689751.7734000003, 6570131.0613)]
# Skipping invalid value 255 at coordinates [(708903.4233999997, 6590186.887)]
# Skipping invalid value 255 at coordinates [(691005.8410999998, 6599731.2167)]
# Skipping invalid value 255 at coordinates [(692875.5450999998, 6598371.8647)]
# Skipping invalid value 255 at coordinates [(690807.0250000004, 6580248.7889)]
# Skipping invalid value 255 at coordinates [(689750.3816, 6570256.7704)]
# Skipping invalid value 255 at coordinates [(692998.3472999996, 6567683.7487)]
# Skipping invalid value 255 at coordinates [(703272.8957000002, 6579910.1225)]
# Skipping invalid value 255 at coordinates [(701699.7012999998, 6588825.7231)]
# Skipping invalid value 255 at coordinates [(690142.5062999995, 6570357.0003)]
# Skipping invalid value 255 at coordinates [(707958.1490000002, 6590428.4815)]
# Skipping invalid value 255 at coordinates [(690984.4256999996, 6581705.8585)]
# Skipping invalid value 255 at coordinates [(708853.5695000002, 6592514.3622)]
# Skipping invalid value 255 at coordinates [(690028.6464999998, 6570195.3239)]
# Skipping invalid value 255 at coordinates [(689673.0053000003, 6570333.7507)]
# Skipping invalid value 255 at coordinates [(708798.9249999998, 6592519.7445)]
# Skipping invalid value 255 at coordinates [(690261.2017999999, 6578711.4855)]
# Skipping invalid value 255 at coordinates [(691174.7335999999, 6599909.8615)]
# Skipping invalid value 255 at coordinates [(679966.9708000002, 6602519.9086)]
# Skipping invalid value 255 at coordinates [(708715.4469999997, 6590395.4149)]
# Skipping invalid value 255 at coordinates [(690253.4134, 6578670.9749)]
# Skipping invalid value 255 at coordinates [(691008.0576, 6599848.2446)]
# Skipping invalid value 255 at coordinates [(679934.3771000002, 6602510.6498)]
# Skipping invalid value 255 at coordinates [(690953.8724999996, 6580463.4292)]
# Skipping invalid value 255 at coordinates [(677871.7384000001, 6577336.4184)]
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_17_2020_1377_RGB_RECT_projected_classified.tif
# Skipping invalid value 255 at coordinates [(689963.5349000003, 6570128.567)]
# Skipping invalid value 255 at coordinates [(690554.9042999996, 6594323.7953)]
# Skipping invalid value 255 at coordinates [(701864.3657, 6588811.1657)]
# Skipping invalid value 255 at coordinates [(689763.1364000002, 6570196.1107)]
# Skipping invalid value 255 at coordinates [(690387.2967999997, 6594332.7356)]
# Skipping invalid value 255 at coordinates [(690942.4511000002, 6599787.0709)]
# Skipping invalid value 255 at coordinates [(690883.9029000001, 6580352.031)]
# Skipping invalid value 255 at coordinates [(679980.5745999999, 6602618.4019)]
# Skipping invalid value 255 at coordinates [(708731.5776000004, 6592517.9952)]
# Skipping invalid value 255 at coordinates [(698056.7525000004, 6591147.1521)]
# Skipping invalid value 255 at coordinates [(698960.8870000001, 6568254.0181)]
# Skipping invalid value 255 at coordinates [(708500.1891999999, 6590365.6486)]
# Skipping invalid value 255 at coordinates [(701797.068, 6588818.8626)]
# Skipping invalid value 255 at coordinates [(703228.7085999995, 6579902.504)]
# Skipping invalid value 255 at coordinates [(692713.8925000001, 6567680.0679)]
# Skipping invalid value 255 at coordinates [(703330.7960000001, 6579902.504)]
# Skipping invalid value 255 at coordinates [(707889.0376000004, 6590427.5369)]
# Skipping invalid value 255 at coordinates [(679875.1328999996, 6602525.3526)]
# Skipping invalid value 255 at coordinates [(679845.7358999997, 6602455.2579)]
# Skipping invalid value 255 at coordinates [(702424.5541000003, 6578984.8591)]
# Skipping invalid value 255 at coordinates [(708634.9680000003, 6590346.1374)]
# Skipping invalid value 255 at coordinates [(694247.0718999999, 6567504.6648)]
# Skipping invalid value 255 at coordinates [(689174.9493000004, 6590143.8048)]
# Skipping invalid value 255 at coordinates [(701682.3980999999, 6588873.4917)]
# Skipping invalid value 255 at coordinates [(693016.0283000004, 6598394.2897)]
# Skipping invalid value 255 at coordinates [(708714.5022999998, 6589524.5199)]
# Skipping invalid value 255 at coordinates [(689803.7492000004, 6570131.5488)]
# Skipping invalid value 255 at coordinates [(690966.3459999999, 6580536.1162)]
# Skipping invalid value 255 at coordinates [(677816.0344000002, 6577293.8581)]
# Skipping invalid value 255 at coordinates [(708678.2279000003, 6590353.891)]
# Skipping invalid value 255 at coordinates [(702933.3103, 6579569.8428)]
# Skipping invalid value 255 at coordinates [(699032.5999999996, 6568255.123)]
# Skipping invalid value 255 at coordinates [(679913.3339999998, 6602465.2133)]
# Skipping invalid value 255 at coordinates [(707867.6095000003, 6590368.5783)]
# Skipping invalid value 255 at coordinates [(708733.2127999999, 6590355.6482)]
# Skipping invalid value 255 at coordinates [(690847.1199000003, 6580315.3625)]
# Skipping invalid value 255 at coordinates [(689928.6984999999, 6570127.1777)]
# Skipping invalid value 255 at coordinates [(695098.1168999998, 6567396.3136)]
# Skipping invalid value 255 at coordinates [(690380.9842999997, 6594385.0968)]
# Skipping invalid value 255 at coordinates [(693658.5997000001, 6567642.4525)]
# Skipping invalid value 255 at coordinates [(692996.8071999997, 6598449.3384)]
# Skipping invalid value 255 at coordinates [(692647.8552000001, 6567968.2175)]
# Skipping invalid value 255 at coordinates [(708400.1962000001, 6590473.1306)]
# Skipping invalid value 255 at coordinates [(690433.9988000002, 6579176.4563)]
# Skipping invalid value 255 at coordinates [(692828.1728999997, 6568093.3901)]
# Skipping invalid value 255 at coordinates [(698162.1957, 6591094.3607)]
# Skipping invalid value 255 at coordinates [(689304.2660999997, 6590074.5991)]
# Skipping invalid value 255 at coordinates [(689751.7734000003, 6570131.0613)]
# Skipping invalid value 255 at coordinates [(708903.4233999997, 6590186.887)]
# Skipping invalid value 255 at coordinates [(691005.8410999998, 6599731.2167)]
# Skipping invalid value 255 at coordinates [(692875.5450999998, 6598371.8647)]
# Skipping invalid value 255 at coordinates [(690807.0250000004, 6580248.7889)]
# Skipping invalid value 255 at coordinates [(689750.3816, 6570256.7704)]
# Skipping invalid value 255 at coordinates [(692998.3472999996, 6567683.7487)]
# Skipping invalid value 255 at coordinates [(703272.8957000002, 6579910.1225)]
# Skipping invalid value 255 at coordinates [(701699.7012999998, 6588825.7231)]
# Skipping invalid value 255 at coordinates [(690142.5062999995, 6570357.0003)]
# Skipping invalid value 255 at coordinates [(707958.1490000002, 6590428.4815)]
# Skipping invalid value 255 at coordinates [(690984.4256999996, 6581705.8585)]
# Skipping invalid value 255 at coordinates [(708853.5695000002, 6592514.3622)]
# Skipping invalid value 255 at coordinates [(690028.6464999998, 6570195.3239)]
# Skipping invalid value 255 at coordinates [(689673.0053000003, 6570333.7507)]
# Skipping invalid value 255 at coordinates [(708798.9249999998, 6592519.7445)]
# Skipping invalid value 255 at coordinates [(690261.2017999999, 6578711.4855)]
# Skipping invalid value 255 at coordinates [(691174.7335999999, 6599909.8615)]
# Skipping invalid value 255 at coordinates [(679966.9708000002, 6602519.9086)]
# Skipping invalid value 255 at coordinates [(708715.4469999997, 6590395.4149)]
# Skipping invalid value 255 at coordinates [(690253.4134, 6578670.9749)]
# Skipping invalid value 255 at coordinates [(691008.0576, 6599848.2446)]
# Skipping invalid value 255 at coordinates [(679934.3771000002, 6602510.6498)]
# Skipping invalid value 255 at coordinates [(690953.8724999996, 6580463.4292)]
# Skipping invalid value 255 at coordinates [(677871.7384000001, 6577336.4184)]
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_18_2020_1377_RGB_RECT_projected_classified.tif
# Skipping invalid value 255 at coordinates [(689963.5349000003, 6570128.567)]
# Skipping invalid value 255 at coordinates [(690554.9042999996, 6594323.7953)]
# Skipping invalid value 255 at coordinates [(701864.3657, 6588811.1657)]
# Skipping invalid value 255 at coordinates [(689763.1364000002, 6570196.1107)]
# Skipping invalid value 255 at coordinates [(690387.2967999997, 6594332.7356)]
# Skipping invalid value 255 at coordinates [(690942.4511000002, 6599787.0709)]
# Skipping invalid value 255 at coordinates [(690883.9029000001, 6580352.031)]
# Skipping invalid value 255 at coordinates [(708731.5776000004, 6592517.9952)]
# Skipping invalid value 255 at coordinates [(698056.7525000004, 6591147.1521)]
# Skipping invalid value 255 at coordinates [(698960.8870000001, 6568254.0181)]
# Skipping invalid value 255 at coordinates [(708500.1891999999, 6590365.6486)]
# Skipping invalid value 255 at coordinates [(701797.068, 6588818.8626)]
# Skipping invalid value 255 at coordinates [(703228.7085999995, 6579902.504)]
# Skipping invalid value 255 at coordinates [(692713.8925000001, 6567680.0679)]
# Skipping invalid value 255 at coordinates [(703330.7960000001, 6579902.504)]
# Skipping invalid value 255 at coordinates [(707889.0376000004, 6590427.5369)]
# Skipping invalid value 255 at coordinates [(702424.5541000003, 6578984.8591)]
# Skipping invalid value 255 at coordinates [(708634.9680000003, 6590346.1374)]
# Skipping invalid value 255 at coordinates [(694247.0718999999, 6567504.6648)]
# Skipping invalid value 255 at coordinates [(689174.9493000004, 6590143.8048)]
# Skipping invalid value 255 at coordinates [(701682.3980999999, 6588873.4917)]
# Skipping invalid value 255 at coordinates [(693016.0283000004, 6598394.2897)]
# Skipping invalid value 255 at coordinates [(708714.5022999998, 6589524.5199)]
# Skipping invalid value 255 at coordinates [(689803.7492000004, 6570131.5488)]
# Skipping invalid value 255 at coordinates [(690966.3459999999, 6580536.1162)]
# Skipping invalid value 255 at coordinates [(677816.0344000002, 6577293.8581)]
# Skipping invalid value 255 at coordinates [(708678.2279000003, 6590353.891)]
# Skipping invalid value 255 at coordinates [(702933.3103, 6579569.8428)]
# Skipping invalid value 255 at coordinates [(699032.5999999996, 6568255.123)]
# Skipping invalid value 255 at coordinates [(707867.6095000003, 6590368.5783)]
# Skipping invalid value 255 at coordinates [(708733.2127999999, 6590355.6482)]
# Skipping invalid value 255 at coordinates [(690847.1199000003, 6580315.3625)]
# Skipping invalid value 255 at coordinates [(689928.6984999999, 6570127.1777)]
# Skipping invalid value 255 at coordinates [(695098.1168999998, 6567396.3136)]
# Skipping invalid value 255 at coordinates [(690380.9842999997, 6594385.0968)]
# Skipping invalid value 255 at coordinates [(693658.5997000001, 6567642.4525)]
# Skipping invalid value 255 at coordinates [(692996.8071999997, 6598449.3384)]
# Skipping invalid value 255 at coordinates [(692647.8552000001, 6567968.2175)]
# Skipping invalid value 255 at coordinates [(708400.1962000001, 6590473.1306)]
# Skipping invalid value 255 at coordinates [(690433.9988000002, 6579176.4563)]
# Skipping invalid value 255 at coordinates [(692828.1728999997, 6568093.3901)]
# Skipping invalid value 255 at coordinates [(698162.1957, 6591094.3607)]
# Skipping invalid value 255 at coordinates [(689304.2660999997, 6590074.5991)]
# Skipping invalid value 255 at coordinates [(689751.7734000003, 6570131.0613)]
# Skipping invalid value 255 at coordinates [(708903.4233999997, 6590186.887)]
# Skipping invalid value 255 at coordinates [(691005.8410999998, 6599731.2167)]
# Skipping invalid value 255 at coordinates [(692875.5450999998, 6598371.8647)]
# Skipping invalid value 255 at coordinates [(690807.0250000004, 6580248.7889)]
# Skipping invalid value 255 at coordinates [(689750.3816, 6570256.7704)]
# Skipping invalid value 255 at coordinates [(692998.3472999996, 6567683.7487)]
# Skipping invalid value 255 at coordinates [(703272.8957000002, 6579910.1225)]
# Skipping invalid value 255 at coordinates [(701699.7012999998, 6588825.7231)]
# Skipping invalid value 255 at coordinates [(690142.5062999995, 6570357.0003)]
# Skipping invalid value 255 at coordinates [(707958.1490000002, 6590428.4815)]
# Skipping invalid value 255 at coordinates [(690984.4256999996, 6581705.8585)]
# Skipping invalid value 255 at coordinates [(708853.5695000002, 6592514.3622)]
# Skipping invalid value 255 at coordinates [(690028.6464999998, 6570195.3239)]
# Skipping invalid value 255 at coordinates [(689673.0053000003, 6570333.7507)]
# Skipping invalid value 255 at coordinates [(708798.9249999998, 6592519.7445)]
# Skipping invalid value 255 at coordinates [(690261.2017999999, 6578711.4855)]
# Skipping invalid value 255 at coordinates [(691174.7335999999, 6599909.8615)]
# Skipping invalid value 255 at coordinates [(708715.4469999997, 6590395.4149)]
# Skipping invalid value 255 at coordinates [(690253.4134, 6578670.9749)]
# Skipping invalid value 255 at coordinates [(691008.0576, 6599848.2446)]
# Skipping invalid value 255 at coordinates [(690953.8724999996, 6580463.4292)]
# Skipping invalid value 255 at coordinates [(677871.7384000001, 6577336.4184)]
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_19_2020_1377_RGB_RECT_projected_classified.tif
# Skipping invalid value 255 at coordinates [(689963.5349000003, 6570128.567)]
# Skipping invalid value 255 at coordinates [(690554.9042999996, 6594323.7953)]
# Skipping invalid value 255 at coordinates [(701864.3657, 6588811.1657)]
# Skipping invalid value 255 at coordinates [(689763.1364000002, 6570196.1107)]
# Skipping invalid value 255 at coordinates [(690387.2967999997, 6594332.7356)]
# Skipping invalid value 255 at coordinates [(690942.4511000002, 6599787.0709)]
# Skipping invalid value 255 at coordinates [(690883.9029000001, 6580352.031)]
# Skipping invalid value 255 at coordinates [(679980.5745999999, 6602618.4019)]
# Skipping invalid value 255 at coordinates [(708731.5776000004, 6592517.9952)]
# Skipping invalid value 255 at coordinates [(698056.7525000004, 6591147.1521)]
# Skipping invalid value 255 at coordinates [(698960.8870000001, 6568254.0181)]
# Skipping invalid value 255 at coordinates [(708500.1891999999, 6590365.6486)]
# Skipping invalid value 255 at coordinates [(701797.068, 6588818.8626)]
# Skipping invalid value 255 at coordinates [(703228.7085999995, 6579902.504)]
# Skipping invalid value 255 at coordinates [(692713.8925000001, 6567680.0679)]
# Skipping invalid value 255 at coordinates [(703330.7960000001, 6579902.504)]
# Skipping invalid value 255 at coordinates [(707889.0376000004, 6590427.5369)]
# Skipping invalid value 255 at coordinates [(679875.1328999996, 6602525.3526)]
# Skipping invalid value 255 at coordinates [(679845.7358999997, 6602455.2579)]
# Skipping invalid value 255 at coordinates [(702424.5541000003, 6578984.8591)]
# Skipping invalid value 255 at coordinates [(708634.9680000003, 6590346.1374)]
# Skipping invalid value 255 at coordinates [(694247.0718999999, 6567504.6648)]
# Skipping invalid value 255 at coordinates [(689174.9493000004, 6590143.8048)]
# Skipping invalid value 255 at coordinates [(701682.3980999999, 6588873.4917)]
# Skipping invalid value 255 at coordinates [(693016.0283000004, 6598394.2897)]
# Skipping invalid value 255 at coordinates [(708714.5022999998, 6589524.5199)]
# Skipping invalid value 255 at coordinates [(689803.7492000004, 6570131.5488)]
# Skipping invalid value 255 at coordinates [(690966.3459999999, 6580536.1162)]
# Skipping invalid value 255 at coordinates [(677816.0344000002, 6577293.8581)]
# Skipping invalid value 255 at coordinates [(708678.2279000003, 6590353.891)]
# Skipping invalid value 255 at coordinates [(702933.3103, 6579569.8428)]
# Skipping invalid value 255 at coordinates [(699032.5999999996, 6568255.123)]
# Skipping invalid value 255 at coordinates [(679913.3339999998, 6602465.2133)]
# Skipping invalid value 255 at coordinates [(707867.6095000003, 6590368.5783)]
# Skipping invalid value 255 at coordinates [(708733.2127999999, 6590355.6482)]
# Skipping invalid value 255 at coordinates [(690847.1199000003, 6580315.3625)]
# Skipping invalid value 255 at coordinates [(689928.6984999999, 6570127.1777)]
# Skipping invalid value 255 at coordinates [(695098.1168999998, 6567396.3136)]
# Skipping invalid value 255 at coordinates [(690380.9842999997, 6594385.0968)]
# Skipping invalid value 255 at coordinates [(693658.5997000001, 6567642.4525)]
# Skipping invalid value 255 at coordinates [(692996.8071999997, 6598449.3384)]
# Skipping invalid value 255 at coordinates [(692647.8552000001, 6567968.2175)]
# Skipping invalid value 255 at coordinates [(708400.1962000001, 6590473.1306)]
# Skipping invalid value 255 at coordinates [(690433.9988000002, 6579176.4563)]
# Skipping invalid value 255 at coordinates [(692828.1728999997, 6568093.3901)]
# Skipping invalid value 255 at coordinates [(698162.1957, 6591094.3607)]
# Skipping invalid value 255 at coordinates [(689304.2660999997, 6590074.5991)]
# Skipping invalid value 255 at coordinates [(689751.7734000003, 6570131.0613)]
# Skipping invalid value 255 at coordinates [(708903.4233999997, 6590186.887)]
# Skipping invalid value 255 at coordinates [(691005.8410999998, 6599731.2167)]
# Skipping invalid value 255 at coordinates [(692875.5450999998, 6598371.8647)]
# Skipping invalid value 255 at coordinates [(690807.0250000004, 6580248.7889)]
# Skipping invalid value 255 at coordinates [(689750.3816, 6570256.7704)]
# Skipping invalid value 255 at coordinates [(692998.3472999996, 6567683.7487)]
# Skipping invalid value 255 at coordinates [(703272.8957000002, 6579910.1225)]
# Skipping invalid value 255 at coordinates [(701699.7012999998, 6588825.7231)]
# Skipping invalid value 255 at coordinates [(690142.5062999995, 6570357.0003)]
# Skipping invalid value 255 at coordinates [(707958.1490000002, 6590428.4815)]
# Skipping invalid value 255 at coordinates [(690984.4256999996, 6581705.8585)]
# Skipping invalid value 255 at coordinates [(708853.5695000002, 6592514.3622)]
# Skipping invalid value 255 at coordinates [(690028.6464999998, 6570195.3239)]
# Skipping invalid value 255 at coordinates [(689673.0053000003, 6570333.7507)]
# Skipping invalid value 255 at coordinates [(708798.9249999998, 6592519.7445)]
# Skipping invalid value 255 at coordinates [(690261.2017999999, 6578711.4855)]
# Skipping invalid value 255 at coordinates [(691174.7335999999, 6599909.8615)]
# Skipping invalid value 255 at coordinates [(679966.9708000002, 6602519.9086)]
# Skipping invalid value 255 at coordinates [(708715.4469999997, 6590395.4149)]
# Skipping invalid value 255 at coordinates [(690253.4134, 6578670.9749)]
# Skipping invalid value 255 at coordinates [(691008.0576, 6599848.2446)]
# Skipping invalid value 255 at coordinates [(679934.3771000002, 6602510.6498)]
# Skipping invalid value 255 at coordinates [(690953.8724999996, 6580463.4292)]
# Skipping invalid value 255 at coordinates [(677871.7384000001, 6577336.4184)]
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_20_2020_1377_RGB_RECT_projected_classified.tif
# Skipping invalid value 255 at coordinates [(689963.5349000003, 6570128.567)]
# Skipping invalid value 255 at coordinates [(690554.9042999996, 6594323.7953)]
# Skipping invalid value 255 at coordinates [(701864.3657, 6588811.1657)]
# Skipping invalid value 255 at coordinates [(689763.1364000002, 6570196.1107)]
# Skipping invalid value 255 at coordinates [(690387.2967999997, 6594332.7356)]
# Skipping invalid value 255 at coordinates [(690942.4511000002, 6599787.0709)]
# Skipping invalid value 255 at coordinates [(690883.9029000001, 6580352.031)]
# Skipping invalid value 255 at coordinates [(679980.5745999999, 6602618.4019)]
# Skipping invalid value 255 at coordinates [(708731.5776000004, 6592517.9952)]
# Skipping invalid value 255 at coordinates [(698056.7525000004, 6591147.1521)]
# Skipping invalid value 255 at coordinates [(698960.8870000001, 6568254.0181)]
# Skipping invalid value 255 at coordinates [(708500.1891999999, 6590365.6486)]
# Skipping invalid value 255 at coordinates [(701797.068, 6588818.8626)]
# Skipping invalid value 255 at coordinates [(703228.7085999995, 6579902.504)]
# Skipping invalid value 255 at coordinates [(692713.8925000001, 6567680.0679)]
# Skipping invalid value 255 at coordinates [(703330.7960000001, 6579902.504)]
# Skipping invalid value 255 at coordinates [(707889.0376000004, 6590427.5369)]
# Skipping invalid value 255 at coordinates [(679875.1328999996, 6602525.3526)]
# Skipping invalid value 255 at coordinates [(679845.7358999997, 6602455.2579)]
# Skipping invalid value 255 at coordinates [(702424.5541000003, 6578984.8591)]
# Skipping invalid value 255 at coordinates [(708634.9680000003, 6590346.1374)]
# Skipping invalid value 255 at coordinates [(694247.0718999999, 6567504.6648)]
# Skipping invalid value 255 at coordinates [(689174.9493000004, 6590143.8048)]
# Skipping invalid value 255 at coordinates [(701682.3980999999, 6588873.4917)]
# Skipping invalid value 255 at coordinates [(693016.0283000004, 6598394.2897)]
# Skipping invalid value 255 at coordinates [(708714.5022999998, 6589524.5199)]
# Skipping invalid value 255 at coordinates [(689803.7492000004, 6570131.5488)]
# Skipping invalid value 255 at coordinates [(690966.3459999999, 6580536.1162)]
# Skipping invalid value 255 at coordinates [(677816.0344000002, 6577293.8581)]
# Skipping invalid value 255 at coordinates [(708678.2279000003, 6590353.891)]
# Skipping invalid value 255 at coordinates [(702933.3103, 6579569.8428)]
# Skipping invalid value 255 at coordinates [(699032.5999999996, 6568255.123)]
# Skipping invalid value 255 at coordinates [(679913.3339999998, 6602465.2133)]
# Skipping invalid value 255 at coordinates [(707867.6095000003, 6590368.5783)]
# Skipping invalid value 255 at coordinates [(708733.2127999999, 6590355.6482)]
# Skipping invalid value 255 at coordinates [(690847.1199000003, 6580315.3625)]
# Skipping invalid value 255 at coordinates [(689928.6984999999, 6570127.1777)]
# Skipping invalid value 255 at coordinates [(695098.1168999998, 6567396.3136)]
# Skipping invalid value 255 at coordinates [(690380.9842999997, 6594385.0968)]
# Skipping invalid value 255 at coordinates [(693658.5997000001, 6567642.4525)]
# Skipping invalid value 255 at coordinates [(692996.8071999997, 6598449.3384)]
# Skipping invalid value 255 at coordinates [(692647.8552000001, 6567968.2175)]
# Skipping invalid value 255 at coordinates [(708400.1962000001, 6590473.1306)]
# Skipping invalid value 255 at coordinates [(690433.9988000002, 6579176.4563)]
# Skipping invalid value 255 at coordinates [(692828.1728999997, 6568093.3901)]
# Skipping invalid value 255 at coordinates [(698162.1957, 6591094.3607)]
# Skipping invalid value 255 at coordinates [(689304.2660999997, 6590074.5991)]
# Skipping invalid value 255 at coordinates [(689751.7734000003, 6570131.0613)]
# Skipping invalid value 255 at coordinates [(708903.4233999997, 6590186.887)]
# Skipping invalid value 255 at coordinates [(691005.8410999998, 6599731.2167)]
# Skipping invalid value 255 at coordinates [(692875.5450999998, 6598371.8647)]
# Skipping invalid value 255 at coordinates [(690807.0250000004, 6580248.7889)]
# Skipping invalid value 255 at coordinates [(689750.3816, 6570256.7704)]
# Skipping invalid value 255 at coordinates [(692998.3472999996, 6567683.7487)]
# Skipping invalid value 255 at coordinates [(703272.8957000002, 6579910.1225)]
# Skipping invalid value 255 at coordinates [(701699.7012999998, 6588825.7231)]
# Skipping invalid value 255 at coordinates [(690142.5062999995, 6570357.0003)]
# Skipping invalid value 255 at coordinates [(707958.1490000002, 6590428.4815)]
# Skipping invalid value 255 at coordinates [(690984.4256999996, 6581705.8585)]
# Skipping invalid value 255 at coordinates [(708853.5695000002, 6592514.3622)]
# Skipping invalid value 255 at coordinates [(690028.6464999998, 6570195.3239)]
# Skipping invalid value 255 at coordinates [(689673.0053000003, 6570333.7507)]
# Skipping invalid value 255 at coordinates [(708798.9249999998, 6592519.7445)]
# Skipping invalid value 255 at coordinates [(690261.2017999999, 6578711.4855)]
# Skipping invalid value 255 at coordinates [(691174.7335999999, 6599909.8615)]
# Skipping invalid value 255 at coordinates [(679966.9708000002, 6602519.9086)]
# Skipping invalid value 255 at coordinates [(708715.4469999997, 6590395.4149)]
# Skipping invalid value 255 at coordinates [(690253.4134, 6578670.9749)]
# Skipping invalid value 255 at coordinates [(691008.0576, 6599848.2446)]
# Skipping invalid value 255 at coordinates [(679934.3771000002, 6602510.6498)]
# Skipping invalid value 255 at coordinates [(690953.8724999996, 6580463.4292)]
# Skipping invalid value 255 at coordinates [(677871.7384000001, 6577336.4184)]
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_21_2020_1377_RGB_RECT_projected_classified.tif
# Skipping invalid value 0 at coordinates [(689963.5349000003, 6570128.567)]
# Skipping invalid value 0 at coordinates [(690554.9042999996, 6594323.7953)]
# Skipping invalid value 0 at coordinates [(701864.3657, 6588811.1657)]
# Skipping invalid value 0 at coordinates [(689763.1364000002, 6570196.1107)]
# Skipping invalid value 0 at coordinates [(690387.2967999997, 6594332.7356)]
# Skipping invalid value 0 at coordinates [(690942.4511000002, 6599787.0709)]
# Skipping invalid value 0 at coordinates [(690883.9029000001, 6580352.031)]
# Skipping invalid value 0 at coordinates [(679980.5745999999, 6602618.4019)]
# Skipping invalid value 0 at coordinates [(708731.5776000004, 6592517.9952)]
# Skipping invalid value 0 at coordinates [(698056.7525000004, 6591147.1521)]
# Skipping invalid value 0 at coordinates [(698960.8870000001, 6568254.0181)]
# Skipping invalid value 0 at coordinates [(708500.1891999999, 6590365.6486)]
# Skipping invalid value 0 at coordinates [(701797.068, 6588818.8626)]
# Skipping invalid value 0 at coordinates [(703228.7085999995, 6579902.504)]
# Skipping invalid value 0 at coordinates [(692713.8925000001, 6567680.0679)]
# Skipping invalid value 0 at coordinates [(703330.7960000001, 6579902.504)]
# Skipping invalid value 0 at coordinates [(707889.0376000004, 6590427.5369)]
# Skipping invalid value 0 at coordinates [(679875.1328999996, 6602525.3526)]
# Skipping invalid value 0 at coordinates [(679845.7358999997, 6602455.2579)]
# Skipping invalid value 0 at coordinates [(702424.5541000003, 6578984.8591)]
# Skipping invalid value 0 at coordinates [(708634.9680000003, 6590346.1374)]
# Skipping invalid value 0 at coordinates [(694247.0718999999, 6567504.6648)]
# Skipping invalid value 0 at coordinates [(689174.9493000004, 6590143.8048)]
# Skipping invalid value 0 at coordinates [(701682.3980999999, 6588873.4917)]
# Skipping invalid value 0 at coordinates [(693016.0283000004, 6598394.2897)]
# Skipping invalid value 0 at coordinates [(708714.5022999998, 6589524.5199)]
# Skipping invalid value 0 at coordinates [(689803.7492000004, 6570131.5488)]
# Skipping invalid value 0 at coordinates [(690966.3459999999, 6580536.1162)]
# Skipping invalid value 0 at coordinates [(677816.0344000002, 6577293.8581)]
# Skipping invalid value 0 at coordinates [(708678.2279000003, 6590353.891)]
# Skipping invalid value 0 at coordinates [(702933.3103, 6579569.8428)]
# Skipping invalid value 0 at coordinates [(699032.5999999996, 6568255.123)]
# Skipping invalid value 0 at coordinates [(679913.3339999998, 6602465.2133)]
# Skipping invalid value 0 at coordinates [(707867.6095000003, 6590368.5783)]
# Skipping invalid value 0 at coordinates [(708733.2127999999, 6590355.6482)]
# Skipping invalid value 0 at coordinates [(690847.1199000003, 6580315.3625)]
# Skipping invalid value 0 at coordinates [(689928.6984999999, 6570127.1777)]
# Skipping invalid value 0 at coordinates [(695098.1168999998, 6567396.3136)]
# Skipping invalid value 0 at coordinates [(690380.9842999997, 6594385.0968)]
# Skipping invalid value 0 at coordinates [(693658.5997000001, 6567642.4525)]
# Skipping invalid value 0 at coordinates [(692996.8071999997, 6598449.3384)]
# Skipping invalid value 0 at coordinates [(692647.8552000001, 6567968.2175)]
# Skipping invalid value 0 at coordinates [(708400.1962000001, 6590473.1306)]
# Skipping invalid value 0 at coordinates [(690433.9988000002, 6579176.4563)]
# Skipping invalid value 0 at coordinates [(692828.1728999997, 6568093.3901)]
# Skipping invalid value 0 at coordinates [(698162.1957, 6591094.3607)]
# Skipping invalid value 0 at coordinates [(689304.2660999997, 6590074.5991)]
# Skipping invalid value 0 at coordinates [(689751.7734000003, 6570131.0613)]
# Skipping invalid value 0 at coordinates [(708903.4233999997, 6590186.887)]
# Skipping invalid value 0 at coordinates [(691005.8410999998, 6599731.2167)]
# Skipping invalid value 0 at coordinates [(692875.5450999998, 6598371.8647)]
# Skipping invalid value 0 at coordinates [(690807.0250000004, 6580248.7889)]
# Skipping invalid value 0 at coordinates [(689750.3816, 6570256.7704)]
# Skipping invalid value 0 at coordinates [(692998.3472999996, 6567683.7487)]
# Skipping invalid value 0 at coordinates [(703272.8957000002, 6579910.1225)]
# Skipping invalid value 0 at coordinates [(701699.7012999998, 6588825.7231)]
# Skipping invalid value 0 at coordinates [(690142.5062999995, 6570357.0003)]
# Skipping invalid value 0 at coordinates [(707958.1490000002, 6590428.4815)]
# Skipping invalid value 0 at coordinates [(690984.4256999996, 6581705.8585)]
# Skipping invalid value 0 at coordinates [(708853.5695000002, 6592514.3622)]
# Skipping invalid value 0 at coordinates [(690028.6464999998, 6570195.3239)]
# Skipping invalid value 0 at coordinates [(689673.0053000003, 6570333.7507)]
# Skipping invalid value 0 at coordinates [(708798.9249999998, 6592519.7445)]
# Skipping invalid value 0 at coordinates [(690261.2017999999, 6578711.4855)]
# Skipping invalid value 0 at coordinates [(691174.7335999999, 6599909.8615)]
# Skipping invalid value 0 at coordinates [(679966.9708000002, 6602519.9086)]
# Skipping invalid value 0 at coordinates [(708715.4469999997, 6590395.4149)]
# Skipping invalid value 0 at coordinates [(690253.4134, 6578670.9749)]
# Skipping invalid value 0 at coordinates [(691008.0576, 6599848.2446)]
# Skipping invalid value 0 at coordinates [(679934.3771000002, 6602510.6498)]
# Skipping invalid value 0 at coordinates [(690953.8724999996, 6580463.4292)]
# Skipping invalid value 0 at coordinates [(677871.7384000001, 6577336.4184)]
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_22_2020_1377_RGB_RECT_projected_classified.tif
# Skipping invalid value 255 at coordinates [(689963.5349000003, 6570128.567)]
# Skipping invalid value 255 at coordinates [(690554.9042999996, 6594323.7953)]
# Skipping invalid value 255 at coordinates [(701864.3657, 6588811.1657)]
# Skipping invalid value 255 at coordinates [(689763.1364000002, 6570196.1107)]
# Skipping invalid value 255 at coordinates [(690387.2967999997, 6594332.7356)]
# Skipping invalid value 255 at coordinates [(690942.4511000002, 6599787.0709)]
# Skipping invalid value 255 at coordinates [(690883.9029000001, 6580352.031)]
# Skipping invalid value 255 at coordinates [(679980.5745999999, 6602618.4019)]
# Skipping invalid value 255 at coordinates [(708731.5776000004, 6592517.9952)]
# Skipping invalid value 255 at coordinates [(698056.7525000004, 6591147.1521)]
# Skipping invalid value 255 at coordinates [(698960.8870000001, 6568254.0181)]
# Skipping invalid value 255 at coordinates [(708500.1891999999, 6590365.6486)]
# Skipping invalid value 255 at coordinates [(701797.068, 6588818.8626)]
# Skipping invalid value 255 at coordinates [(703228.7085999995, 6579902.504)]
# Skipping invalid value 255 at coordinates [(692713.8925000001, 6567680.0679)]
# Skipping invalid value 255 at coordinates [(703330.7960000001, 6579902.504)]
# Skipping invalid value 255 at coordinates [(707889.0376000004, 6590427.5369)]
# Skipping invalid value 255 at coordinates [(679875.1328999996, 6602525.3526)]
# Skipping invalid value 255 at coordinates [(679845.7358999997, 6602455.2579)]
# Skipping invalid value 255 at coordinates [(702424.5541000003, 6578984.8591)]
# Skipping invalid value 255 at coordinates [(708634.9680000003, 6590346.1374)]
# Skipping invalid value 255 at coordinates [(694247.0718999999, 6567504.6648)]
# Skipping invalid value 255 at coordinates [(689174.9493000004, 6590143.8048)]
# Skipping invalid value 255 at coordinates [(701682.3980999999, 6588873.4917)]
# Skipping invalid value 255 at coordinates [(693016.0283000004, 6598394.2897)]
# Skipping invalid value 255 at coordinates [(708714.5022999998, 6589524.5199)]
# Skipping invalid value 255 at coordinates [(689803.7492000004, 6570131.5488)]
# Skipping invalid value 255 at coordinates [(690966.3459999999, 6580536.1162)]
# Skipping invalid value 255 at coordinates [(677816.0344000002, 6577293.8581)]
# Skipping invalid value 255 at coordinates [(708678.2279000003, 6590353.891)]
# Skipping invalid value 255 at coordinates [(702933.3103, 6579569.8428)]
# Skipping invalid value 255 at coordinates [(699032.5999999996, 6568255.123)]
# Skipping invalid value 255 at coordinates [(679913.3339999998, 6602465.2133)]
# Skipping invalid value 255 at coordinates [(707867.6095000003, 6590368.5783)]
# Skipping invalid value 255 at coordinates [(708733.2127999999, 6590355.6482)]
# Skipping invalid value 255 at coordinates [(690847.1199000003, 6580315.3625)]
# Skipping invalid value 255 at coordinates [(689928.6984999999, 6570127.1777)]
# Skipping invalid value 255 at coordinates [(695098.1168999998, 6567396.3136)]
# Skipping invalid value 255 at coordinates [(690380.9842999997, 6594385.0968)]
# Skipping invalid value 255 at coordinates [(693658.5997000001, 6567642.4525)]
# Skipping invalid value 255 at coordinates [(692996.8071999997, 6598449.3384)]
# Skipping invalid value 255 at coordinates [(692647.8552000001, 6567968.2175)]
# Skipping invalid value 255 at coordinates [(708400.1962000001, 6590473.1306)]
# Skipping invalid value 255 at coordinates [(690433.9988000002, 6579176.4563)]
# Skipping invalid value 255 at coordinates [(692828.1728999997, 6568093.3901)]
# Skipping invalid value 255 at coordinates [(698162.1957, 6591094.3607)]
# Skipping invalid value 255 at coordinates [(689304.2660999997, 6590074.5991)]
# Skipping invalid value 255 at coordinates [(689751.7734000003, 6570131.0613)]
# Skipping invalid value 255 at coordinates [(708903.4233999997, 6590186.887)]
# Skipping invalid value 255 at coordinates [(691005.8410999998, 6599731.2167)]
# Skipping invalid value 255 at coordinates [(692875.5450999998, 6598371.8647)]
# Skipping invalid value 255 at coordinates [(690807.0250000004, 6580248.7889)]
# Skipping invalid value 255 at coordinates [(689750.3816, 6570256.7704)]
# Skipping invalid value 255 at coordinates [(692998.3472999996, 6567683.7487)]
# Skipping invalid value 255 at coordinates [(703272.8957000002, 6579910.1225)]
# Skipping invalid value 255 at coordinates [(701699.7012999998, 6588825.7231)]
# Skipping invalid value 255 at coordinates [(690142.5062999995, 6570357.0003)]
# Skipping invalid value 255 at coordinates [(707958.1490000002, 6590428.4815)]
# Skipping invalid value 255 at coordinates [(690984.4256999996, 6581705.8585)]
# Skipping invalid value 255 at coordinates [(708853.5695000002, 6592514.3622)]
# Skipping invalid value 255 at coordinates [(690028.6464999998, 6570195.3239)]
# Skipping invalid value 255 at coordinates [(689673.0053000003, 6570333.7507)]
# Skipping invalid value 255 at coordinates [(708798.9249999998, 6592519.7445)]
# Skipping invalid value 255 at coordinates [(690261.2017999999, 6578711.4855)]
# Skipping invalid value 255 at coordinates [(691174.7335999999, 6599909.8615)]
# Skipping invalid value 255 at coordinates [(679966.9708000002, 6602519.9086)]
# Skipping invalid value 255 at coordinates [(708715.4469999997, 6590395.4149)]
# Skipping invalid value 255 at coordinates [(690253.4134, 6578670.9749)]
# Skipping invalid value 255 at coordinates [(691008.0576, 6599848.2446)]
# Skipping invalid value 255 at coordinates [(679934.3771000002, 6602510.6498)]
# Skipping invalid value 255 at coordinates [(690953.8724999996, 6580463.4292)]
# Skipping invalid value 255 at coordinates [(677871.7384000001, 6577336.4184)]
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_23_2020_1377_RGB_RECT_projected_classified.tif
# Skipping invalid value 255 at coordinates [(689963.5349000003, 6570128.567)]
# Skipping invalid value 255 at coordinates [(690554.9042999996, 6594323.7953)]
# Skipping invalid value 255 at coordinates [(701864.3657, 6588811.1657)]
# Skipping invalid value 255 at coordinates [(689763.1364000002, 6570196.1107)]
# Skipping invalid value 255 at coordinates [(690387.2967999997, 6594332.7356)]
# Skipping invalid value 255 at coordinates [(690942.4511000002, 6599787.0709)]
# Skipping invalid value 255 at coordinates [(690883.9029000001, 6580352.031)]
# Skipping invalid value 255 at coordinates [(679980.5745999999, 6602618.4019)]
# Skipping invalid value 255 at coordinates [(708731.5776000004, 6592517.9952)]
# Skipping invalid value 255 at coordinates [(698056.7525000004, 6591147.1521)]
# Skipping invalid value 255 at coordinates [(698960.8870000001, 6568254.0181)]
# Skipping invalid value 255 at coordinates [(708500.1891999999, 6590365.6486)]
# Skipping invalid value 255 at coordinates [(701797.068, 6588818.8626)]
# Skipping invalid value 255 at coordinates [(703228.7085999995, 6579902.504)]
# Skipping invalid value 255 at coordinates [(692713.8925000001, 6567680.0679)]
# Skipping invalid value 255 at coordinates [(703330.7960000001, 6579902.504)]
# Skipping invalid value 255 at coordinates [(707889.0376000004, 6590427.5369)]
# Skipping invalid value 255 at coordinates [(679875.1328999996, 6602525.3526)]
# Skipping invalid value 255 at coordinates [(679845.7358999997, 6602455.2579)]
# Skipping invalid value 255 at coordinates [(702424.5541000003, 6578984.8591)]
# Skipping invalid value 255 at coordinates [(708634.9680000003, 6590346.1374)]
# Skipping invalid value 255 at coordinates [(694247.0718999999, 6567504.6648)]
# Skipping invalid value 255 at coordinates [(689174.9493000004, 6590143.8048)]
# Skipping invalid value 255 at coordinates [(701682.3980999999, 6588873.4917)]
# Skipping invalid value 255 at coordinates [(693016.0283000004, 6598394.2897)]
# Skipping invalid value 255 at coordinates [(708714.5022999998, 6589524.5199)]
# Skipping invalid value 255 at coordinates [(689803.7492000004, 6570131.5488)]
# Skipping invalid value 255 at coordinates [(690966.3459999999, 6580536.1162)]
# Skipping invalid value 255 at coordinates [(677816.0344000002, 6577293.8581)]
# Skipping invalid value 255 at coordinates [(708678.2279000003, 6590353.891)]
# Skipping invalid value 255 at coordinates [(702933.3103, 6579569.8428)]
# Skipping invalid value 255 at coordinates [(699032.5999999996, 6568255.123)]
# Skipping invalid value 255 at coordinates [(679913.3339999998, 6602465.2133)]
# Skipping invalid value 255 at coordinates [(707867.6095000003, 6590368.5783)]
# Skipping invalid value 255 at coordinates [(708733.2127999999, 6590355.6482)]
# Skipping invalid value 255 at coordinates [(690847.1199000003, 6580315.3625)]
# Skipping invalid value 255 at coordinates [(689928.6984999999, 6570127.1777)]
# Skipping invalid value 255 at coordinates [(695098.1168999998, 6567396.3136)]
# Skipping invalid value 255 at coordinates [(690380.9842999997, 6594385.0968)]
# Skipping invalid value 255 at coordinates [(693658.5997000001, 6567642.4525)]
# Skipping invalid value 255 at coordinates [(692996.8071999997, 6598449.3384)]
# Skipping invalid value 255 at coordinates [(692647.8552000001, 6567968.2175)]
# Skipping invalid value 255 at coordinates [(708400.1962000001, 6590473.1306)]
# Skipping invalid value 255 at coordinates [(690433.9988000002, 6579176.4563)]
# Skipping invalid value 255 at coordinates [(692828.1728999997, 6568093.3901)]
# Skipping invalid value 255 at coordinates [(698162.1957, 6591094.3607)]
# Skipping invalid value 255 at coordinates [(689304.2660999997, 6590074.5991)]
# Skipping invalid value 255 at coordinates [(689751.7734000003, 6570131.0613)]
# Skipping invalid value 255 at coordinates [(708903.4233999997, 6590186.887)]
# Skipping invalid value 255 at coordinates [(691005.8410999998, 6599731.2167)]
# Skipping invalid value 255 at coordinates [(692875.5450999998, 6598371.8647)]
# Skipping invalid value 255 at coordinates [(690807.0250000004, 6580248.7889)]
# Skipping invalid value 255 at coordinates [(689750.3816, 6570256.7704)]
# Skipping invalid value 255 at coordinates [(692998.3472999996, 6567683.7487)]
# Skipping invalid value 255 at coordinates [(703272.8957000002, 6579910.1225)]
# Skipping invalid value 255 at coordinates [(701699.7012999998, 6588825.7231)]
# Skipping invalid value 255 at coordinates [(690142.5062999995, 6570357.0003)]
# Skipping invalid value 255 at coordinates [(707958.1490000002, 6590428.4815)]
# Skipping invalid value 255 at coordinates [(690984.4256999996, 6581705.8585)]
# Skipping invalid value 255 at coordinates [(708853.5695000002, 6592514.3622)]
# Skipping invalid value 255 at coordinates [(690028.6464999998, 6570195.3239)]
# Skipping invalid value 255 at coordinates [(689673.0053000003, 6570333.7507)]
# Skipping invalid value 255 at coordinates [(708798.9249999998, 6592519.7445)]
# Skipping invalid value 255 at coordinates [(690261.2017999999, 6578711.4855)]
# Skipping invalid value 255 at coordinates [(691174.7335999999, 6599909.8615)]
# Skipping invalid value 255 at coordinates [(679966.9708000002, 6602519.9086)]
# Skipping invalid value 255 at coordinates [(708715.4469999997, 6590395.4149)]
# Skipping invalid value 255 at coordinates [(690253.4134, 6578670.9749)]
# Skipping invalid value 255 at coordinates [(691008.0576, 6599848.2446)]
# Skipping invalid value 255 at coordinates [(679934.3771000002, 6602510.6498)]
# Skipping invalid value 255 at coordinates [(690953.8724999996, 6580463.4292)]
# Skipping invalid value 255 at coordinates [(677871.7384000001, 6577336.4184)]
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_24_2020_1377_RGB_RECT_projected_classified.tif
# Skipping invalid value 255 at coordinates [(689963.5349000003, 6570128.567)]
# Skipping invalid value 255 at coordinates [(690554.9042999996, 6594323.7953)]
# Skipping invalid value 255 at coordinates [(701864.3657, 6588811.1657)]
# Skipping invalid value 255 at coordinates [(689763.1364000002, 6570196.1107)]
# Skipping invalid value 255 at coordinates [(690387.2967999997, 6594332.7356)]
# Skipping invalid value 255 at coordinates [(690942.4511000002, 6599787.0709)]
# Skipping invalid value 255 at coordinates [(690883.9029000001, 6580352.031)]
# Skipping invalid value 255 at coordinates [(679980.5745999999, 6602618.4019)]
# Skipping invalid value 255 at coordinates [(708731.5776000004, 6592517.9952)]
# Skipping invalid value 255 at coordinates [(698056.7525000004, 6591147.1521)]
# Skipping invalid value 255 at coordinates [(698960.8870000001, 6568254.0181)]
# Skipping invalid value 255 at coordinates [(708500.1891999999, 6590365.6486)]
# Skipping invalid value 255 at coordinates [(701797.068, 6588818.8626)]
# Skipping invalid value 255 at coordinates [(703228.7085999995, 6579902.504)]
# Skipping invalid value 255 at coordinates [(692713.8925000001, 6567680.0679)]
# Skipping invalid value 255 at coordinates [(703330.7960000001, 6579902.504)]
# Skipping invalid value 255 at coordinates [(707889.0376000004, 6590427.5369)]
# Skipping invalid value 255 at coordinates [(679875.1328999996, 6602525.3526)]
# Skipping invalid value 255 at coordinates [(679845.7358999997, 6602455.2579)]
# Skipping invalid value 255 at coordinates [(702424.5541000003, 6578984.8591)]
# Skipping invalid value 255 at coordinates [(708634.9680000003, 6590346.1374)]
# Skipping invalid value 255 at coordinates [(694247.0718999999, 6567504.6648)]
# Skipping invalid value 255 at coordinates [(689174.9493000004, 6590143.8048)]
# Skipping invalid value 255 at coordinates [(701682.3980999999, 6588873.4917)]
# Skipping invalid value 255 at coordinates [(693016.0283000004, 6598394.2897)]
# Skipping invalid value 255 at coordinates [(708714.5022999998, 6589524.5199)]
# Skipping invalid value 255 at coordinates [(689803.7492000004, 6570131.5488)]
# Skipping invalid value 255 at coordinates [(690966.3459999999, 6580536.1162)]
# Skipping invalid value 255 at coordinates [(677816.0344000002, 6577293.8581)]
# Skipping invalid value 255 at coordinates [(708678.2279000003, 6590353.891)]
# Skipping invalid value 255 at coordinates [(702933.3103, 6579569.8428)]
# Skipping invalid value 255 at coordinates [(699032.5999999996, 6568255.123)]
# Skipping invalid value 255 at coordinates [(679913.3339999998, 6602465.2133)]
# Skipping invalid value 255 at coordinates [(707867.6095000003, 6590368.5783)]
# Skipping invalid value 255 at coordinates [(708733.2127999999, 6590355.6482)]
# Skipping invalid value 255 at coordinates [(690847.1199000003, 6580315.3625)]
# Skipping invalid value 255 at coordinates [(689928.6984999999, 6570127.1777)]
# Skipping invalid value 255 at coordinates [(695098.1168999998, 6567396.3136)]
# Skipping invalid value 255 at coordinates [(690380.9842999997, 6594385.0968)]
# Skipping invalid value 255 at coordinates [(693658.5997000001, 6567642.4525)]
# Skipping invalid value 255 at coordinates [(692996.8071999997, 6598449.3384)]
# ...
# Skipping invalid value 255 at coordinates [(693016.0283000004, 6598394.2897)]
# Skipping invalid value 255 at coordinates [(708714.5022999998, 6589524.5199)]
# Skipping invalid value 255 at coordinates [(689803.7492000004, 6570131.5488)]
# Skipping invalid value 255 at coordinates [(690966.3459999999, 6580536.1162)]
# Skipping invalid value 255 at coordinates [(677816.0344000002, 6577293.8581)]
# Skipping invalid value 255 at coordinates [(708678.2279000003, 6590353.891)]
# Skipping invalid value 255 at coordinates [(702933.3103, 6579569.8428)]
# Skipping invalid value 255 at coordinates [(699032.5999999996, 6568255.123)]
# Skipping invalid value 255 at coordinates [(679913.3339999998, 6602465.2133)]
# Skipping invalid value 255 at coordinates [(707867.6095000003, 6590368.5783)]
# Skipping invalid value 255 at coordinates [(708733.2127999999, 6590355.6482)]
# Skipping invalid value 255 at coordinates [(690847.1199000003, 6580315.3625)]
# Skipping invalid value 255 at coordinates [(689928.6984999999, 6570127.1777)]
# Skipping invalid value 255 at coordinates [(695098.1168999998, 6567396.3136)]
# Skipping invalid value 255 at coordinates [(690380.9842999997, 6594385.0968)]
# Skipping invalid value 255 at coordinates [(693658.5997000001, 6567642.4525)]
# Skipping invalid value 255 at coordinates [(692996.8071999997, 6598449.3384)]
# Skipping invalid value 255 at coordinates [(692647.8552000001, 6567968.2175)]
# Skipping invalid value 255 at coordinates [(708400.1962000001, 6590473.1306)]
# Skipping invalid value 255 at coordinates [(690433.9988000002, 6579176.4563)]
# Skipping invalid value 255 at coordinates [(692828.1728999997, 6568093.3901)]
# Skipping invalid value 255 at coordinates [(698162.1957, 6591094.3607)]
# Skipping invalid value 255 at coordinates [(689304.2660999997, 6590074.5991)]
# Skipping invalid value 255 at coordinates [(689751.7734000003, 6570131.0613)]
# Skipping invalid value 255 at coordinates [(708903.4233999997, 6590186.887)]
# Skipping invalid value 255 at coordinates [(691005.8410999998, 6599731.2167)]
# Skipping invalid value 255 at coordinates [(692875.5450999998, 6598371.8647)]
# Skipping invalid value 255 at coordinates [(690807.0250000004, 6580248.7889)]
# Skipping invalid value 255 at coordinates [(689750.3816, 6570256.7704)]
# Skipping invalid value 255 at coordinates [(692998.3472999996, 6567683.7487)]
# Skipping invalid value 255 at coordinates [(703272.8957000002, 6579910.1225)]
# Skipping invalid value 255 at coordinates [(701699.7012999998, 6588825.7231)]
# Skipping invalid value 255 at coordinates [(690142.5062999995, 6570357.0003)]
# Skipping invalid value 255 at coordinates [(707958.1490000002, 6590428.4815)]
# Skipping invalid value 255 at coordinates [(690984.4256999996, 6581705.8585)]
# Skipping invalid value 255 at coordinates [(708853.5695000002, 6592514.3622)]
# Skipping invalid value 255 at coordinates [(690028.6464999998, 6570195.3239)]
# Skipping invalid value 255 at coordinates [(689673.0053000003, 6570333.7507)]
# Skipping invalid value 255 at coordinates [(708798.9249999998, 6592519.7445)]
# Skipping invalid value 255 at coordinates [(690261.2017999999, 6578711.4855)]
# Skipping invalid value 255 at coordinates [(691174.7335999999, 6599909.8615)]
# Skipping invalid value 255 at coordinates [(679966.9708000002, 6602519.9086)]
# Skipping invalid value 255 at coordinates [(708715.4469999997, 6590395.4149)]
# Skipping invalid value 255 at coordinates [(690253.4134, 6578670.9749)]
# Skipping invalid value 255 at coordinates [(691008.0576, 6599848.2446)]
# Skipping invalid value 255 at coordinates [(679934.3771000002, 6602510.6498)]
# Skipping invalid value 255 at coordinates [(690953.8724999996, 6580463.4292)]
# Skipping invalid value 255 at coordinates [(677871.7384000001, 6577336.4184)]
# Processing: Z:\Data\CLASSIFIED\with_indices_3129AA_04_2020_1386_RGB_RECT_projected_classified.tif
# Skipping invalid value 255 at coordinates [(689963.5349000003, 6570128.567)]
# Skipping invalid value 255 at coordinates [(690554.9042999996, 6594323.7953)]
# Skipping invalid value 255 at coordinates [(701864.3657, 6588811.1657)]
# Skipping invalid value 255 at coordinates [(689763.1364000002, 6570196.1107)]
# Skipping invalid value 255 at coordinates [(690387.2967999997, 6594332.7356)]
# Skipping invalid value 255 at coordinates [(690942.4511000002, 6599787.0709)]
# Skipping invalid value 255 at coordinates [(690883.9029000001, 6580352.031)]
# Skipping invalid value 255 at coordinates [(679980.5745999999, 6602618.4019)]
# Skipping invalid value 255 at coordinates [(708731.5776000004, 6592517.9952)]
# Skipping invalid value 255 at coordinates [(698056.7525000004, 6591147.1521)]
# Skipping invalid value 255 at coordinates [(698960.8870000001, 6568254.0181)]
# Skipping invalid value 255 at coordinates [(708500.1891999999, 6590365.6486)]
# Skipping invalid value 255 at coordinates [(701797.068, 6588818.8626)]
# Skipping invalid value 255 at coordinates [(703228.7085999995, 6579902.504)]
# Skipping invalid value 255 at coordinates [(692713.8925000001, 6567680.0679)]
# Skipping invalid value 255 at coordinates [(703330.7960000001, 6579902.504)]
# Skipping invalid value 255 at coordinates [(707889.0376000004, 6590427.5369)]
# Skipping invalid value 255 at coordinates [(679875.1328999996, 6602525.3526)]
# Skipping invalid value 255 at coordinates [(679845.7358999997, 6602455.2579)]
# Skipping invalid value 255 at coordinates [(702424.5541000003, 6578984.8591)]
# Skipping invalid value 255 at coordinates [(708634.9680000003, 6590346.1374)]
# Skipping invalid value 255 at coordinates [(694247.0718999999, 6567504.6648)]
# Skipping invalid value 255 at coordinates [(689174.9493000004, 6590143.8048)]
# Skipping invalid value 255 at coordinates [(701682.3980999999, 6588873.4917)]
# Skipping invalid value 255 at coordinates [(693016.0283000004, 6598394.2897)]
# Skipping invalid value 255 at coordinates [(708714.5022999998, 6589524.5199)]
# Skipping invalid value 255 at coordinates [(689803.7492000004, 6570131.5488)]
# Skipping invalid value 255 at coordinates [(690966.3459999999, 6580536.1162)]
# Skipping invalid value 255 at coordinates [(677816.0344000002, 6577293.8581)]
# Skipping invalid value 255 at coordinates [(708678.2279000003, 6590353.891)]
# Skipping invalid value 255 at coordinates [(702933.3103, 6579569.8428)]
# Skipping invalid value 255 at coordinates [(699032.5999999996, 6568255.123)]
# Skipping invalid value 255 at coordinates [(679913.3339999998, 6602465.2133)]
# Skipping invalid value 255 at coordinates [(707867.6095000003, 6590368.5783)]
# Skipping invalid value 255 at coordinates [(708733.2127999999, 6590355.6482)]
# Skipping invalid value 255 at coordinates [(690847.1199000003, 6580315.3625)]
# Skipping invalid value 255 at coordinates [(689928.6984999999, 6570127.1777)]
# Skipping invalid value 255 at coordinates [(695098.1168999998, 6567396.3136)]
# Skipping invalid value 255 at coordinates [(690380.9842999997, 6594385.0968)]
# Skipping invalid value 255 at coordinates [(693658.5997000001, 6567642.4525)]
# Skipping invalid value 255 at coordinates [(692996.8071999997, 6598449.3384)]
# Skipping invalid value 255 at coordinates [(692647.8552000001, 6567968.2175)]
# Skipping invalid value 255 at coordinates [(708400.1962000001, 6590473.1306)]
# Skipping invalid value 255 at coordinates [(690433.9988000002, 6579176.4563)]
# Skipping invalid value 255 at coordinates [(692828.1728999997, 6568093.3901)]
# Skipping invalid value 255 at coordinates [(698162.1957, 6591094.3607)]
# Skipping invalid value 255 at coordinates [(689304.2660999997, 6590074.5991)]
# Skipping invalid value 255 at coordinates [(689751.7734000003, 6570131.0613)]
# Skipping invalid value 255 at coordinates [(708903.4233999997, 6590186.887)]
# Skipping invalid value 255 at coordinates [(691005.8410999998, 6599731.2167)]
# Skipping invalid value 255 at coordinates [(692875.5450999998, 6598371.8647)]
# Skipping invalid value 255 at coordinates [(690807.0250000004, 6580248.7889)]
# Skipping invalid value 255 at coordinates [(689750.3816, 6570256.7704)]
# Skipping invalid value 255 at coordinates [(692998.3472999996, 6567683.7487)]
# Skipping invalid value 255 at coordinates [(703272.8957000002, 6579910.1225)]
# Skipping invalid value 255 at coordinates [(701699.7012999998, 6588825.7231)]
# Skipping invalid value 255 at coordinates [(690142.5062999995, 6570357.0003)]
# Skipping invalid value 255 at coordinates [(707958.1490000002, 6590428.4815)]
# Skipping invalid value 255 at coordinates [(690984.4256999996, 6581705.8585)]
# Skipping invalid value 255 at coordinates [(708853.5695000002, 6592514.3622)]
# Skipping invalid value 255 at coordinates [(690028.6464999998, 6570195.3239)]
# Skipping invalid value 255 at coordinates [(689673.0053000003, 6570333.7507)]
# Skipping invalid value 255 at coordinates [(708798.9249999998, 6592519.7445)]
# Skipping invalid value 255 at coordinates [(690261.2017999999, 6578711.4855)]
# Skipping invalid value 255 at coordinates [(691174.7335999999, 6599909.8615)]
# Skipping invalid value 255 at coordinates [(679966.9708000002, 6602519.9086)]
# Skipping invalid value 255 at coordinates [(708715.4469999997, 6590395.4149)]
# Skipping invalid value 255 at coordinates [(690253.4134, 6578670.9749)]
# Skipping invalid value 255 at coordinates [(691008.0576, 6599848.2446)]
# Skipping invalid value 255 at coordinates [(679934.3771000002, 6602510.6498)]
# Skipping invalid value 255 at coordinates [(690953.8724999996, 6580463.4292)]
# Skipping invalid value 255 at coordinates [(677871.7384000001, 6577336.4184)]
# Processing: Z:\Data\CLASSIFIED\with_indices_3129AA_05_2020_1386_RGB_RECT_projected_classified.tif
# Skipping invalid value 0 at coordinates [(689963.5349000003, 6570128.567)]
# Skipping invalid value 0 at coordinates [(690554.9042999996, 6594323.7953)]
# Skipping invalid value 0 at coordinates [(701864.3657, 6588811.1657)]
# Skipping invalid value 0 at coordinates [(689763.1364000002, 6570196.1107)]
# Skipping invalid value 0 at coordinates [(690387.2967999997, 6594332.7356)]
# Skipping invalid value 0 at coordinates [(690942.4511000002, 6599787.0709)]
# Skipping invalid value 0 at coordinates [(690883.9029000001, 6580352.031)]
# Skipping invalid value 0 at coordinates [(679980.5745999999, 6602618.4019)]
# Skipping invalid value 0 at coordinates [(708731.5776000004, 6592517.9952)]
# Skipping invalid value 0 at coordinates [(698056.7525000004, 6591147.1521)]
# Skipping invalid value 0 at coordinates [(698960.8870000001, 6568254.0181)]
# Skipping invalid value 0 at coordinates [(708500.1891999999, 6590365.6486)]
# Skipping invalid value 0 at coordinates [(701797.068, 6588818.8626)]
# Skipping invalid value 0 at coordinates [(703228.7085999995, 6579902.504)]
# Skipping invalid value 0 at coordinates [(692713.8925000001, 6567680.0679)]
# Skipping invalid value 0 at coordinates [(703330.7960000001, 6579902.504)]
# Skipping invalid value 0 at coordinates [(707889.0376000004, 6590427.5369)]
# Skipping invalid value 0 at coordinates [(679875.1328999996, 6602525.3526)]
# Skipping invalid value 0 at coordinates [(679845.7358999997, 6602455.2579)]
# Skipping invalid value 0 at coordinates [(702424.5541000003, 6578984.8591)]
# Skipping invalid value 0 at coordinates [(708634.9680000003, 6590346.1374)]
# Skipping invalid value 0 at coordinates [(694247.0718999999, 6567504.6648)]
# Skipping invalid value 0 at coordinates [(689174.9493000004, 6590143.8048)]
# Skipping invalid value 0 at coordinates [(701682.3980999999, 6588873.4917)]
# Skipping invalid value 0 at coordinates [(693016.0283000004, 6598394.2897)]
# Skipping invalid value 0 at coordinates [(708714.5022999998, 6589524.5199)]
# Skipping invalid value 0 at coordinates [(689803.7492000004, 6570131.5488)]
# Skipping invalid value 0 at coordinates [(690966.3459999999, 6580536.1162)]
# Skipping invalid value 0 at coordinates [(677816.0344000002, 6577293.8581)]
# Skipping invalid value 0 at coordinates [(708678.2279000003, 6590353.891)]
# Skipping invalid value 0 at coordinates [(702933.3103, 6579569.8428)]
# Skipping invalid value 0 at coordinates [(699032.5999999996, 6568255.123)]
# Skipping invalid value 0 at coordinates [(679913.3339999998, 6602465.2133)]
# Skipping invalid value 0 at coordinates [(707867.6095000003, 6590368.5783)]
# Skipping invalid value 0 at coordinates [(708733.2127999999, 6590355.6482)]
# Skipping invalid value 0 at coordinates [(690847.1199000003, 6580315.3625)]
# Skipping invalid value 0 at coordinates [(689928.6984999999, 6570127.1777)]
# Skipping invalid value 0 at coordinates [(695098.1168999998, 6567396.3136)]
# Skipping invalid value 0 at coordinates [(690380.9842999997, 6594385.0968)]
# Skipping invalid value 0 at coordinates [(693658.5997000001, 6567642.4525)]
# Skipping invalid value 0 at coordinates [(692996.8071999997, 6598449.3384)]
# Skipping invalid value 0 at coordinates [(692647.8552000001, 6567968.2175)]
# Skipping invalid value 0 at coordinates [(708400.1962000001, 6590473.1306)]
# Skipping invalid value 0 at coordinates [(690433.9988000002, 6579176.4563)]
# Skipping invalid value 0 at coordinates [(692828.1728999997, 6568093.3901)]
# Skipping invalid value 0 at coordinates [(698162.1957, 6591094.3607)]
# Skipping invalid value 0 at coordinates [(689304.2660999997, 6590074.5991)]
# Skipping invalid value 0 at coordinates [(689751.7734000003, 6570131.0613)]
# Skipping invalid value 0 at coordinates [(708903.4233999997, 6590186.887)]
# Skipping invalid value 0 at coordinates [(691005.8410999998, 6599731.2167)]
# Skipping invalid value 0 at coordinates [(692875.5450999998, 6598371.8647)]
# Skipping invalid value 0 at coordinates [(690807.0250000004, 6580248.7889)]
# Skipping invalid value 0 at coordinates [(689750.3816, 6570256.7704)]
# Skipping invalid value 0 at coordinates [(692998.3472999996, 6567683.7487)]
# Skipping invalid value 0 at coordinates [(703272.8957000002, 6579910.1225)]
# Skipping invalid value 0 at coordinates [(701699.7012999998, 6588825.7231)]
# Skipping invalid value 0 at coordinates [(690142.5062999995, 6570357.0003)]
# Skipping invalid value 0 at coordinates [(707958.1490000002, 6590428.4815)]
# Skipping invalid value 0 at coordinates [(690984.4256999996, 6581705.8585)]
# Skipping invalid value 0 at coordinates [(708853.5695000002, 6592514.3622)]
# Skipping invalid value 0 at coordinates [(690028.6464999998, 6570195.3239)]
# Skipping invalid value 0 at coordinates [(689673.0053000003, 6570333.7507)]
# Skipping invalid value 0 at coordinates [(708798.9249999998, 6592519.7445)]
# Skipping invalid value 0 at coordinates [(690261.2017999999, 6578711.4855)]
# Skipping invalid value 0 at coordinates [(691174.7335999999, 6599909.8615)]
# Skipping invalid value 0 at coordinates [(679966.9708000002, 6602519.9086)]
# Skipping invalid value 0 at coordinates [(708715.4469999997, 6590395.4149)]
# Skipping invalid value 0 at coordinates [(690253.4134, 6578670.9749)]
# Skipping invalid value 0 at coordinates [(691008.0576, 6599848.2446)]
# Skipping invalid value 0 at coordinates [(679934.3771000002, 6602510.6498)]
# Skipping invalid value 0 at coordinates [(690953.8724999996, 6580463.4292)]
# Skipping invalid value 0 at coordinates [(677871.7384000001, 6577336.4184)]
# Overall Accuracy: 0.6623376623376623
# Confusion Matrix:
# [[ 4  1  0  0  1  3  0  0]
#  [ 1  4  3  0  0  1  0  0]
#  [ 1  1  7  0  0  2  0  0]
#  [ 0  0  0 10  0  0  0  2]
#  [ 0  0  0  0  9  0  0  0]
#  [ 0  0  2  0  1  6  0  0]
#  [ 0  0  0  1  3  0  5  0]
#  [ 0  0  0  3  0  0  0  6]]
#
# User's Accuracy:
# Class 1: 0.67
# Class 2: 0.67
# Class 3: 0.58
# Class 4: 0.71
# Class 5: 0.64
# Class 6: 0.50
# Class 7: 1.00
# Class 8: 0.75
#
# Producer's Accuracy:
# Class 1: 0.44
# Class 2: 0.44
# Class 3: 0.64
# Class 4: 0.83
# Class 5: 1.00
# Class 6: 0.67
# Class 7: 0.56
# Class 8: 0.67
#
# Kappa Coefficient:
# 0.61
#
# Comparison Table:
#     Validation Value  Classified Value
# 0                7.0                 5
# 1                7.0                 7
# 2                7.0                 7
# 3                7.0                 5
# 4                7.0                 7
# ..               ...               ...
# 72               2.0                 2
# 73               2.0                 2
# 74               2.0                 3
# 75               6.0                 6
# 76               6.0                 3
#
# [77 rows x 2 columns]

# %% [markdown]
# #### Inter accuracy assessment

# %%
# Initialize lists to store overall metrics
all_validation_values = []
all_classified_values = []

# Initialize lists to store detailed comparison data
comparison_data = []

# Define groups
def group_class(value):
    if value in [1, 2, 3]:  # Invasive alien plants
        return 'Invasive Alien'
    elif value in [4, 5, 6, 7, 8]:  # Non-invasive plants
        return 'Non-Invasive'
    else:
        return 'Unknown'

# Loop through each classified image
for classified_image_file in classified_imagelist:
    print("Processing:", classified_image_file)
    
    # Open the classified image
    with rasterio.open(classified_image_file) as classified_image:
        # Generate samples of the classified image values at validation point locations
        validation_values = []
        classified_values = []
        
        for _, row in validation_gdf.iterrows():
            coords = [(row.geometry.x, row.geometry.y)]
            sampled_values = list(sample_gen(classified_image, coords))
            
            if sampled_values:
                classified_value = sampled_values[0][0]
                
                # Ensure classified values are between 1 and 8, ignoring 0 or 255 (NoData or out of range values)
                if 1 <= classified_value <= 8:
                    validation_value = row['ID']  # Assuming 'ID' is the ground truth column name
                    classified_values.append(classified_value)
                    validation_values.append(validation_value)
                    
                    # Store comparison data
                    comparison_data.append({
                        'Validation Value': validation_value,
                        'Classified Value': classified_value,
                        'Grouped Validation': group_class(validation_value),
                        'Grouped Classified': group_class(classified_value)
                    })
        
        # Append to overall lists
        all_validation_values.extend(validation_values)
        all_classified_values.extend(classified_values)

# Group the values
grouped_validation_values = [group_class(value) for value in all_validation_values]
grouped_classified_values = [group_class(value) for value in all_classified_values]

# Calculate overall accuracy for the grouped classes
accuracy = accuracy_score(grouped_validation_values, grouped_classified_values)
conf_matrix = confusion_matrix(grouped_validation_values, grouped_classified_values, labels=['Invasive Alien', 'Non-Invasive'])

# Calculate Kappa Coefficient
def calculate_kappa(conf_matrix):
    total = np.sum(conf_matrix)
    sum_po = np.sum(np.diag(conf_matrix))  # Observed agreement
    sum_pe = np.sum(np.sum(conf_matrix, axis=0) * np.sum(conf_matrix, axis=1)) / total  # Expected agreement
    kappa = (sum_po - sum_pe) / (total - sum_pe) if (total - sum_pe) != 0 else 0
    return kappa

kappa = calculate_kappa(conf_matrix)

# Print results
print("Overall Accuracy:", accuracy)
print("Confusion Matrix:")
print(conf_matrix)

# Print Kappa Coefficient
print("\nKappa Coefficient:")
print(f"{kappa:.2f}")

# Create and print comparison DataFrame
comparison_df = pd.DataFrame(comparison_data)
print("\nComparison Table:")
print(comparison_df)
# Out:
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_16_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_17_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_18_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_19_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_20_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_21_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_22_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_23_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_24_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DB_25_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_01_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_02_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_03_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_04_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_05_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_06_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_07_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_08_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_09_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_10_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_11_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_12_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_13_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_14_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_15_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_16_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_17_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_18_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_19_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_20_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_21_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_22_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_23_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_24_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3028DD_25_2020_1377_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CA_16_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CA_17_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CA_18_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CA_19_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CA_20_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CA_21_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CA_22_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CA_23_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CA_24_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CA_25_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_01_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_02_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_03_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_04_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_05_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_06_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_07_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_08_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_09_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_10_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_11_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_12_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_13_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_14_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_15_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_16_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_17_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_18_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_19_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_20_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_21_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_22_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_23_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_24_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3029CC_25_2019_1380_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3128BB_01_2021_1384_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3128BB_02_2021_1384_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3128BB_03_2021_1384_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3128BB_04_2021_1384_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3128BB_05_2021_1384_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3129AA_01_2020_1386_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3129AA_02_2020_1386_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3129AA_03_2020_1386_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3129AA_04_2020_1386_RGB_RECT_projected_classified.tif
# Processing: Z:\Data\CLASSIFIED\with_indices_3129AA_05_2020_1386_RGB_RECT_projected_classified.tif
# Overall Accuracy: 0.8831168831168831
# Confusion Matrix:
# [[22  7]
#  [ 2 46]]
#
# Kappa Coefficient:
# 0.74
#
# Comparison Table:
#     Validation Value  Classified Value Grouped Validation Grouped Classified
# 0                7.0                 5       Non-Invasive       Non-Invasive
# 1                7.0                 7       Non-Invasive       Non-Invasive
# 2                7.0                 7       Non-Invasive       Non-Invasive
# 3                7.0                 5       Non-Invasive       Non-Invasive
# 4                7.0                 7       Non-Invasive       Non-Invasive
# ..               ...               ...                ...                ...
# 72               2.0                 2     Invasive Alien     Invasive Alien
# 73               2.0                 2     Invasive Alien     Invasive Alien
# 74               2.0                 3     Invasive Alien     Invasive Alien
# 75               6.0                 6       Non-Invasive       Non-Invasive
# 76               6.0                 3       Non-Invasive     Invasive Alien
#
# [77 rows x 4 columns]

# %% [markdown]
# #### Intra accuracy assessment

# %%
# Define the paths
classified_image_path = r'Z:\Data\CLASSIFIED'
classified_imagelist = [os.path.join(classified_image_path, file) for file in os.listdir(classified_image_path) if file.endswith('.TIF') or file.endswith('.tif')]

# Initialize lists to store overall metrics
all_validation_values = []
all_classified_values = []

# Initialize lists to store detailed comparison data
comparison_data = []

# Define groups
def group_class(value):
    if value == 1:  # Black Wattle
        return 'Invasive Alien 1'  # Black Wattle
    elif value == 2:  # Gum
        return 'Invasive Alien 2'  # Gum
    elif value == 3:  # Silver Wattle
        return 'Invasive Alien 3'  # Silver Wattle
    elif value in [4, 5, 6, 7, 8]:  # Non-invasive plants
        return 'Non-Invasive'
    else:
        return 'Unknown'

# Loop through each TIFF file in the specified directory
for classified_image_file in classified_imagelist:
    print(f'Processing file: {classified_image_file}')
    
    # Open the classified image
    with rasterio.open(classified_image_file) as classified_image:
        # Generate samples of the classified image values at validation point locations
        validation_values = []
        classified_values = []
        
        for _, row in validation_gdf.iterrows():
            coords = [(row.geometry.x, row.geometry.y)]
            sampled_values = list(sample_gen(classified_image, coords))
            if sampled_values:
                classified_value = sampled_values[0][0]
                
                # Ensure classified values are between 1 and 8, ignoring 0 or 255 (which may be NoData)
                if classified_value in [1, 2, 3, 4, 5, 6, 7, 8]:
                    validation_value = row['ID']  # Assuming 'ID' is the ground truth column name
                    classified_values.append(classified_value)
                    validation_values.append(validation_value)
                    
                    # Store comparison data
                    comparison_data.append({
                        'Validation Value': validation_value,
                        'Classified Value': classified_value,
                        'Grouped Validation': group_class(validation_value),
                        'Grouped Classified': group_class(classified_value)
                    })
        
        # Append to overall lists
        all_validation_values.extend(validation_values)
        all_classified_values.extend(classified_values)

# Group the values
grouped_validation_values = [group_class(value) for value in all_validation_values]
grouped_classified_values = [group_class(value) for value in all_classified_values]

# Calculate overall accuracy for the grouped classes
accuracy = accuracy_score(grouped_validation_values, grouped_classified_values)
conf_matrix = confusion_matrix(
    grouped_validation_values,
    grouped_classified_values,
    labels=[
        'Invasive Alien 1',  # Black Wattle
        'Invasive Alien 2',  # Gum
        'Invasive Alien 3',  # Silver Wattle
        'Non-Invasive'       # Classes 4-8
    ]
)

# Calculate Kappa Coefficient
def calculate_kappa(conf_matrix):
    total = np.sum(conf_matrix)
    sum_po = np.sum(np.diag(conf_matrix))  # Observed agreement
    sum_pe = np.sum(np.sum(conf_matrix, axis=0) * np.sum(conf_matrix, axis=1)) / total  # Expected agreement
    kappa = (sum_po - sum_pe) / (total - sum_pe) if (total - sum_pe) != 0 else 0
    return kappa

kappa = calculate_kappa(conf_matrix)

print("Overall Accuracy:", accuracy)
print("Confusion Matrix:")
print(conf_matrix)

# Print Kappa Coefficient
print("\nKappa Coefficient:")
print(f"{kappa:.2f}")

# Create and print comparison DataFrame
comparison_df = pd.DataFrame(comparison_data)
print("\nComparison Table:")
print(comparison_df)
# Out:
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DB_16_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DB_17_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DB_18_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DB_19_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DB_20_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DB_21_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DB_22_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DB_23_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DB_24_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DB_25_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_01_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_02_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_03_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_04_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_05_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_06_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_07_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_08_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_09_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_10_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_11_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_12_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_13_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_14_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_15_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_16_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_17_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_18_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_19_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_20_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_21_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_22_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_23_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_24_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3028DD_25_2020_1377_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CA_16_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CA_17_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CA_18_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CA_19_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CA_20_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CA_21_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CA_22_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CA_23_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CA_24_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CA_25_2019_1380_RGB_RECT_projected_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_01_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_02_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_03_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_04_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_05_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_06_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_07_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_08_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_09_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_10_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_11_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_12_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_13_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_14_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_15_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_16_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_17_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_18_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_19_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_20_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_21_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_22_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_23_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_24_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3029CC_25_2019_1380_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3128BB_01_2021_1384_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3128BB_02_2021_1384_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3128BB_03_2021_1384_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3128BB_04_2021_1384_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3128BB_05_2021_1384_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3129AA_01_2020_1386_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3129AA_02_2020_1386_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3129AA_03_2020_1386_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3129AA_04_2020_1386_RGB_RECT_projected_classified.tif
# Processing file: Z:\Data\CLASSIFIED\with_indices_3129AA_05_2020_1386_RGB_RECT_projected_classified.tif
# Overall Accuracy: 0.7922077922077922
# Confusion Matrix:
# [[ 4  1  0  4]
#  [ 1  4  3  1]
#  [ 1  1  7  2]
#  [ 0  0  2 46]]
#
# Kappa Coefficient:
# 0.61
#
# Comparison Table:
#     Validation Value  Classified Value Grouped Validation Grouped Classified
# 0                7.0                 5       Non-Invasive       Non-Invasive
# 1                7.0                 7       Non-Invasive       Non-Invasive
# 2                7.0                 7       Non-Invasive       Non-Invasive
# 3                7.0                 5       Non-Invasive       Non-Invasive
# 4                7.0                 7       Non-Invasive       Non-Invasive
# ..               ...               ...                ...                ...
# 72               2.0                 2   Invasive Alien 2   Invasive Alien 2
# 73               2.0                 2   Invasive Alien 2   Invasive Alien 2
# 74               2.0                 3   Invasive Alien 2   Invasive Alien 3
# 75               6.0                 6       Non-Invasive       Non-Invasive
# 76               6.0                 3       Non-Invasive   Invasive Alien 3
#
# [77 rows x 4 columns]
